# %%
output_folder_msi = "/home/ajarrah/PhD_Thesis/chapter_4/h5ad_data_copy/lipids_common/"
output_folder_st = "/home/ajarrah/PhD_Thesis/chapter_4/h5ad_data_copy/genes/"

# %%
import os
import scanpy as sc

# %%
msi_paths = [
        '/home/ajarrah/PhD_Thesis/chapter_4/h5ad_data/lipids_common/msi_aad_1_20.h5ad',
        '/home/ajarrah/PhD_Thesis/chapter_4/h5ad_data/lipids_common/msi_aad_2_20.h5ad',
        '/home/ajarrah/PhD_Thesis/chapter_4/h5ad_data/lipids_common/msi_aad_3_20.h5ad',
        '/home/ajarrah/PhD_Thesis/chapter_4/h5ad_data/lipids_common/msi_aad_4_20.h5ad',
        '/home/ajarrah/PhD_Thesis/chapter_4/h5ad_data/lipids_common/msi_ac_1_20.h5ad',
        '/home/ajarrah/PhD_Thesis/chapter_4/h5ad_data/lipids_common/msi_ac_2_20.h5ad',
        '/home/ajarrah/PhD_Thesis/chapter_4/h5ad_data/lipids_common/msi_ac_3_20.h5ad',
        '/home/ajarrah/PhD_Thesis/chapter_4/h5ad_data/lipids_common/msi_ac_4_20.h5ad',
        '/home/ajarrah/PhD_Thesis/chapter_4/h5ad_data/lipids_common/msi_yad_1_20.h5ad',
        '/home/ajarrah/PhD_Thesis/chapter_4/h5ad_data/lipids_common/msi_yad_2_20.h5ad',
        '/home/ajarrah/PhD_Thesis/chapter_4/h5ad_data/lipids_common/msi_yad_3_20.h5ad',
        '/home/ajarrah/PhD_Thesis/chapter_4/h5ad_data/lipids_common/msi_yad_4_20.h5ad',
        '/home/ajarrah/PhD_Thesis/chapter_4/h5ad_data/lipids_common/msi_yc_1_20.h5ad',
        '/home/ajarrah/PhD_Thesis/chapter_4/h5ad_data/lipids_common/msi_yc_2_20.h5ad',
        '/home/ajarrah/PhD_Thesis/chapter_4/h5ad_data/lipids_common/msi_yc_3_20.h5ad',
        '/home/ajarrah/PhD_Thesis/chapter_4/h5ad_data/lipids_common/msi_yc_4_20.h5ad'
    ]
        
st_paths = [
        '/home/ajarrah/PhD_Thesis/chapter_4/h5ad_data/genes/rna_aad_1_20.h5ad',
        '/home/ajarrah/PhD_Thesis/chapter_4/h5ad_data/genes/rna_aad_2_20.h5ad',
        '/home/ajarrah/PhD_Thesis/chapter_4/h5ad_data/genes/rna_aad_3_20.h5ad',
        '/home/ajarrah/PhD_Thesis/chapter_4/h5ad_data/genes/rna_aad_4_20.h5ad',
        '/home/ajarrah/PhD_Thesis/chapter_4/h5ad_data/genes/rna_ac_1_20.h5ad',
        '/home/ajarrah/PhD_Thesis/chapter_4/h5ad_data/genes/rna_ac_2_20.h5ad',
        '/home/ajarrah/PhD_Thesis/chapter_4/h5ad_data/genes/rna_ac_3_20.h5ad',
        '/home/ajarrah/PhD_Thesis/chapter_4/h5ad_data/genes/rna_ac_4_20.h5ad',
        '/home/ajarrah/PhD_Thesis/chapter_4/h5ad_data/genes/rna_yad_1_20.h5ad',
        '/home/ajarrah/PhD_Thesis/chapter_4/h5ad_data/genes/rna_yad_2_20.h5ad',
        '/home/ajarrah/PhD_Thesis/chapter_4/h5ad_data/genes/rna_yad_3_20.h5ad',
        '/home/ajarrah/PhD_Thesis/chapter_4/h5ad_data/genes/rna_yad_4_20.h5ad',
        '/home/ajarrah/PhD_Thesis/chapter_4/h5ad_data/genes/rna_yc_1_20.h5ad',
        '/home/ajarrah/PhD_Thesis/chapter_4/h5ad_data/genes/rna_yc_2_20.h5ad',
        '/home/ajarrah/PhD_Thesis/chapter_4/h5ad_data/genes/rna_yc_3_20.h5ad',
        '/home/ajarrah/PhD_Thesis/chapter_4/h5ad_data/genes/rna_yc_4_20.h5ad'
    ]

# %%
for i, path in enumerate(msi_paths):
    adata = sc.read_h5ad(path)
    print(adata)
    adata = adata[:1200, :500].copy()
    adata.write_h5ad(os.path.join(output_folder_msi, path.split("/")[-1]))

for i, path in enumerate(st_paths):
    adata = sc.read_h5ad(path)
    print(adata)
    adata = adata[:1200, :500].copy()
    adata.write_h5ad(os.path.join(output_folder_st, path.split("/")[-1]))
# Out:
# AnnData object with n_obs × n_vars = 1200 × 500
#     obs: 'sample', 'y', 'x', 'x_um', 'y_um'
#     obsm: 'spatial'
# AnnData object with n_obs × n_vars = 1200 × 500
#     obs: 'sample', 'y', 'x', 'x_um', 'y_um'
#     obsm: 'spatial'
# AnnData object with n_obs × n_vars = 1200 × 500
#     obs: 'sample', 'y', 'x', 'x_um', 'y_um'
#     obsm: 'spatial'
# AnnData object with n_obs × n_vars = 1200 × 500
#     obs: 'sample', 'y', 'x', 'x_um', 'y_um'
#     obsm: 'spatial'
# AnnData object with n_obs × n_vars = 1200 × 500
#     obs: 'sample', 'y', 'x', 'x_um', 'y_um'
#     obsm: 'spatial'
# AnnData object with n_obs × n_vars = 1200 × 500
#     obs: 'sample', 'y', 'x', 'x_um', 'y_um'
#     obsm: 'spatial'
# AnnData object with n_obs × n_vars = 1200 × 500
#     obs: 'sample', 'y', 'x', 'x_um', 'y_um'
#     obsm: 'spatial'
# AnnData object with n_obs × n_vars = 1200 × 500
#     obs: 'sample', 'y', 'x', 'x_um', 'y_um'
#     obsm: 'spatial'
# AnnData object with n_obs × n_vars = 1200 × 500
# ...
