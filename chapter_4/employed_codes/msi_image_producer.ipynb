# %%
"""
Optimized MSI Processing Pipeline with Memory Management
"""

import os
import gc
import psutil
import pandas as pd
import numpy as np
import scanpy as sc
import matplotlib
matplotlib.use('Agg')  # Non-interactive backend to prevent memory leaks
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
from concurrent.futures import ProcessPoolExecutor, as_completed
from functools import partial

# =============================================================================
# CONFIGURATION SECTION
# =============================================================================

class Config:
    """Configuration settings for memory and CPU usage"""
    # Resource limits
    MAX_MEMORY_GB = 160  # Maximum memory usage in GB (adjust based on your system)
    NUM_CORES = 78  # Number of CPU cores to use (None = all available - 1)
    BATCH_SIZE = 156  # Number of plots to process before garbage collection
    
    # Input/Output paths
    MSI_INPUT_FOLDER = "/home/ajarrah/PhD_Thesis/chapter_2/h5ad_data_processed_4lockmasses_filtered_halfbrain/"
    COMMON_MZS_CSV = "/home/ajarrah/PhD_Thesis/chapter_2/csv_data/common_mz_clusters_improved.csv"
    OUTPUT_DIR = "/home/ajarrah/PhD_Thesis/chapter_4/images/lipids/"
    
    # Processing parameters
    SQUARE_SPACING = 60  # µm center-to-center
    MZ_TOLERANCE = 0.01
    VMAX_PERCENTILE = 99.9
    SQUARE_SIZE = 60
    DPI = 300
    
    # Sample IDs
    SAMPLE_IDS = [
        "aad_1", "aad_2", "aad_3", "aad_4",
        "ac_1", "ac_2", "ac_3", "ac_4",
        "yad_1", "yad_2", "yad_3", "yad_4",
        "yc_1", "yc_2", "yc_3", "yc_4"
    ]
    
    MSI_ORDER = [
        'yc_1', 'yc_2', 'yc_3', 'yc_4',
        'yad_1', 'yad_2', 'yad_3', 'yad_4',
        'ac_1', 'ac_2', 'ac_3', 'ac_4',
        'aad_1', 'aad_2', 'aad_3', 'aad_4'
    ]

# =============================================================================
# CUSTOM COLORMAP
# =============================================================================

CUSTOM_CMAP = LinearSegmentedColormap.from_list("custom_scale", [
    (0.0, "#454545"),      # dark gray
    (0.00000001, "#000000"),  # black
    (0.10, "#000080"),     # navy
    (0.15, "#0000FF"),     # blue
    (0.30, "#8000FF"),     # purple-ish
    (0.45, "#FF0000"),     # red
    (0.60, "#FF8000"),     # orange
    (0.75, "#FFFF00"),     # yellow
    (1.0, "#FFFFFF")       # white
])

# =============================================================================
# MEMORY MONITORING UTILITIES
# =============================================================================

def check_memory_usage():
    """Check current memory usage"""
    process = psutil.Process(os.getpid())
    mem_gb = process.memory_info().rss / (1024 ** 3)
    return mem_gb

def force_garbage_collection():
    """Force garbage collection and clear matplotlib cache"""
    plt.close('all')
    gc.collect()

# =============================================================================
# DATA LOADING AND PREPROCESSING
# =============================================================================

def load_sample(sample_id, input_folder):
    """Load a single h5ad sample with error handling"""
    filepath = os.path.join(input_folder, f"halfbrain_{sample_id}_filtered.h5ad")
    try:
        adata = sc.read_h5ad(filepath)
        print(f"✓ Loaded {sample_id}")
        return adata
    except Exception as e:
        print(f"✗ Failed to load {sample_id}: {e}")
        return None

def preprocess_sample(adata, pixel_spacing):
    """Add TIC and spatial coordinates to AnnData object"""
    # Calculate TIC
    tic = adata.X.sum(axis=1)
    if hasattr(tic, "A1"):  # sparse matrix
        tic = tic.A1
    else:
        tic = np.asarray(tic).flatten()
    adata.obs["Processed_TIC"] = tic
    
    # Add spatial coordinates in µm
    spatial = adata.obsm['spatial']
    array_row = spatial[:, 1]
    array_col = spatial[:, 0]
    adata.obs['x_um'] = array_col * pixel_spacing
    adata.obs['y_um'] = array_row * pixel_spacing
    
    return adata

def load_and_preprocess_all_samples(config):
    """Load all samples and preprocess them"""
    print("=" * 80)
    print("LOADING AND PREPROCESSING SAMPLES")
    print("=" * 80)
    
    sample_map = {}
    for sample_id in config.SAMPLE_IDS:
        adata = load_sample(sample_id, config.MSI_INPUT_FOLDER)
        if adata is not None:
            adata = preprocess_sample(adata, config.SQUARE_SPACING)
            sample_map[sample_id] = adata
            
        # Monitor memory
        mem_gb = check_memory_usage()
        if mem_gb > config.MAX_MEMORY_GB * 0.8:
            print(f"⚠️ Memory usage high ({mem_gb:.2f} GB), forcing cleanup...")
            force_garbage_collection()
    
    print(f"\n✓ Loaded {len(sample_map)}/{len(config.SAMPLE_IDS)} samples successfully\n")
    return sample_map

def load_common_mz_data(csv_path, msi_order):
    """Load and pivot common m/z data"""
    print("Loading common m/z data...")
    common_mz_df = pd.read_csv(csv_path)
    
    # Create sample_id column
    common_mz_df['sample_id'] = (
        common_mz_df['group'].str.lower() + '_' + 
        common_mz_df['sample'].astype(str)
    )
    
    # Pivot and sort
    pivot_df = common_mz_df.pivot(
        index='sample_id', 
        columns='common_group_name', 
        values='mzs'
    )
    pivot_df_sorted = pivot_df.loc[pivot_df.index.intersection(msi_order)]
    pivot_df_sorted = pivot_df_sorted.loc[msi_order]
    
    print(f"✓ Loaded m/z data for {len(pivot_df_sorted)} samples\n")
    return pivot_df_sorted

# =============================================================================
# PLOTTING FUNCTION
# =============================================================================

def msi_plot_producer(
    adata,
    mz_val,
    sample_name,
    output_dir,
    tol=0.01,
    vmax_percentile=99.8,
    square_size=60,
    cmap=CUSTOM_CMAP,
    dpi=300,
    show_colorbar=False,
    show_axis=False,
    show_title=False,
    background_color="#00BF00"
):
    """
    Plot TIC-normalized intensity for one m/z and one sample.
    Optimized to minimize memory usage.
    """
    try:
        # Extract m/z index
        mz_axis = adata.var_names.astype(float).values
        mz_diff = np.abs(mz_axis - mz_val)
        if np.min(mz_diff) > tol:
            return False, f"m/z {mz_val} not found within tolerance {tol}"
        mz_index = np.argmin(mz_diff)
        
        # Extract intensities
        intensities = (
            adata.X[:, mz_index].toarray().flatten()
            if hasattr(adata.X, "toarray")
            else adata.X[:, mz_index]
        )
        
        # Extract coordinates & TIC
        x = adata.obs["x_um"].values
        y = adata.obs["y_um"].values
        tic = adata.obs["Processed_TIC"].values
        
        # Normalize by TIC
        normalized_intensities = (intensities / tic) * 100
        normalized_intensities = np.nan_to_num(
            normalized_intensities, nan=0.0, posinf=0.0, neginf=0.0
        )
        
        # Build grid
        x_unique = np.unique(x)
        y_unique = np.unique(y)
        x_size = len(x_unique)
        y_size = len(y_unique)
        grid = np.full((y_size, x_size), np.nan)
        
        for xi, yi, val in zip(x, y, normalized_intensities):
            x_idx = np.where(x_unique == xi)[0][0]
            y_idx = np.where(y_unique == yi)[0][0]
            grid[y_idx, x_idx] = val
        
        # Color scaling
        vmin_value = np.nanmin(normalized_intensities)
        vmax_value = np.percentile(normalized_intensities, vmax_percentile)
        
        # Create figure
        extent = [x.min(), x.max() + square_size, y.min(), y.max() + square_size]
        fig, ax = plt.subplots(
            figsize=(x_size * square_size / 1000, y_size * square_size / 1000)
        )
        fig.patch.set_facecolor(background_color)
        
        im = ax.imshow(
            grid,
            cmap=cmap,
            origin="lower",
            extent=extent,
            vmin=vmin_value,
            vmax=vmax_value,
            interpolation="none",
        )
        ax.invert_xaxis()
        ax.set_aspect("equal")
        
        if show_axis:
            ax.set_xlabel("x (µm)")
            ax.set_ylabel("y (µm)")
        else:
            ax.axis("off")
        
        if show_title:
            ax.set_title(f"m/z {mz_val:.4f} normalized intensity")
        
        if show_colorbar:
            cbar = fig.colorbar(im, ax=ax)
            cbar.set_label("Normalized intensity (TIC%)")
        
        # Save image
        sample_dir = os.path.join(output_dir, sample_name)
        os.makedirs(sample_dir, exist_ok=True)
        filename = f"{mz_val:.4f}|{sample_name}|{vmin_value:.2f}|{vmax_value:.2f}.png"
        filepath = os.path.join(sample_dir, filename)
        fig.savefig(filepath, dpi=dpi, bbox_inches="tight", transparent=False)
        
        # Clean up immediately
        plt.close(fig)
        del fig, ax, im, grid, normalized_intensities
        
        return True, f"✅ {sample_name} | m/z {mz_val:.4f}"
        
    except Exception as e:
        plt.close('all')
        return False, f"⚠️ Failed {sample_name} | m/z {mz_val:.4f}: {e}"

# =============================================================================
# PARALLEL PROCESSING WITH SERIALIZATION
# =============================================================================

def process_mz_wrapper(args):
    """
    Wrapper function for multiprocessing.
    Each process loads its own copy of the data to avoid serialization issues.
    """
    sample_id, mz_val, config = args
    
    try:
        # Load sample in this process
        adata = load_sample(sample_id, config.MSI_INPUT_FOLDER)
        if adata is None:
            return False, f"⚠️ Failed to load {sample_id}"
        
        adata = preprocess_sample(adata, config.SQUARE_SPACING)
        
        # Generate plot
        success, msg = msi_plot_producer(
            adata=adata,
            mz_val=mz_val,
            sample_name=sample_id,
            output_dir=config.OUTPUT_DIR,
            tol=config.MZ_TOLERANCE,
            vmax_percentile=config.VMAX_PERCENTILE,
            square_size=config.SQUARE_SIZE,
            cmap=CUSTOM_CMAP,
            dpi=config.DPI,
            show_colorbar=False,
            show_axis=False,
            show_title=False,
            background_color="#00BF00"
        )
        
        # Clean up
        del adata
        force_garbage_collection()
        
        return success, msg
        
    except Exception as e:
        return False, f"⚠️ Error {sample_id} | m/z {mz_val:.4f}: {e}"

# =============================================================================
# MAIN PROCESSING PIPELINE
# =============================================================================

def main():
    """Main processing pipeline"""
    # Initialize configuration
    config = Config()
    
    # Set number of cores
    if config.NUM_CORES is None:
        max_workers = max(1, os.cpu_count() - 1)
    else:
        max_workers = min(config.NUM_CORES, os.cpu_count())
    
    print("=" * 80)
    print("MSI PROCESSING PIPELINE")
    print("=" * 80)
    print(f"Max Memory: {config.MAX_MEMORY_GB} GB")
    print(f"CPU Cores: {max_workers}")
    print(f"Batch Size: {config.BATCH_SIZE}")
    print("=" * 80 + "\n")
    
    # Load common m/z data
    pivot_df = load_common_mz_data(config.COMMON_MZS_CSV, config.MSI_ORDER)
    
    # Prepare all tasks
    tasks = []
    for sample_id in config.SAMPLE_IDS:
        if sample_id not in pivot_df.index:
            print(f"⚠️ Sample '{sample_id}' not in pivot table — skipping.")
            continue
        
        mz_values = pivot_df.loc[sample_id].values.astype(float)
        mz_values = mz_values[~np.isnan(mz_values)]
        
        for mz_val in mz_values:
            tasks.append((sample_id, mz_val, config))
    
    print(f"Total tasks to process: {len(tasks)}\n")
    print("=" * 80)
    print("PROCESSING")
    print("=" * 80 + "\n")
    
    # Process in batches to manage memory
    success_count = 0
    fail_count = 0
    
    with ProcessPoolExecutor(max_workers=max_workers) as executor:
        # Submit all tasks
        futures = [executor.submit(process_mz_wrapper, task) for task in tasks]
        
        # Process results
        for i, future in enumerate(as_completed(futures), 1):
            success, msg = future.result()
            if success:
                success_count += 1
            else:
                fail_count += 1
            
            print(f"[{i}/{len(tasks)}] {msg}")
            
            # Periodic garbage collection
            if i % config.BATCH_SIZE == 0:
                force_garbage_collection()
                mem_gb = check_memory_usage()
                print(f"  └─ Memory usage: {mem_gb:.2f} GB")
    
    # Final cleanup
    force_garbage_collection()
    
    print("\n" + "=" * 80)
    print("PROCESSING COMPLETE")
    print("=" * 80)
    print(f"✅ Success: {success_count}")
    print(f"⚠️ Failed: {fail_count}")
    print(f"📊 Total: {len(tasks)}")
    print("=" * 80)

if __name__ == "__main__":
    main()
# Out:
# ================================================================================
# MSI PROCESSING PIPELINE
# ================================================================================
# Max Memory: 160 GB
# CPU Cores: 78
# Batch Size: 156
# ================================================================================
#
# Loading common m/z data...
# ✓ Loaded m/z data for 16 samples
#
# Total tasks to process: 8448
#
# ================================================================================
# PROCESSING
# ================================================================================
#
# ✓ Loaded aad_1✓ Loaded aad_1
#
# ✓ Loaded aad_1
# ✓ Loaded aad_1✓ Loaded aad_1✓ Loaded aad_1✓ Loaded aad_1✓ Loaded aad_1✓ Loaded aad_1
# ✓ Loaded aad_1✓ Loaded aad_1
#
# ✓ Loaded aad_1✓ Loaded aad_1
#
# ✓ Loaded aad_1✓ Loaded aad_1✓ Loaded aad_1✓ Loaded aad_1✓ Loaded aad_1
# ✓ Loaded aad_1✓ Loaded aad_1
# ✓ Loaded aad_1✓ Loaded aad_1✓ Loaded aad_1
# ✓ Loaded aad_1✓ Loaded aad_1✓ Loaded aad_1✓ Loaded aad_1✓ Loaded aad_1✓ Loaded aad_1✓ Loaded aad_1✓ Loaded aad_1✓ Loaded aad_1✓ Loaded aad_1
# ✓ Loaded aad_1✓ Loaded aad_1
# ✓ Loaded aad_1
#
#
#
#
#
#
#
#
#
# ✓ Loaded aad_1
#
#
#
#
#
#
#
# ✓ Loaded aad_1
#
#
#
#
#
#
# ✓ Loaded aad_1✓ Loaded aad_1
#
# ✓ Loaded aad_1✓ Loaded aad_1✓ Loaded aad_1✓ Loaded aad_1
# ✓ Loaded aad_1✓ Loaded aad_1✓ Loaded aad_1
#
#
# ✓ Loaded aad_1✓ Loaded aad_1✓ Loaded aad_1
#
#
# ✓ Loaded aad_1✓ Loaded aad_1
#
#
# ✓ Loaded aad_1✓ Loaded aad_1
# ✓ Loaded aad_1✓ Loaded aad_1✓ Loaded aad_1
# ✓ Loaded aad_1✓ Loaded aad_1✓ Loaded aad_1
#
#
# ✓ Loaded aad_1✓ Loaded aad_1✓ Loaded aad_1
#
# ✓ Loaded aad_1✓ Loaded aad_1✓ Loaded aad_1✓ Loaded aad_1
#
#
#
# ✓ Loaded aad_1
#
# ✓ Loaded aad_1✓ Loaded aad_1✓ Loaded aad_1✓ Loaded aad_1✓ Loaded aad_1
#
#
#
# ✓ Loaded aad_1✓ Loaded aad_1✓ Loaded aad_1✓ Loaded aad_1
# ✓ Loaded aad_1
#
#
#
#
# ✓ Loaded aad_1
#
#
#
#
#
# ✓ Loaded aad_1
# ✓ Loaded aad_1
# ✓ Loaded aad_1✓ Loaded aad_1
#
# [1/8448] ✅ aad_1 | m/z 351.1722
# [2/8448] ✅ aad_1 | m/z 370.2803
# [3/8448] ✅ aad_1 | m/z 370.2451
# [4/8448] ✅ aad_1 | m/z 337.1939
# [5/8448] ✅ aad_1 | m/z 385.2140
# [6/8448] ✅ aad_1 | m/z 356.2655
# [7/8448] ✅ aad_1 | m/z 355.3724
# [8/8448] ✅ aad_1 | m/z 326.1996
# [9/8448] ✅ aad_1 | m/z 360.1393
# ✓ Loaded aad_1
# ✓ Loaded aad_1
# ✓ Loaded aad_1
# ✓ Loaded aad_1
# ✓ Loaded aad_1
# ✓ Loaded aad_1✓ Loaded aad_1
#
# ✓ Loaded aad_1
# ✓ Loaded aad_1
# ✓ Loaded aad_1
# ✓ Loaded aad_1
# ✓ Loaded aad_1
# ✓ Loaded aad_1
# [10/8448] ✅ aad_1 | m/z 358.2715
# [11/8448] ✅ aad_1 | m/z 355.2623
# [12/8448] ✅ aad_1 | m/z 339.2315
# [13/8448] ✅ aad_1 | m/z 387.2514
# [14/8448] ✅ aad_1 | m/z 357.2680
# [15/8448] ✅ aad_1 | m/z 383.2564
# [16/8448] ✅ aad_1 | m/z 351.2319
# [17/8448] ✅ aad_1 | m/z 340.2354
# [18/8448] ✅ aad_1 | m/z 341.2474
# [19/8448] ✅ aad_1 | m/z 354.2548
# [20/8448] ✅ aad_1 | m/z 386.2169
# [21/8448] ✅ aad_1 | m/z 385.2718
# [22/8448] ✅ aad_1 | m/z 352.2361
# ✓ Loaded aad_1✓ Loaded aad_1
#
# ✓ Loaded aad_1
# ✓ Loaded aad_1
# ✓ Loaded aad_1
# ✓ Loaded aad_1
# ✓ Loaded aad_1
# ✓ Loaded aad_1
# ✓ Loaded aad_1
# ✓ Loaded aad_1
# ✓ Loaded aad_1
# ✓ Loaded aad_1✓ Loaded aad_1✓ Loaded aad_1
#
#
# ✓ Loaded aad_1
# ✓ Loaded aad_1
# ✓ Loaded aad_1✓ Loaded aad_1
# ✓ Loaded aad_1
#
# ✓ Loaded aad_
# ✓ Loaded yc_4✓ Loaded yc_4
#
# ✓ Loaded yc_4
# ✓ Loaded yc_4
# ✓ Loaded yc_4
# ✓ Loaded yc_4
# ✓ Loaded yc_4
# ✓ Loaded yc_4
# ✓ Loaded yc_4✓ Loaded yc_4
#
# ✓ Loaded yc_4
# ✓ Loaded yc_4
# ✓ Loaded yc_4
# ✓ Loaded yc_4
# ✓ Loaded yc_4
# ✓ Loaded yc_4
# ✓ Loaded yc_4
# ✓ Loaded yc_4✓ Loaded yc_4
# ✓ Loaded yc_4
#
# [8321/8448] ✅ yc_4 | m/z 846.6774
# [8322/8448] ✅ yc_4 | m/z 846.5419
# [8323/8448] ✅ yc_4 | m/z 847.6855
# [8324/8448] ✅ yc_4 | m/z 848.5549
# [8325/8448] ✅ yc_4 | m/z 848.6143
# [8326/8448] ✅ yc_4 | m/z 849.6205
# [8327/8448] ✅ yc_4 | m/z 848.6907
# [8328/8448] ✅ yc_4 | m/z 849.5611
# [8329/8448] ✅ yc_4 | m/z 854.5670
# [8330/8448] ✅ yc_4 | m/z 855.5717
# [8331/8448] ✅ yc_4 | m/z 856.5819
# [8332/8448] ✅ yc_4 | m/z 858.6960
# [8333/8448] ✅ yc_4 | m/z 857.5847
# [8334/8448] ✅ yc_4 | m/z 858.5929
# [8335/8448] ✅ yc_4 | m/z 859.6926
# [8336/8448] ✅ yc_4 | m/z 860.6862
# [8337/8448] ✅ yc_4 | m/z 859.5981
# [8338/8448] ✅ yc_4 | m/z 864.6459
# ✓ Loaded yc_4
# ✓ Loaded yc_4
# ✓ Loaded yc_4
# ✓ Loaded yc_4
# ✓ Loaded yc_4
# ✓ Loaded yc_4
# ✓ Loaded yc_4✓ Loaded yc_4
#
# ✓ Loaded yc_4
# ✓ Loaded yc_4✓ Loaded yc_4
#
# ✓ Loaded yc_4✓ Loaded yc_4
#
# ✓ Loaded yc_4✓ Loaded yc_4
# ✓ Loaded yc_4
# ✓ Loaded yc_4
# ✓ Loaded yc_4
#
# ✓ Loaded yc_4
# ✓ Loaded yc_4
# [8339/8448] ✅ yc_4 | m/z 860.6174
# [8340/8448] ✅ yc_4 | m/z 862.6292
# [8341/8448] ✅ yc_4 | m/z 862.6939
# [8342/8448] ✅ yc_4 | m/z 861.6895
# [8343/8448] ✅ yc_4 | m/z 861.6206
# [8344/8448] ✅ yc_4 | m/z 866.6629
# [8345/8448] ✅ yc_4 | m/z 875.7145
# [8346/8448] ✅ yc_4 | m/z 867.6601
# [8347/8448] ✅ yc_4 | m/z 871.6954
# [8348/8448] ✅ yc_4 | m/z 879.6598
# [8349/8448] ✅ yc_4 | m/z 870.6936
# [8350/8448] ✅ yc_4 | m/z 873.7071
# [8351/8448] ✅ yc_4 | m/z 864.6891
# [8352/8448] ✅ yc_4 | m/z 865.6971
# [8353/8448] ✅ yc_4 | m/z 878.5697
# [8354/8448] ✅ yc_4 | m/z 863.6866
# [8355/8448] ✅ yc_4 | m/z 872.5589
# [8356/8448] ✅ yc_4 | m/z 874.7124
# [8357/8448] ✅ yc_4 | m/z 880.6632
# [8358/8448] ✅ yc_4 | m/z 872.7073
# [8359/8448] ✅ yc_4 | m/z 888.7184
# [8360/8448] ✅ yc_4 | m/z 882.6734
# [8361/8448] ✅ yc_4 | m/z 868.6629
# [8362/8448] ✅ yc_4 | m/z 892.6642
# [8363/8448] ✅ yc_4 | m/z 889.7188
# [8364/8448] ✅ yc_4 | m/z 881.6722
# [8365/8448] ✅ yc_4 | m/z 891.7185
# ✓ Loaded yc_4✓ Loaded yc_4
#
# ✓ Loaded yc_4
# ✓ Loaded yc_4
# ✓ Loaded yc_4
# ✓ Loaded yc_4
# ✓ Loaded yc_4✓ Loaded yc_4
#
# ✓ Loaded yc_4✓ Loaded yc_4✓ Loaded yc_4
#
#
# ✓ Loaded yc_4
# ✓ Loaded yc_4
# ✓ Loaded yc_4
# ✓ Loaded yc_4✓ Loaded yc_4
#
# [8366/8448] ✅ yc_4 | m/z 891.6605
# [8367/8448] ✅ yc_4 | m/z 894.6750
# [8368/8448] ✅ yc_4 | m/z 893.6690
# [8369/8448] ✅ yc_4 | m/z 895.6911
# [8370/8448] ✅ yc_4 | m/z 896.6948
# [8371/8448] ✅ yc_4 | m/z 899.6273
# [8372/8448] ✅ yc_4 | m/z 905.6752
# [8373/8448] ✅ yc_4 | m/z 907.6563
# [8374/8448] ✅ yc_4 | m/z 906.6765
# [8375/8448] ✅ yc_4 | m/z 907.6880
# [8376/8448] ✅ yc_4 | m/z 908.6916
# [8377/8448] ✅ yc_4 | m/z 919.6894
# [8378/8448] ✅ yc_4 | m/z 909.6645
# [8379/8448] ✅ yc_4 | m/z 919.6434
# [8380/8448] ✅ yc_4 | m/z 918.6415
# [8437/8448] ✅ yc_4 | m/z 1001.6937
# [8438/8448] ✅ yc_4 | m/z 1003.7092
# [8439/8448] ✅ yc_4 | m/z 993.6672
# [8440/8448] ✅ yc_4 | m/z 990.6361
# [8441/8448] ✅ yc_4 | m/z 971.6513
# [8442/8448] ✅ yc_4 | m/z 999.6822
# [8443/8448] ✅ yc_4 | m/z 976.6829
# [8444/8448] ✅ yc_4 | m/z 1002.7009
# [8445/8448] ✅ yc_4 | m/z 998.6681
# [8446/8448] ✅ yc_4 | m/z 978.7019
# [8447/8448] ✅ yc_4 | m/z 972.6526
# [8448/8448] ✅ yc_4 | m/z 1017.6669
#
# ================================================================================
# PROCESSING COMPLETE
# ================================================================================
# ✅ Success: 8448
# ⚠️ Failed: 0
# 📊 Total: 8448
# ================================================================================

# %%
"""
Optimized MSI Processing Pipeline with Memory Management
"""

import os
import gc
import psutil
import pandas as pd
import numpy as np
import scanpy as sc
import matplotlib
matplotlib.use('Agg')  # Non-interactive backend to prevent memory leaks
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
from concurrent.futures import ProcessPoolExecutor, as_completed
from functools import partial

# =============================================================================
# CONFIGURATION SECTION
# =============================================================================

class Config:
    """Configuration settings for memory and CPU usage"""
    # Resource limits
    MAX_MEMORY_GB = 160  # Maximum memory usage in GB (adjust based on your system)
    NUM_CORES = 78  # Number of CPU cores to use (None = all available - 1)
    BATCH_SIZE = 156  # Number of plots to process before garbage collection
    
    # Input/Output paths
    MSI_INPUT_FOLDER = "/home/ajarrah/PhD_Thesis/chapter_2/h5ad_data_processed_4lockmasses_filtered_halfbrain/"
    COMMON_MZS_CSV = "/home/ajarrah/PhD_Thesis/chapter_2/csv_data/common_mz_clusters_improved.csv"
    OUTPUT_DIR = "/home/ajarrah/PhD_Thesis/chapter_4/images/lipids/"
    
    # Processing parameters
    SQUARE_SPACING = 60  # µm center-to-center
    MZ_TOLERANCE = 0.01
    VMAX_PERCENTILE = 99.9
    SQUARE_SIZE = 60
    PIXEL_SIZE_UM = 5  # ← target physical pixel size (µm)  

    # Sample IDs
    SAMPLE_IDS = [
        "aad_1", "aad_2", "aad_3", "aad_4",
        "ac_1", "ac_2", "ac_3", "ac_4",
        "yad_1", "yad_2", "yad_3", "yad_4",
        "yc_1", "yc_2", "yc_3", "yc_4"
    ]
    
    MSI_ORDER = [
        'yc_1', 'yc_2', 'yc_3', 'yc_4',
        'yad_1', 'yad_2', 'yad_3', 'yad_4',
        'ac_1', 'ac_2', 'ac_3', 'ac_4',
        'aad_1', 'aad_2', 'aad_3', 'aad_4'
    ]

# =============================================================================
# CUSTOM COLORMAP
# =============================================================================

CUSTOM_CMAP = LinearSegmentedColormap.from_list("custom_scale", [
    (0.0, "#454545"),      # dark gray
    (0.00000001, "#000000"),  # black
    (0.10, "#000080"),     # navy
    (0.15, "#0000FF"),     # blue
    (0.30, "#8000FF"),     # purple-ish
    (0.45, "#FF0000"),     # red
    (0.60, "#FF8000"),     # orange
    (0.75, "#FFFF00"),     # yellow
    (1.0, "#FFFFFF")       # white
])

# =============================================================================
# MEMORY MONITORING UTILITIES
# =============================================================================

def check_memory_usage():
    """Check current memory usage"""
    process = psutil.Process(os.getpid())
    mem_gb = process.memory_info().rss / (1024 ** 3)
    return mem_gb

def force_garbage_collection():
    """Force garbage collection and clear matplotlib cache"""
    plt.close('all')
    gc.collect()

# =============================================================================
# DATA LOADING AND PREPROCESSING
# =============================================================================

def load_sample(sample_id, input_folder):
    """Load a single h5ad sample with error handling"""
    filepath = os.path.join(input_folder, f"halfbrain_{sample_id}_filtered.h5ad")
    try:
        adata = sc.read_h5ad(filepath)
        print(f"✓ Loaded {sample_id}")
        return adata
    except Exception as e:
        print(f"✗ Failed to load {sample_id}: {e}")
        return None

def preprocess_sample(adata, pixel_spacing):
    """Add TIC and spatial coordinates to AnnData object"""
    # Calculate TIC
    tic = adata.X.sum(axis=1)
    if hasattr(tic, "A1"):  # sparse matrix
        tic = tic.A1
    else:
        tic = np.asarray(tic).flatten()
    adata.obs["Processed_TIC"] = tic
    
    # Add spatial coordinates in µm
    spatial = adata.obsm['spatial']
    array_row = spatial[:, 1]
    array_col = spatial[:, 0]
    adata.obs['x_um'] = array_col * pixel_spacing
    adata.obs['y_um'] = array_row * pixel_spacing
    
    return adata

def load_and_preprocess_all_samples(config):
    """Load all samples and preprocess them"""
    print("=" * 80)
    print("LOADING AND PREPROCESSING SAMPLES")
    print("=" * 80)
    
    sample_map = {}
    for sample_id in config.SAMPLE_IDS:
        adata = load_sample(sample_id, config.MSI_INPUT_FOLDER)
        if adata is not None:
            adata = preprocess_sample(adata, config.SQUARE_SPACING)
            sample_map[sample_id] = adata
            
        # Monitor memory
        mem_gb = check_memory_usage()
        if mem_gb > config.MAX_MEMORY_GB * 0.8:
            print(f"⚠️ Memory usage high ({mem_gb:.2f} GB), forcing cleanup...")
            force_garbage_collection()
    
    print(f"\n✓ Loaded {len(sample_map)}/{len(config.SAMPLE_IDS)} samples successfully\n")
    return sample_map

def load_common_mz_data(csv_path, msi_order):
    """Load and pivot common m/z data"""
    print("Loading common m/z data...")
    common_mz_df = pd.read_csv(csv_path)
    
    # Create sample_id column
    common_mz_df['sample_id'] = (
        common_mz_df['group'].str.lower() + '_' + 
        common_mz_df['sample'].astype(str)
    )
    
    # Pivot and sort
    pivot_df = common_mz_df.pivot(
        index='sample_id', 
        columns='common_group_name', 
        values='mzs'
    )
    pivot_df_sorted = pivot_df.loc[pivot_df.index.intersection(msi_order)]
    pivot_df_sorted = pivot_df_sorted.loc[msi_order]
    
    print(f"✓ Loaded m/z data for {len(pivot_df_sorted)} samples\n")
    return pivot_df_sorted

# =============================================================================
# PLOTTING FUNCTION
# =============================================================================

def msi_plot_producer(
    adata,
    mz_val,
    sample_name,
    output_dir,
    tol=0.01,
    vmax_percentile=99.8,
    square_size=60,
    cmap=CUSTOM_CMAP,
    pixel_size_um=5,                 # ← target physical pixel size (µm)
    show_colorbar=False,
    show_axis=False,
    show_title=False,
    background_color="#00BF00"
):
    """
    Plot TIC-normalized intensity for one m/z and one sample
    with automatic DPI and figsize calculation based on 5 µm per pixel.
    """
    try:
        # Extract m/z index
        mz_axis = adata.var_names.astype(float).values
        mz_diff = np.abs(mz_axis - mz_val)
        if np.min(mz_diff) > tol:
            return False, f"m/z {mz_val} not found within tolerance {tol}"
        mz_index = np.argmin(mz_diff)

        # Extract intensities
        intensities = (
            adata.X[:, mz_index].toarray().flatten()
            if hasattr(adata.X, "toarray")
            else adata.X[:, mz_index]
        )

        # Extract coordinates & TIC
        x = adata.obs["x_um"].values
        y = adata.obs["y_um"].values
        tic = adata.obs["Processed_TIC"].values

        # Normalize by TIC
        normalized_intensities = (intensities / tic) * 100
        normalized_intensities = np.nan_to_num(
            normalized_intensities, nan=0.0, posinf=0.0, neginf=0.0
        )

        # Build grid
        x_unique = np.unique(x)
        y_unique = np.unique(y)
        x_size = len(x_unique)
        y_size = len(y_unique)
        grid = np.full((y_size, x_size), np.nan)
        for xi, yi, val in zip(x, y, normalized_intensities):
            x_idx = np.where(x_unique == xi)[0][0]
            y_idx = np.where(y_unique == yi)[0][0]
            grid[y_idx, x_idx] = val

        # Color scaling
        vmin_value = np.nanmin(normalized_intensities)
        vmax_value = np.percentile(normalized_intensities, vmax_percentile)

        # === AUTO FIGURE SCALING (PHYSICAL UNITS) ===
        x_min, x_max = x.min() , x.max() + 10 * square_size
        y_min, y_max = y.min() , y.max() + 10 * square_size

        width_um = x_max - x_min
        height_um = y_max - y_min

        # Number of pixels (rounded)
        width_px = int(np.round(width_um / pixel_size_um))
        height_px = int(np.round(height_um / pixel_size_um))

        # Recalculate exact physical extent
        width_um = width_px * pixel_size_um
        height_um = height_px * pixel_size_um

        # DPI derived from pixel size (1 inch = 25.4 mm = 25,400 µm)
        dpi = 25.4 / (pixel_size_um )  # convert µm → mm → inches
        # Equivalent: dpi = 25400 / pixel_size_um

        # Figure size in inches
        fig_width_in = width_px / dpi
        fig_height_in = height_px / dpi

        # Log info
        print(
            f"🖼️ {sample_name} | m/z {mz_val:.4f} → {width_px}×{height_px} px "
            f"({pixel_size_um} µm/px @ {dpi:.0f} DPI)"
        )

        # Create figure
        extent = [x_min, x_max, y_min, y_max]
        fig, ax = plt.subplots(figsize=(fig_width_in, fig_height_in), dpi=dpi)
        fig.patch.set_facecolor(background_color)

        # Plot image
        im = ax.imshow(
            grid,
            cmap=cmap,
            origin="lower",
            extent=extent,
            vmin=vmin_value,
            vmax=vmax_value,
            interpolation="none",
        )

        # Adjust axes
        ax.invert_xaxis()
        ax.set_aspect("equal")
        if show_axis:
            ax.set_xlabel("x (µm)")
            ax.set_ylabel("y (µm)")
        else:
            ax.axis("off")
        if show_title:
            ax.set_title(f"m/z {mz_val:.4f} normalized intensity")
        if show_colorbar:
            cbar = fig.colorbar(im, ax=ax)
            cbar.set_label("Normalized intensity (TIC%)")

        # Save image
        sample_dir = os.path.join(output_dir, sample_name)
        os.makedirs(sample_dir, exist_ok=True)
        filename = f"{mz_val:.4f}|{sample_name}|{vmin_value:.2f}|{vmax_value:.2f}.png"
        filepath = os.path.join(sample_dir, filename)
        fig.savefig(filepath, bbox_inches="tight", transparent=False)

        # Clean up
        plt.close(fig)
        del fig, ax, im, grid, normalized_intensities

        return True, f"✅ {sample_name} | m/z {mz_val:.4f}"

    except Exception as e:
        plt.close('all')
        return False, f"⚠️ Failed {sample_name} | m/z {mz_val:.4f}: {e}"




# =============================================================================
# PARALLEL PROCESSING WITH SERIALIZATION
# =============================================================================

def process_mz_wrapper(args):
    """
    Wrapper function for multiprocessing.
    Each process loads its own copy of the data to avoid serialization issues.
    """
    sample_id, mz_val, config = args
    
    try:
        # Load sample in this process
        adata = load_sample(sample_id, config.MSI_INPUT_FOLDER)
        if adata is None:
            return False, f"⚠️ Failed to load {sample_id}"
        
        adata = preprocess_sample(adata, config.SQUARE_SPACING)
        
        # Generate plot
        success, msg = msi_plot_producer(
            adata=adata,
            mz_val=mz_val,
            sample_name=sample_id,
            output_dir=config.OUTPUT_DIR,
            tol=config.MZ_TOLERANCE,
            vmax_percentile=config.VMAX_PERCENTILE,
            square_size=config.SQUARE_SIZE,
            cmap=CUSTOM_CMAP,
            pixel_size_um=config.PIXEL_SIZE_UM,
            show_colorbar=False,
            show_axis=False,
            show_title=False,
            background_color="#00BF00"
        )
        
        # Clean up
        del adata
        force_garbage_collection()
        
        return success, msg
        
    except Exception as e:
        return False, f"⚠️ Error {sample_id} | m/z {mz_val:.4f}: {e}"

# =============================================================================
# MAIN PROCESSING PIPELINE
# =============================================================================

def main():
    """Main processing pipeline"""
    # Initialize configuration
    config = Config()
    
    # Set number of cores
    if config.NUM_CORES is None:
        max_workers = max(1, os.cpu_count() - 1)
    else:
        max_workers = min(config.NUM_CORES, os.cpu_count())
    
    print("=" * 80)
    print("MSI PROCESSING PIPELINE")
    print("=" * 80)
    print(f"Max Memory: {config.MAX_MEMORY_GB} GB")
    print(f"CPU Cores: {max_workers}")
    print(f"Batch Size: {config.BATCH_SIZE}")
    print("=" * 80 + "\n")
    
    # Load common m/z data
    pivot_df = load_common_mz_data(config.COMMON_MZS_CSV, config.MSI_ORDER)
    
    # Prepare all tasks
    tasks = []
    for sample_id in config.SAMPLE_IDS:
        if sample_id not in pivot_df.index:
            print(f"⚠️ Sample '{sample_id}' not in pivot table — skipping.")
            continue
        
        mz_values = pivot_df.loc[sample_id].values.astype(float)
        mz_values = mz_values[~np.isnan(mz_values)]
        
        for mz_val in mz_values:
            tasks.append((sample_id, mz_val, config))
    
    print(f"Total tasks to process: {len(tasks)}\n")
    print("=" * 80)
    print("PROCESSING")
    print("=" * 80 + "\n")
    
    # Process in batches to manage memory
    success_count = 0
    fail_count = 0
    
    with ProcessPoolExecutor(max_workers=max_workers) as executor:
        # Submit all tasks
        futures = [executor.submit(process_mz_wrapper, task) for task in tasks]
        
        # Process results
        for i, future in enumerate(as_completed(futures), 1):
            success, msg = future.result()
            if success:
                success_count += 1
            else:
                fail_count += 1
            
            print(f"[{i}/{len(tasks)}] {msg}")
            
            # Periodic garbage collection
            if i % config.BATCH_SIZE == 0:
                force_garbage_collection()
                mem_gb = check_memory_usage()
                print(f"  └─ Memory usage: {mem_gb:.2f} GB")
    
    # Final cleanup
    force_garbage_collection()
    
    print("\n" + "=" * 80)
    print("PROCESSING COMPLETE")
    print("=" * 80)
    print(f"✅ Success: {success_count}")
    print(f"⚠️ Failed: {fail_count}")
    print(f"📊 Total: {len(tasks)}")
    print("=" * 80)

if __name__ == "__main__":
    main()
# Out:
# ================================================================================
# [330/8448] ✅ aad_1 | m/z 796.6211
# [331/8448] ✅ aad_1 | m/z 798.5393
# [332/8448] ✅ aad_1 | m/z 799.5461
# [333/8448] ✅ aad_1 | m/z 800.5501
# [334/8448] ✅ aad_1 | m/z 803.6343
# [335/8448] ✅ aad_1 | m/z 801.5555
# [336/8448] ✅ aad_1 | m/z 813.6126
# [337/8448] ✅ aad_1 | m/z 800.6142
# [338/8448] ✅ aad_1 | m/z 818.6482
# [339/8448] ✅ aad_1 | m/z 801.6197
# [340/8448] ✅ aad_1 | m/z 817.6992
# [341/8448] ✅ aad_1 | m/z 804.6394
# [342/8448] ✅ aad_1 | m/z 819.6599
# [343/8448] ✅ aad_1 | m/z 821.5884
# [344/8448] ✅ aad_1 | m/z 806.5688
# [345/8448] ✅ aad_1 | m/z 810.5997
# [346/8448] ✅ aad_1 | m/z 820.5866
# [347/8448] ✅ aad_1 | m/z 802.6303
#
# 🖼️ aad_1 | m/z 844.5255 → 1044×1176 px (5 µm/px @ 5 DPI)✓ Loaded aad_1
# ✓ Loaded aad_1
# ✓ Loaded aad_1
# ✓ Loaded aad_1✓ Loaded aad_1
#
#
# ✓ Loaded aad_1
# ✓ Loaded aad_1✓ Loaded aad_1🖼️ aad_1 | m/z 845.5311 → 1044×1176 px (5 µm/px @ 5 DPI)
# 🖼️ aad_1 | m/z 844.6775 → 1044×1176 px (5 µm/px @ 5 DPI)
#
#
# ✓ Loaded aad_1✓ Loaded aad_1
#
# ✓ Loaded aad_1
# 🖼️ aad_1 | m/z 845.6748 → 1044×1176 px (5 µm/px @ 5 DPI)✓ Loaded aad_1
# 🖼️ aad_1 | m/z 843.6645 → 1044×1176 px (5 µm/px @ 5 DPI)✓ Loaded aad_1✓ Loaded aad_1
# ✓ Loaded aad_1
#
# ✓ Loaded aad_1
#
#
# ✓ Loaded aad_1
# ✓ Loaded aad_1
# ✓ Loaded aad_1
# 🖼️ aad_1 | m/z 846.5379 → 1044×1176 px (5 µm/px @ 5 DPI)
# ✓ Loaded aad_1
# ✓ Loaded aad_1
# ✓ Loaded aad_1✓ Loaded aad_1✓ Loaded aad_1✓ Loaded aad_1
#
#
# ✓ Loaded aad_1
# ✓ Loaded aad_1
#
#
# 🖼️ aad_1 | m/z 848.5550 → 1044×1176 px (5 µm/px @ 5 DPI)✓ Loaded aad_1✓ Loaded aad_1✓ Loaded aad_1
# ✓ Loaded aad_1✓ Loaded aad_1
# 🖼️ aad_1 | m/z 846.6776 → 1044×1176 px (5 µm/px @ 5 DPI)🖼️ aad_1 | m/z 848.6187 → 1044×1176 px (5 µm/px @ 5 DPI)
#
#
# 🖼️ aad_1 | m/z 847.6857 → 1044×1176 px (5 µm/px @ 5 DPI)🖼️ aad_1 | m/z 848.6908 → 1044×1176 px (5 µm/px @ 5 DPI)
#
#
# 🖼️ aad_1 | m/z 854.5671 → 1044×1176 px (5 µm/px @ 5 DPI)✓ Loaded aad_1
# ✓ Loaded aad_1🖼️ aad_1 | m/z 849.6207 → 1044×1176 px (5 µm/px @ 5 DPI)
#
# ✓ Loaded aad_1🖼️ aad_1 | m/z 849.5613 → 1044×1176 px (5 µm/px @ 5 DPI)
#
# ✓ Loaded aad_1
# ✓ Loaded aad_1
# ✓ Loaded aad_1
#
#
# ✓ Loaded aad_1
#
# ✓ Loaded aad_1🖼️ aad_1 | m/z 856.5821 → 1044×1176 px (5 µm/px @ 5 DPI)
# 🖼️ aad_1 | m/z 855.5719 → 1044×1176 px (5 µm/px @ 5 DPI)
# ✓ Loaded aad_1✓ Loaded aad_1🖼️ aad_1 | m/z 858.5931 → 1044×1176 px (5 µm/px @ 5 DPI)
#
#
# 🖼️ aad_1 | m/z 859.5983 → 1044×1176 px (5 µm/px @ 5 DPI)
# ✓ Loaded aad_1✓ Loaded aad_1🖼️ aad_1 | m/z 857.5849 → 1044×1176 px (5 µm/px @ 5 DPI)
# 🖼️ aad_1 | m/z 860.6133 → 1044×1176 px (5 µm/px @ 5 DPI)🖼️ aad_1 | m/z 859.6928 → 1044×1176 px (5 µm/px @ 5 DPI)✓ Loaded aad_1🖼️ aad_1 | m/z 860.6864 → 1044×1176 px (5 µm/px @ 5 DPI)✓ Loaded aad_1
#
#
#
#
#
#
# 🖼️ aad_1 | m/z 861.6208 → 1044×1176 px (5 µm/px @ 5 DPI)
# ✓ Loaded aad_1🖼️ aad_1 | m/z 858.6962 → 1044×1176 px (5 µm/px @ 5 DPI)✓ Loaded aad_1✓ Loaded aad_1🖼️ aad_1 | m/z 861.6897 → 1044×1176 px (5 µm/px @ 5 DPI)
# ✓ Loaded aad_1✓ Loaded aad_1
#
# ✓ Loaded aad_1
#
#
# 🖼️ aad_1 | m/z 863.6868 → 1044×1176 px (5 µm/px @ 5 DPI)
# ✓ Loaded aad_1
# 🖼️ aad_1 | m/z 866.6631 → 1044×1176 px (5 µm/px @ 5 DPI)
# 🖼️ aad_1 | m/z 862.6295 → 1044×1176 px (5 µm/px @ 5 DPI)🖼️ aad_1 | m/z 862.6985 → 1044×1176 px (5 µm/px @ 5 DPI)🖼️ aad_1 | m/z 865.6972 → 1044×1176 px (5 µm/px @ 5 DPI)✓ Loaded aad_1✓ Loaded aad_1🖼️ aad_1 | m/z 864.6893 → 1044×1176 px (5 µm/px @ 5 DPI)🖼️ aad_1 | m/z 864.6461 → 1044×1176 px (5 µm/px @ 5 DPI)✓ Loaded aad_1
#
#
# 🖼️ aad_1 | m/z 870.6938 → 1044×1176 px (5 µm/px @ 5 DPI)
#
#
#
#
# ✓ Loaded aad_1🖼️ aad_1 | m/z 872.5592 → 1044×1176 px (5 µm/px @ 5 DPI)🖼️ aad_1 | m/z 871.6914 → 1044×1176 px (5 µm/px @ 5 DPI)
#
#
# 🖼️ aad_1 | m/z 868.6631 → 1044×1176 px (5 µm/px @ 5 DPI)
#
# 🖼️ aad_1 | m/z 867.6604 → 1044×1176 px (5 µm/px @ 5 DPI)✓ Loaded aad_1
#
#
# 🖼️ aad_1 | m/z 873.7073 → 1044×1176 px (5 µm/px @ 5 DPI)🖼️ aad_1 | m/z 874.7083 → 1044×1176 px (5 µm/px @ 5 DPI)
#
# 🖼️ aad_1 | m/z 879.6601 → 1044×1176 px (5 µm/px @ 5 DPI)
# 🖼️ aad_1 | m/z 872.7031 → 1044×1176 px (5 µm/px @ 5 DPI)
# ✓ Loaded aad_1🖼️ aad_1 | m/z 875.7148 → 1044×1176 px (5 µm/px @ 5 DPI)🖼️ aad_1 | m/z 880.6635 → 1044×1176 px (5 µm/px @ 5 DPI)🖼️ aad_1 | m/z 881.6724 → 1044×1176 px (5 µm/px @ 5 DPI)
#
# 🖼️ aad_1 | m/z 882.6738 → 1044×1176 px (5 µm/px @ 5 DPI)
#
#
#
# 🖼️ aad_1 | m/z 878.5700 → 1044×1176 px (5 µm/px @ 5 DPI)🖼️ aad_1 | m/z 889.7191 → 1044×1176 px (5 µm/px @ 5 DPI)
# 🖼️ aad_1 | m/z 888.7187 → 1044×1176 px (5 µm/px @ 5 DPI)✓ Loaded aad_1
#
#
#
# 🖼️ aad_1 | m/z 892.6645 → 1044×1176 px (5 µm/px @ 5 DPI)✓ Loaded aad_1✓ Loaded aad_1
# [348/8448] ✅ aad_1 | m/z 824.5556
# [349/8448] ✅ aad_1 | m/z 805.5572
# [350/8448] ✅ aad_1 | m/z 816.6981
# [351/8448] ✅ aad_1 | m/z 829.5552
# [352/8448] ✅ aad_1 | m/z 824.6175
# [353/8448] ✅ aad_1 | m/z 813.6859
# [354/8448] ✅ aad_1 | m/z 805.6781
# [355/8448] ✅ aad_1 | m/z 808.5837
# [356/8448] ✅ aad_1 | m/z 832.5845
# [357/8448] ✅ aad_1 | m/z 809.5871
# [358/8448] ✅ aad_1 | m/z 831.5694
# [359/8448] ✅ aad_1 | m/z 817.6501
# [360/8448] ✅ aad_1 | m/z 816.6491
# [361/8448] ✅ aad_1 | m/z 822.5995
# [362/8448] ✅ aad_1 | m/z 811.6055
# [363/8448] ✅ aad_1 | m/z 820.6605
# [364/8448] ✅ aad_1 | m/z 836.5446
# [365/8448] ✅ aad_1 | m/z 815.6370
# [366/8448] ✅ aad_1 | m/z 815.6941
# [367/8448] ✅ aad_1 | m/z 814.6873
# [368/8448] ✅ aad_1 | m/z 830.6634
# [369/8448] ✅ aad_1 | m/z 834.6018
# [370/8448] ✅ aad_1 | m/z 821.6664
# [371/8448] ✅ aad_1 | m/z 821.5308
# [372/8448] ✅ aad_1 | m/z 831.6650
# [373/8448] ✅ aad_1 | m/z 833.5884
# [374/8448] ✅ aad_1 | m/z 820.5251
# [375/8448] ✅ aad_1 | m/z 826.5741
# [376/8448] ✅ aad_1 | m/z 830.5638
# [377/8448] ✅ aad_1 | m/z 826.6237
# [378/8448] ✅ aad_1 | m/z 827.5749
# [379/8448] ✅ aad_1 | m/z 839.5574
# [380/8448] ✅ aad_1 | m/z 834.6686
# [381/8448] ✅ aad_1 | m/z 825.6200
# [382/8448] ✅ aad_1 | m/z 828.5520
# [383/8448] ✅ aad_1 | m/z 835.6039
# [384/8448] ✅ aad_1 | m/z 831.7024
# [385/8448] ✅ aad_1 | m/z 836.6115
# [386/8448] ✅ aad_1 | m/z 835.6708
# [387/8448] ✅ aad_1 | m/z 837.6161
# [388/8448] ✅ aad_1 | m/z 838.5589
# [389/8448] ✅ aad_1 | m/z 837.6705
# [390/8448] ✅ aad_1 | m/z 838.6302
#
# 🖼️ aad_1 | m/z 891.7187 → 1044×1176 px (5 µm/px @ 5 DPI)🖼️ aad_1 | m/z 891.6608 → 1044×1176 px (5 µm/px @ 5 DPI)
#
# 🖼️ aad_1 | m/z 893.6738 → 1044×1176 px (5 µm/px @ 5 DPI)
# ✓ Loaded aad_1
#
# 🖼️ aad_1 | m/z 894.6798 → 1044×1176 px (5 µm/px @ 5 DPI)🖼️ aad_1 | m/z 905.6755 → 1044×1176 px (5 µm/px @ 5 DPI)
#
# ✓ Loaded aad_1🖼️ aad_1 | m/z 896.6951 → 1044×1176 px (5 µm/px @ 5 DPI)🖼️ aad_1 | m/z 895.6913 → 1044×1176 px (5 µm/px @ 5 DPI)✓ Loaded aad_1
# 🖼️ aad_1 | m/z 899.6276 → 1044×1176 px (5 µm/px @ 5 DPI)
# ✓ Loaded aad_1
# 🖼️ aad_1 | m/z 906.6769 → 1044×1176 px (5 µm/px @ 5 DPI)
# ✓ Loaded aad_1
#
# 🖼️ aad_1 | m/z 907.6566 → 1044×1176 px (5 µm/px @ 5 DPI)
#
# 🖼️ aad_1 | m/z 909.6693 → 1044×1176 px (5 µm/px @ 5 DPI)🖼️ aad_1 | m/z 908.6601 → 1044×1176 px (5 µm/px @ 5 DPI)🖼️ aad_1 | m/z 908.6919 → 1044×1176 px (5 µm/px @ 5 DPI)
# 🖼️ aad_1 | m/z 907.6884 → 1044×1176 px (5 µm/px @ 5 DPI)
#
#
#
# 🖼️ aad_1 | m/z 914.6726 → 1044×1176 px (5 µm/px @ 5 DPI)
# 🖼️ aad_1 | m/z 915.6199 → 1044×1176 px (5 µm/px @ 5 DPI)
# 🖼️ aad_1 | m/z 917.6365 → 1044×1176 px (5 µm/px @ 5 DPI)
# 🖼️ aad_1 | m/z 919.6897 → 1044×1176 px (5 µm/px @ 5 DPI)🖼️ aad_1 | m/z 918.6418 → 1044×1176 px (5 µm/px @ 5 DPI)🖼️ aad_1 | m/z 919.6437 → 1044×1176 px (5 µm/px @ 5 DPI)
#
#
# 🖼️ aad_1 | m/z 921.6923 → 1044×1176 px (5 µm/px @ 5 DPI)
# 🖼️ aad_1 | m/z 920.6882 → 1044×1176 px (5 µm/px @ 5 DPI)🖼️ aad_1 | m/z 921.6370 → 1044×1176 px (5 µm/px @ 5 DPI)
#
# 🖼️ aad_1 | m/z 922.6375 → 1044×1176 px (5 µm/px @ 5 DPI)
# ✓ Loaded aad_1
# ✓ Loaded aad_1✓ Loaded aad_1
#
# ✓ Loaded aad_1
# 🖼️ aad_1 | m/z 922.6975 → 1044×1176 px (5 µm/px @ 5 DPI)✓ Loaded aad_1✓ Loaded aad_1
#
#
# ✓ Loaded aad_1
# ✓ Loaded aad_1
# 🖼️ aad_1 | m/z 923.6483 → 1044×1176 px (5 µm/px @ 5 DPI)
# ✓ Loaded aad_1✓ Loaded aad_1
#
# 🖼️ aad_1 | m/z 926.6552 → 1044×1176 px (5 µm/px @ 5 DPI)
# 🖼️ aad_1 | m/z 925.6549 → 1044×1176 px (5 µm/px @ 5 DPI)[391/8448] ✅ aad_1 | m/z 839.6371
# [392/8448] ✅ aad_1 | m/z 840.6411
# [393/8448] ✅ aad_1 | m/z 842.6653
# [394/8448] ✅ aad_1 | m/z 840.5528
# ...
# ✓ Loaded aad_4
# ✓ Loaded aad_4✓ Loaded aad_4✓ Loaded aad_4🖼️ aad_4 | m/z 943.6515 → 1152×1092 px (5 µm/px @ 5 DPI)
#
#
# ✓ Loaded aad_4🖼️ aad_4 | m/z 946.6713 → 1152×1092 px (5 µm/px @ 5 DPI)
#
#
# ✓ Loaded aad_4
# 🖼️ aad_4 | m/z 947.6469 → 1152×1092 px (5 µm/px @ 5 DPI)🖼️ aad_4 | m/z 945.6684 → 1152×1092 px (5 µm/px @ 5 DPI)
#
# ✓ Loaded aad_4✓ Loaded aad_4
#
# ✓ Loaded aad_4
# ✓ Loaded aad_4✓ Loaded aad_4✓ Loaded aad_4✓ Loaded aad_4✓ Loaded aad_4✓ Loaded aad_4
# ✓ Loaded aad_4
#
#
# 🖼️ aad_4 | m/z 948.6519 → 1152×1092 px (5 µm/px @ 5 DPI)
#
#
# ✓ Loaded aad_4✓ Loaded aad_4
# ✓ Loaded aad_4🖼️ aad_4 | m/z 949.6676 → 1152×1092 px (5 µm/px @ 5 DPI)
# 🖼️ aad_4 | m/z 950.6701 → 1152×1092 px (5 µm/px @ 5 DPI)
# ✓ Loaded aad_4
# ✓ Loaded aad_4
#
#
#
# 🖼️ aad_4 | m/z 951.6783 → 1152×1092 px (5 µm/px @ 5 DPI)✓ Loaded aad_4
# ✓ Loaded aad_4
# 🖼️ aad_4 | m/z 953.6838 → 1152×1092 px (5 µm/px @ 5 DPI)🖼️ aad_4 | m/z 961.7046 → 1152×1092 px (5 µm/px @ 5 DPI)
# ✓ Loaded aad_4
# 🖼️ aad_4 | m/z 954.6857 → 1152×1092 px (5 µm/px @ 5 DPI)
#
# ✓ Loaded aad_4✓ Loaded aad_4✓ Loaded aad_4✓ Loaded aad_4
# 🖼️ aad_4 | m/z 952.6828 → 1152×1092 px (5 µm/px @ 5 DPI)🖼️ aad_4 | m/z 957.6690 → 1152×1092 px (5 µm/px @ 5 DPI)
#
#
# ✓ Loaded aad_4✓ Loaded aad_4
#
# ✓ Loaded aad_4
# ✓ Loaded aad_4
#
#
# 🖼️ aad_4 | m/z 965.6364 → 1152×1092 px (5 µm/px @ 5 DPI)✓ Loaded aad_4🖼️ aad_4 | m/z 962.7053 → 1152×1092 px (5 µm/px @ 5 DPI)✓ Loaded aad_4
# ✓ Loaded aad_4
#
#
#
#
# 🖼️ aad_4 | m/z 971.6518 → 1152×1092 px (5 µm/px @ 5 DPI)🖼️ aad_4 | m/z 966.6412 → 1152×1092 px (5 µm/px @ 5 DPI)
# ✓ Loaded aad_4✓ Loaded aad_4
# ✓ Loaded aad_4
# 🖼️ aad_4 | m/z 972.6872 → 1152×1092 px (5 µm/px @ 5 DPI)
#
# ✓ Loaded aad_4
# ✓ Loaded aad_4🖼️ aad_4 | m/z 969.6716 → 1152×1092 px (5 µm/px @ 5 DPI)🖼️ aad_4 | m/z 967.6519 → 1152×1092 px (5 µm/px @ 5 DPI)
# 🖼️ aad_4 | m/z 974.6687 → 1152×1092 px (5 µm/px @ 5 DPI)🖼️ aad_4 | m/z 971.6858 → 1152×1092 px (5 µm/px @ 5 DPI)✓ Loaded aad_4✓ Loaded ac_1✓ Loaded ac_1
# 🖼️ aad_4 | m/z 972.6532 → 1152×1092 px (5 µm/px @ 5 DPI)
#
#
# ✓ Loaded ac_1✓ Loaded ac_1
#
#
# ✓ Loaded ac_1🖼️ aad_4 | m/z 973.6653 → 1152×1092 px (5 µm/px @ 5 DPI)
#
#
#
# ✓ Loaded ac_1🖼️ aad_4 | m/z 975.6780 → 1152×1092 px (5 µm/px @ 5 DPI)
# 🖼️ aad_4 | m/z 976.6835 → 1152×1092 px (5 µm/px @ 5 DPI)
# 🖼️ aad_4 | m/z 978.7025 → 1152×1092 px (5 µm/px @ 5 DPI)🖼️ aad_4 | m/z 977.6998 → 1152×1092 px (5 µm/px @ 5 DPI)
# ✓ Loaded ac_1
#
#
# ✓ Loaded ac_1
#
# ✓ Loaded ac_1
#
# ✓ Loaded ac_1🖼️ aad_4 | m/z 979.7062 → 1152×1092 px (5 µm/px @ 5 DPI)
#
# 🖼️ aad_4 | m/z 979.6523 → 1152×1092 px (5 µm/px @ 5 DPI)
# ✓ Loaded ac_1✓ Loaded ac_1✓ Loaded ac_1
#
#
# ✓ Loaded ac_1🖼️ aad_4 | m/z 989.6318 → 1152×1092 px (5 µm/px @ 5 DPI)🖼️ aad_4 | m/z 983.6871 → 1152×1092 px (5 µm/px @ 5 DPI)
#
#
# 🖼️ aad_4 | m/z 984.6910 → 1152×1092 px (5 µm/px @ 5 DPI)🖼️ aad_4 | m/z 980.7109 → 1152×1092 px (5 µm/px @ 5 DPI)
# ✓ Loaded ac_1✓ Loaded ac_1
# 🖼️ aad_4 | m/z 996.6534 → 1152×1092 px (5 µm/px @ 5 DPI)
#
# 🖼️ aad_4 | m/z 998.6688 → 1152×1092 px (5 µm/px @ 5 DPI)🖼️ aad_4 | m/z 991.6478 → 1152×1092 px (5 µm/px @ 5 DPI)
# 🖼️ aad_4 | m/z 994.6721 → 1152×1092 px (5 µm/px @ 5 DPI)
#
# 🖼️ aad_4 | m/z 1000.6882 → 1152×1092 px (5 µm/px @ 5 DPI)🖼️ aad_4 | m/z 990.6368 → 1152×1092 px (5 µm/px @ 5 DPI)🖼️ aad_4 | m/z 995.6523 → 1152×1092 px (5 µm/px @ 5 DPI)🖼️ aad_4 | m/z 1017.6676 → 1152×1092 px (5 µm/px @ 5 DPI)
#
#
#
#
# 🖼️ aad_4 | m/z 993.6680 → 1152×1092 px (5 µm/px @ 5 DPI)
# 🖼️ aad_4 | m/z 999.6829 → 1152×1092 px (5 µm/px @ 5 DPI)
# 🖼️ aad_4 | m/z 1002.7016 → 1152×1092 px (5 µm/px @ 5 DPI)
# ✓ Loaded ac_1🖼️ aad_4 | m/z 1001.6944 → 1152×1092 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 340.2354 → 1032×1140 px (5 µm/px @ 5 DPI)
#
# 🖼️ aad_4 | m/z 1003.7048 → 1152×1092 px (5 µm/px @ 5 DPI)✓ Loaded ac_1
# ✓ Loaded ac_1
# 🖼️ aad_4 | m/z 1088.8262 → 1152×1092 px (5 µm/px @ 5 DPI)
#
# ✓ Loaded ac_1
# 🖼️ ac_1 | m/z 339.2315 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 353.2467 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 351.2319 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 337.1939 → 1032×1140 px (5 µm/px @ 5 DPI)✓ Loaded ac_1✓ Loaded ac_1🖼️ ac_1 | m/z 326.1996 → 1032×1140 px (5 µm/px @ 5 DPI)
# ✓ Loaded ac_1
#
#
# 🖼️ ac_1 | m/z 341.2457 → 1032×1140 px (5 µm/px @ 5 DPI)
#
#
#
# 🖼️ ac_1 | m/z 351.1722 → 1032×1140 px (5 µm/px @ 5 DPI)
# 🖼️ ac_1 | m/z 355.3724 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 352.2361 → 1032×1140 px (5 µm/px @ 5 DPI)
# 🖼️ ac_1 | m/z 354.2548 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 355.8187 → 1032×1140 px (5 µm/px @ 5 DPI)
#
#
# 🖼️ ac_1 | m/z 355.2623 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 357.2680 → 1032×1140 px (5 µm/px @ 5 DPI)
#
#
# 🖼️ ac_1 | m/z 356.2655 → 1032×1140 px (5 µm/px @ 5 DPI)
#
# 🖼️ ac_1 | m/z 357.1591 → 1032×1140 px (5 µm/px @ 5 DPI)
# 🖼️ ac_1 | m/z 358.2715 → 1032×1140 px (5 µm/px @ 5 DPI)
# 🖼️ ac_1 | m/z 363.1717 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 360.1393 → 1032×1140 px (5 µm/px @ 5 DPI)
#
# 🖼️ ac_1 | m/z 365.1874 → 1032×1140 px (5 µm/px @ 5 DPI)
# 🖼️ ac_1 | m/z 367.2619 → 1032×1140 px (5 µm/px @ 5 DPI)
# 🖼️ ac_1 | m/z 368.2659 → 1032×1140 px (5 µm/px @ 5 DPI)
# ✓ Loaded ac_1
# 🖼️ ac_1 | m/z 364.1754 → 1032×1140 px (5 µm/px @ 5 DPI)
# 🖼️ ac_1 | m/z 370.2451 → 1032×1140 px (5 µm/px @ 5 DPI)
# ✓ Loaded ac_1✓ Loaded ac_1
# ✓ Loaded ac_1
#
# ✓ Loaded ac_1
# ✓ Loaded ac_1
# 🖼️ ac_1 | m/z 371.2572 → 1032×1140 px (5 µm/px @ 5 DPI)
# ✓ Loaded ac_1🖼️ ac_1 | m/z 372.2609 → 1032×1140 px (5 µm/px @ 5 DPI)
#
# 🖼️ ac_1 | m/z 370.2803 → 1032×1140 px (5 µm/px @ 5 DPI)
# ✓ Loaded ac_1
# ✓ Loaded ac_1✓ Loaded ac_1✓ Loaded ac_1
#
#
# ✓ Loaded ac_1🖼️ ac_1 | m/z 373.1535 → 1032×1140 px (5 µm/px @ 5 DPI)
#
# ✓ Loaded ac_1✓ Loaded ac_1
#
# 🖼️ ac_1 | m/z 379.1662 → 1032×1140 px (5 µm/px @ 5 DPI)✓ Loaded ac_1
# ✓ Loaded ac_1
#
# ✓ Loaded ac_1
# 🖼️ ac_1 | m/z 380.1741 → 1032×1140 px (5 µm/px @ 5 DPI)
# 🖼️ ac_1 | m/z 382.1867 → 1032×1140 px (5 µm/px @ 5 DPI)
# ✓ Loaded ac_1🖼️ ac_1 | m/z 381.1829 → 1032×1140 px (5 µm/px @ 5 DPI)✓ Loaded ac_1
#
# ✓ Loaded ac_1🖼️ ac_1 | m/z 383.2564 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 384.2022 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 383.1970 → 1032×1140 px (5 µm/px @ 5 DPI)
#
#
#
#
# ✓ Loaded ac_1✓ Loaded ac_1✓ Loaded ac_1
# 🖼️ ac_1 | m/z 385.2718 → 1032×1140 px (5 µm/px @ 5 DPI)
#
# ✓ Loaded ac_1✓ Loaded ac_1✓ Loaded ac_1
# 🖼️ ac_1 | m/z 385.2140 → 1032×1140 px (5 µm/px @ 5 DPI)✓ Loaded ac_1
# ✓ Loaded ac_1
# 🖼️ ac_1 | m/z 386.2169 → 1032×1140 px (5 µm/px @ 5 DPI)
#
# ✓ Loaded ac_1✓ Loaded ac_1
#
#
#
#
# ✓ Loaded ac_1✓ Loaded ac_1
#
# ✓ Loaded ac_1
# 🖼️ ac_1 | m/z 386.2439 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 387.2514 → 1032×1140 px (5 µm/px @ 5 DPI)✓ Loaded ac_1
# ✓ Loaded ac_1
#
#
# ✓ Loaded ac_1✓ Loaded ac_1✓ Loaded ac_1
#
#
# ✓ Loaded ac_1✓ Loaded ac_1✓ Loaded ac_1
#
# ✓ Loaded ac_1✓ Loaded ac_1
# 🖼️ ac_1 | m/z 388.2557 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 397.1776 → 1032×1140 px (5 µm/px @ 5 DPI)✓ Loaded ac_1
#
# 🖼️ ac_1 | m/z 389.2663 → 1032×1140 px (5 µm/px @ 5 DPI)
#
# ✓ Loaded ac_1✓ Loaded ac_1✓ Loaded ac_1
#
# ✓ Loaded ac_1
# ✓ Loaded ac_1
#
# ✓ Loaded ac_1
#
# ✓ Loaded ac_1✓ Loaded ac_1🖼️ ac_1 | m/z 400.3436 → 1032×1140 px (5 µm/px @ 5 DPI)
# 🖼️ ac_1 | m/z 399.2521 → 1032×1140 px (5 µm/px @ 5 DPI)✓ Loaded ac_1✓ Loaded ac_1🖼️ ac_1 | m/z 411.2505 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 403.2464 → 1032×1140 px (5 µm/px @ 5 DPI)
#
#
#
# ✓ Loaded ac_1
#
# ✓ Loaded ac_1
# 🖼️ ac_1 | m/z 413.2643 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 405.1786 → 1032×1140 px (5 µm/px @ 5 DPI)
# ✓ Loaded ac_1🖼️ ac_1 | m/z 412.2511 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 426.3590 → 1032×1140 px (5 µm/px @ 5 DPI)✓ Loaded ac_1✓ Loaded ac_1
#
# 🖼️ ac_1 | m/z 431.2451 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 456.2955 → 1032×1140 px (5 µm/px @ 5 DPI)✓ Loaded ac_1🖼️ ac_1 | m/z 458.3098 → 1032×1140 px (5 µm/px @ 5 DPI)✓ Loaded ac_1✓ Loaded ac_1
# 🖼️ ac_1 | m/z 455.2927 → 1032×1140 px (5 µm/px @ 5 DPI)
# ✓ Loaded ac_1✓ Loaded ac_1
# ✓ Loaded ac_1
#
# 🖼️ ac_1 | m/z 457.3073 → 1032×1140 px (5 µm/px @ 5 DPI)
#
# 🖼️ ac_1 | m/z 471.2860 → 1032×1140 px (5 µm/px @ 5 DPI)
#
#
#
#
# ✓ Loaded ac_1
# ✓ Loaded ac_1
#
#
# 🖼️ ac_1 | m/z 412.2820 → 1032×1140 px (5 µm/px @ 5 DPI)✓ Loaded ac_1
# 🖼️ ac_1 | m/z 486.3091 → 1032×1140 px (5 µm/px @ 5 DPI)✓ Loaded ac_1🖼️ ac_1 | m/z 498.3408 → 1032×1140 px (5 µm/px @ 5 DPI)
# 🖼️ ac_1 | m/z 483.2865 → 1032×1140 px (5 µm/px @ 5 DPI)
# 🖼️ ac_1 | m/z 482.2799 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 478.3294 → 1032×1140 px (5 µm/px @ 5 DPI)
#
#
#
# 🖼️ ac_1 | m/z 496.3390 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 484.2952 → 1032×1140 px (5 µm/px @ 5 DPI)✓ Loaded ac_1🖼️ ac_1 | m/z 491.3612 → 1032×1140 px (5 µm/px @ 5 DPI)
#
#
# 🖼️ ac_1 | m/z 485.3012 → 1032×1140 px (5 µm/px @ 5 DPI)✓ Loaded ac_1
#
# 🖼️ ac_1 | m/z 487.2803 → 1032×1140 px (5 µm/px @ 5 DPI)
# ✓ Loaded ac_1
#
# 🖼️ ac_1 | m/z 492.3646 → 1032×1140 px (5 µm/px @ 5 DPI)
# 🖼️ ac_1 | m/z 499.2811 → 1032×1140 px (5 µm/px @ 5 DPI)
# 🖼️ ac_1 | m/z 501.2972 → 1032×1140 px (5 µm/px @ 5 DPI)
# ✓ Loaded ac_1
#
#
# 🖼️ ac_1 | m/z 499.3410 → 1032×1140 px (5 µm/px @ 5 DPI)
# 🖼️ ac_1 | m/z 497.3427 → 1032×1140 px (5 µm/px @ 5 DPI)
#
# 🖼️ ac_1 | m/z 500.3107 → 1032×1140 px (5 µm/px @ 5 DPI)
# 🖼️ ac_1 | m/z 500.3482 → 1032×1140 px (5 µm/px @ 5 DPI)✓ Loaded ac_1
#
# 🖼️ ac_1 | m/z 501.3523 → 1032×1140 px (5 µm/px @ 5 DPI)
#
# 🖼️ ac_1 | m/z 502.3284 → 1032×1140 px (5 µm/px @ 5 DPI)
#
#
# 🖼️ ac_1 | m/z 500.2857 → 1032×1140 px (5 µm/px @ 5 DPI)✓ Loaded ac_1
# 🖼️ ac_1 | m/z 507.2703 → 1032×1140 px (5 µm/px @ 5 DPI)
# 🖼️ ac_1 | m/z 504.3442 → 1032×1140 px (5 µm/px @ 5 DPI)✓ Loaded ac_1
# 🖼️ ac_1 | m/z 502.3008 → 1032×1140 px (5 µm/px @ 5 DPI)
#
# 🖼️ ac_1 | m/z 516.3418 → 1032×1140 px (5 µm/px @ 5 DPI)
#
# 🖼️ ac_1 | m/z 503.3668 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 502.3610 → 1032×1140 px (5 µm/px @ 5 DPI)
# 🖼️ ac_1 | m/z 517.2901 → 1032×1140 px (5 µm/px @ 5 DPI)
# 🖼️ ac_1 | m/z 506.3581 → 1032×1140 px (5 µm/px @ 5 DPI)
# 🖼️ ac_1 | m/z 515.2740 → 1032×1140 px (5 µm/px @ 5 DPI)
# ✓ Loaded ac_1
# ✓ Loaded ac_1
#
# 🖼️ ac_1 | m/z 518.3206 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 514.3268 → 1032×1140 px (5 µm/px @ 5 DPI)
# 🖼️ ac_1 | m/z 522.3557 → 1032×1140 px (5 µm/px @ 5 DPI)
# 🖼️ ac_1 | m/z 515.3307 → 1032×1140 px (5 µm/px @ 5 DPI)
# 🖼️ ac_1 | m/z 517.3470 → 1032×1140 px (5 µm/px @ 5 DPI)
# ✓ Loaded ac_1
#
# 🖼️ ac_1 | m/z 526.2696 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 525.3731 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 524.3706 → 1032×1140 px (5 µm/px @ 5 DPI)
#
#
# 🖼️ ac_1 | m/z 523.3569 → 1032×1140 px (5 µm/px @ 5 DPI)
# 🖼️ ac_1 | m/z 526.3275 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 527.2731 → 1032×1140 px (5 µm/px @ 5 DPI)
#
# 🖼️ ac_1 | m/z 527.3338 → 1032×1140 px (5 µm/px @ 5 DPI)
# 🖼️ ac_1 | m/z 528.2838 → 1032×1140 px (5 µm/px @ 5 DPI)
# 🖼️ ac_1 | m/z 528.3446 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 529.2884 → 1032×1140 px (5 µm/px @ 5 DPI)
#
# ✓ Loaded ac_1
# ✓ Loaded ac_1
# ✓ Loaded ac_1
# ✓ Loaded ac_1
# 🖼️ ac_1 | m/z 529.3466 → 1032×1140 px (5 µm/px @ 5 DPI)
# ✓ Loaded ac_1
# ✓ Loaded ac_1
# ✓ Loaded ac_1✓ Loaded ac_1🖼️ ac_1 | m/z 537.3413 → 1032×1140 px (5 µm/px @ 5 DPI)
#
# ✓ Loaded ac_1
#
# 🖼️ ac_1 | m/z 530.3534 → 1032×1140 px (5 µm/px @ 5 DPI)✓ Loaded ac_1
#
# ✓ Loaded ac_1✓ Loaded ac_1
#
# 🖼️ ac_1 | m/z 542.3211 → 1032×1140 px (5 µm/px @ 5 DPI)
# ✓ Loaded ac_1
# 🖼️ ac_1 | m/z 544.3015 → 1032×1140 px (5 µm/px @ 5 DPI)✓ Loaded ac_1✓ Loaded ac_1✓ Loaded ac_1
# ✓ Loaded ac_1
#
#
#
# 🖼️ ac_1 | m/z 543.3281 → 1032×1140 px (5 µm/px @ 5 DPI)
# 🖼️ ac_1 | m/z 545.3067 → 1032×1140 px (5 µm/px @ 5 DPI)✓ Loaded ac_1🖼️ ac_1 | m/z 546.3519 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 544.3369 → 1032×1140 px (5 µm/px @ 5 DPI)
# 🖼️ ac_1 | m/z 546.3164 → 1032×1140 px (5 µm/px @ 5 DPI)
#
#
# ✓ Loaded ac_1
#
# 🖼️ ac_1 | m/z 545.3421 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 547.3226 → 1032×1140 px (5 µm/px @ 5 DPI)✓ Loaded ac_1
# ✓ Loaded ac_1
#
#
# ✓ Loaded ac_1
# ✓ Loaded ac_1
# ✓ Loaded ac_1✓ Loaded ac_1✓ Loaded ac_1
#
#
# ✓ Loaded ac_1🖼️ ac_1 | m/z 548.3333 → 1032×1140 px (5 µm/px @ 5 DPI)✓ Loaded ac_1
#
# ✓ Loaded ac_1🖼️ ac_1 | m/z 548.5390 → 1032×1140 px (5 µm/px @ 5 DPI)
#
#
# ✓ Loaded ac_1✓ Loaded ac_1
#
# 🖼️ ac_1 | m/z 548.3690 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 547.3582 → 1032×1140 px (5 µm/px @ 5 DPI)✓ Loaded ac_1✓ Loaded ac_1🖼️ ac_1 | m/z 549.3734 → 1032×1140 px (5 µm/px @ 5 DPI)
#
#
#
# ✓ Loaded ac_1
#
# ✓ Loaded ac_1✓ Loaded ac_1
# 🖼️ ac_1 | m/z 550.3494 → 1032×1140 px (5 µm/px @ 5 DPI)✓ Loaded ac_1
#
#
# ✓ Loaded ac_1✓ Loaded ac_1
# 🖼️ ac_1 | m/z 550.3824 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 551.3519 → 1032×1140 px (5 µm/px @ 5 DPI)
#
# 🖼️ ac_1 | m/z 551.5035 → 1032×1140 px (5 µm/px @ 5 DPI)✓ Loaded ac_1✓ Loaded ac_1
#
#
#
# 🖼️ ac_1 | m/z 559.3208 → 1032×1140 px (5 µm/px @ 5 DPI)✓ Loaded ac_1
# ✓ Loaded ac_1
# ✓ Loaded ac_1
#
# 🖼️ ac_1 | m/z 558.3177 → 1032×1140 px (5 µm/px @ 5 DPI)✓ Loaded ac_1
# ✓ Loaded ac_1🖼️ ac_1 | m/z 564.3604 → 1032×1140 px (5 µm/px @ 5 DPI)
#
#
# 🖼️ ac_1 | m/z 560.3313 → 1032×1140 px (5 µm/px @ 5 DPI)✓ Loaded ac_1🖼️ ac_1 | m/z 556.2780 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 561.3380 → 1032×1140 px (5 µm/px @ 5 DPI)✓ Loaded ac_1
#
# ✓ Loaded ac_1
#
#
# 🖼️ ac_1 | m/z 563.3512 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 562.3493 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 568.3390 → 1032×1140 px (5 µm/px @ 5 DPI)
# 🖼️ ac_1 | m/z 572.2741 → 1032×1140 px (5 µm/px @ 5 DPI)
# ✓ Loaded ac_1
#
# ✓ Loaded ac_1
#
# ✓ Loaded ac_1
#
# ✓ Loaded ac_1🖼️ ac_1 | m/z 565.3687 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 573.2793 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 570.2575 → 1032×1140 px (5 µm/px @ 5 DPI)✓ Loaded ac_1
# ✓ Loaded ac_1
#
# ✓ Loaded ac_1✓ Loaded ac_1
#
# 🖼️ ac_1 | m/z 576.3632 → 1032×1140 px (5 µm/px @ 5 DPI)✓ Loaded ac_1
# 🖼️ ac_1 | m/z 575.2922 → 1032×1140 px (5 µm/px @ 5 DPI)✓ Loaded ac_1
#
#
#
#
# 🖼️ ac_1 | m/z 574.2892 → 1032×1140 px (5 µm/px @ 5 DPI)✓ Loaded ac_1
# 🖼️ ac_1 | m/z 576.3056 → 1032×1140 px (5 µm/px @ 5 DPI)
#
#
# 🖼️ ac_1 | m/z 572.3313 → 1032×1140 px (5 µm/px @ 5 DPI)✓ Loaded ac_1✓ Loaded ac_1🖼️ ac_1 | m/z 578.3435 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 577.5171 → 1032×1140 px (5 µm/px @ 5 DPI)
# ✓ Loaded ac_1
# ✓ Loaded ac_1
#
#
# ✓ Loaded ac_1
#
#
# 🖼️ ac_1 | m/z 578.5200 → 1032×1140 px (5 µm/px @ 5 DPI)✓ Loaded ac_1
# ✓ Loaded ac_1
# ✓ Loaded ac_1
# 🖼️ ac_1 | m/z 578.3811 → 1032×1140 px (5 µm/px @ 5 DPI)
# 🖼️ ac_1 | m/z 579.5304 → 1032×1140 px (5 µm/px @ 5 DPI)
# ✓ Loaded ac_1✓ Loaded ac_1
# ✓ Loaded ac_1
# 🖼️ ac_1 | m/z 592.3946 → 1032×1140 px (5 µm/px @ 5 DPI)
#
#
# 🖼️ ac_1 | m/z 599.5012 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 604.5369 → 1032×1140 px (5 µm/px @ 5 DPI)
#
# 🖼️ ac_1 | m/z 603.5342 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 606.4109 → 1032×1140 px (5 µm/px @ 5 DPI)
#
# 🖼️ ac_1 | m/z 625.5166 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 605.5474 → 1032×1140 px (5 µm/px @ 5 DPI)
#
# 🖼️ ac_1 | m/z 628.5357 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 624.5040 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 580.3567 → 1032×1140 px (5 µm/px @ 5 DPI)
#
# 🖼️ ac_1 | m/z 623.5025 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 622.4404 → 1032×1140 px (5 µm/px @ 5 DPI)
# 🖼️ ac_1 | m/z 620.4269 → 1032×1140 px (5 µm/px @ 5 DPI)✓ Loaded ac_1✓ Loaded ac_1✓ Loaded ac_1
#
#
#
# 🖼️ ac_1 | m/z 621.4328 → 1032×1140 px (5 µm/px @ 5 DPI)
# 🖼️ ac_1 | m/z 606.5534 → 1032×1140 px (5 µm/px @ 5 DPI)
# 🖼️ ac_1 | m/z 627.5340 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 646.4416 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 629.5422 → 1032×1140 px (5 µm/px @ 5 DPI)
#
#
# ✓ Loaded ac_1
#
#
# 🖼️ ac_1 | m/z 635.5386 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 634.4432 → 1032×1140 px (5 µm/px @ 5 DPI)
# ✓ Loaded ac_1🖼️ ac_1 | m/z 630.6164 → 1032×1140 px (5 µm/px @ 5 DPI)
#
# 🖼️ ac_1 | m/z 648.4584 → 1032×1140 px (5 µm/px @ 5 DPI)
#
# ✓ Loaded ac_1🖼️ ac_1 | m/z 645.4339 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 649.5162 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 647.4476 → 1032×1140 px (5 µm/px @ 5 DPI)
#
#
# 🖼️ ac_1 | m/z 649.4643 → 1032×1140 px (5 µm/px @ 5 DPI)
# 🖼️ ac_1 | m/z 650.4360 → 1032×1140 px (5 µm/px @ 5 DPI)
#
# ✓ Loaded ac_1
# 🖼️ ac_1 | m/z 650.4717 → 1032×1140 px (5 µm/px @ 5 DPI)
# 🖼️ ac_1 | m/z 652.5370 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 651.5329 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 653.5427 → 1032×1140 px (5 µm/px @ 5 DPI)🖼️ ac_1 | m/z 651.4417 → 1032×1140 px (5 µm/px @ 5 DPI)
#
#
#
# 🖼️ ac_1 | m/z 662.4386 → 1032×1140 px (5 µm/px @ 5 DPI)
# ✓ Loaded ac_1
# 🖼️ ac_1 | m/z 655.5653 → 1032×1140 px (5 µm/px @ 5 DPI)
