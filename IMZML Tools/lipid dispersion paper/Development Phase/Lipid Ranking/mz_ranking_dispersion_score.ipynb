# %%
import matplotlib
matplotlib.use('Qt5Agg')  # Important for VSCode interactivity

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import PolygonSelector
from matplotlib.path import Path
from matplotlib.colors import LinearSegmentedColormap
import scanpy as sc

import numpy as np
import os
import plotly.io as pio
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import scipy.sparse as sp
from anndata import AnnData

# %%
class PolygonAnnotator:
    def __init__(self, image, cmap='hot'):
        self.image = image
        self.coords = None
        self.done = False

        self.fig, self.ax = plt.subplots()
        self.ax.imshow(image, cmap=cmap)
        self.ax.set_title("Click to draw polygon. Double-click to finish.")

        self.selector = PolygonSelector(
            self.ax,
            self.onselect,
            useblit=True,
            props=dict(color='cyan', linewidth=2),
            handle_props=dict(marker='o', markersize=5, mec='cyan', mfc='cyan')
        )

        self.fig.canvas.mpl_connect('close_event', self._on_close)
        plt.show(block=True)  # Blocks until the window is closed

    def _on_close(self, event):
        self.done = True

    def onselect(self, verts):
        self.coords = verts
        print(f"Polygon drawn with {len(verts)} points.")
        plt.close(self.fig)  # Automatically close the window

    def get_mask(self):
        if not self.coords:
            print("No polygon was drawn.")
            return None
        ny, nx = self.image.shape
        y, x = np.mgrid[:ny, :nx]
        points = np.vstack((x.flatten(), y.flatten())).T
        path = Path(self.coords)
        return path.contains_points(points).reshape((ny, nx))

# %%
def get_mz_heatmap_image(adata, target_mz, tol=0.1):
    mz_axis = adata.var_names.astype(float).values
    mz_diff = np.abs(mz_axis - target_mz)
    if np.min(mz_diff) > tol:
        raise ValueError(f"No m/z found within ±{tol} of {target_mz}")
    mz_index = np.argmin(mz_diff)
    matched_mz = mz_axis[mz_index]

    intensities = adata.X[:, mz_index].toarray().flatten() if hasattr(adata.X, "toarray") else adata.X[:, mz_index]
    x = adata.obs["x"].values.astype(int)
    y = adata.obs["y"].values.astype(int)

    width = x.max() + 1
    height = y.max() + 1
    image = np.zeros((height, width))
    image[y, x] = intensities

    return image, matched_mz

# %%
# Load and visualize the m/z heatmap from AnnData
input_file = "/Users/amin/Desktop/PhD_Thesis/Code/IMZML Tools/a_peaks_0.00001_top1000_9w_3p_5points.h5ad"
adata = sc.read_h5ad(input_file)
print(f"Loaded AnnData from: {input_file}")
# Out:
# Loaded AnnData from: /Users/amin/Desktop/PhD_Thesis/Code/IMZML Tools/a_peaks_0.00001_top1000_9w_3p_5points.h5ad

# %%
def sort_adata_by_mz(adata, mz_column="mzs"):
    def to_float_with_warning(index, label="var_names"):
        mzs = pd.to_numeric(index, errors="coerce")
        n_nans = mzs.isna().sum()
        if n_nans > 0:
            print(f"⚠️ Warning: {n_nans} entries in {label} could not be converted to float and were set to NaN.")
        return mzs
    adata.var[mz_column] = to_float_with_warning(adata.var_names)
    adata = adata[:, adata.var[mz_column].sort_values().index]
    return adata

# %%
adata = sort_adata_by_mz(adata, mz_column="mzs")
adata.var
# Out:
#                  mzs
# 136.0150    136.0150
# 136.0608    136.0608
# 137.0251    137.0251
# 138.0287    138.0287
# 139.0359    139.0359
# ...              ...
# 1520.1588  1520.1588
# 1521.1633  1521.1633
# 1522.1682  1522.1682
# 1542.1475  1542.1475
# 1544.1542  1544.1542
#
# [1000 rows x 1 columns]

# %%
# ---- Run ----

target_mz = 788.5
image, matched_mz = get_mz_heatmap_image(adata, target_mz)
print(f"Target m/z: {target_mz} → Matched m/z: {matched_mz}")

custom_cmap = LinearSegmentedColormap.from_list("custom_scale", [
    (0.0, "#000000"),  # black
    (0.10, "#000080"),  # navy
    (0.15, "#0000FF"),  # blue
    (0.30, "#8000FF"),  # purple-ish
    (0.45, "#FF0000"),  # red
    (0.60, "#FF8000"),  # orange
    (0.75, "#FFFF00"),  # yellow
    (1.0, "#FFFFFF")   # white
])

#custom_cmap = "binary"
# Use the annotator with your image and colormap
annotator = PolygonAnnotator(image, cmap=custom_cmap)
mask = annotator.get_mask()

if mask is not None:
    masked_image = np.where(mask, image, 0)
    plt.imshow(masked_image, cmap=custom_cmap)
    plt.title(f"Masked m/z = {matched_mz:.4f}")
    plt.show()
else:
    print("No mask created.")
# Out:
# Target m/z: 788.5 → Matched m/z: 788.5027
# Polygon drawn with 49 points.

# %%
# Get spatial coordinates
x = adata.obs["x"].astype(int).values
y = adata.obs["y"].astype(int).values

# Mask value at each spot
adata.obs["tissue"] = mask[y, x]  # Boolean mask (True = inside polygon)
adata.obs["tissue"] = adata.obs["tissue"].astype(int)  # 1 = inside, 0 = outside
print(adata.obs["tissue"].value_counts())
# Out:
# tissue
# 0    9461
# 1    7144
# Name: count, dtype: int64
# /var/folders/0n/w0dydx896p7b5chql0_cv6hr0000gn/T/ipykernel_55531/1596079847.py:6: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   adata.obs["tissue"] = mask[y, x]  # Boolean mask (True = inside polygon)

# %%
adata1 = adata
adata.obs["tissue"]
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 16600    0
# 16601    0
# 16602    0
# 16603    0
# 16604    0
# Name: tissue, Length: 16605, dtype: int64

# %%
adata = adata1
adata
# Out:
# AnnData object with n_obs × n_vars = 16605 × 1000
#     obs: 'x', 'y', 'TIC', 'sample', 'batch', 'age_group', 'disease_status', 'tissue'
#     var: 'mzs'

# %%
import numpy as np
import scipy.sparse as sp
import anndata as ad

def tic_normalize(adata, inplace = True, layer_name = None):
    """
    Perform Total Ion Current (TIC) normalization on an AnnData object.
    
    Parameters:
    - adata (AnnData): The input AnnData object with intensity matrix in `.X`.
    - inplace (bool): If True, overwrite `adata.X`. If False, store result in `adata.layers[layer_name]`.
    - layer_name (str): Name of the layer to store normalized matrix. Required if `inplace=False`.

    Returns:
    - None. The AnnData object is modified in-place.
    """

    if not inplace and not layer_name:
        raise ValueError("You must specify 'layer_name' when inplace=False.")

    # Compute TIC per observation
    tic = adata.X.sum(axis=1)
    tic = np.asarray(tic).flatten()
    tic[tic == 0] = 1.0  # Avoid division by zero

    # Normalize
    if sp.issparse(adata.X):
        normalized = adata.X.multiply(1 / tic[:, np.newaxis])
    else:
        normalized = adata.X / tic[:, np.newaxis]

    # Store result
    if inplace:
        adata.layers["raw"] = adata.X.copy()  # Store raw values before normalization
        adata.X = normalized
    else:
        adata.layers[layer_name] = normalized

    # Save TIC to .obs
    adata.obs["tic"] = tic

    print(f"✅ TIC normalization complete. {'Updated adata.X' if inplace else f'Stored in layer: {layer_name}'}")

# %%
tic_normalize(adata, inplace=True)
# Out:
# ✅ TIC normalization complete. Updated adata.X

# %%
def filter_mz_by_tissue(adata, tissue_key="tissue", tissue_val=1, non_tissue_val=0, foldchange=2.0, layer=None, normalize_tic=True):
    # 1. Extract raw data
    data = adata.layers[layer] if layer is not None else adata.X

    # 2. TIC normalization per pixel
    if normalize_tic:
        # Sum across features for each observation (axis=1)
        tic = np.asarray(data.sum(axis=1)).ravel()
        # Avoid division by zero
        tic[tic == 0] = 1.0
        # Normalize in place (if sparse, convert to array)
        data = data / tic[:, None]

    # 3. Define tissue masks
    mask_tissue = adata.obs[tissue_key] == tissue_val
    mask_non    = adata.obs[tissue_key] == non_tissue_val

    # 4. Compute mean normalized intensity per feature
    mean_tissue    = np.asarray(data[mask_tissue].mean(axis=0)).ravel()
    mean_nontissue = np.asarray(data[mask_non].mean(axis=0)).ravel()

    # 5. Identify features to remove
    to_remove = mean_tissue < foldchange * mean_nontissue

    # 6. Print removed m/z names
    mz_to_remove = adata.var_names[to_remove]
    print(f"Dropping {len(mz_to_remove)} m/z features:", mz_to_remove.values)

    # 7. Subset and return
    return adata[:, ~to_remove].copy()

# %%
foldchange = 3

# Filter m/z features based on tissue mask
adata = filter_mz_by_tissue(adata, tissue_key="tissue", tissue_val=1, non_tissue_val=0, foldchange=foldchange, layer=None, normalize_tic=False)
# Out:
# Dropping 660 m/z features: ['136.0150' '137.0251' '138.0287' '139.0359' '154.0255' '155.0350'
#  '156.0424' '159.0070' '160.0107' '163.0405' '165.0200' '172.0540'
#  '173.0578' '176.0111' '177.0146' '178.0269' '179.0362' '181.0163'
#  '187.0399' '189.0757' '190.0676' '191.0379' '192.9801' '195.0905'
#  '196.0981' '196.9856' '197.1082' '197.9919' '199.0008' '199.0439'
#  '199.9998' '200.0492' '201.0571' '202.0613' '202.1793' '203.0369'
#  '203.0680' '203.1800' '204.0398' '210.9897' '211.0595' '213.0560'
#  '213.9619' '214.0577' '214.9722' '215.0298' '216.0426' '217.0514'
#  '218.0560' '219.0630' '219.9751' '220.0723' '220.9800' '226.1111'
#  '227.0378' '228.0455' '229.0025' '229.0488' '230.0543' '231.0686'
#  '232.0653' '233.0507' '233.0774' '235.9458' '239.0343' '240.0412'
#  '241.0502' '242.0613' '243.0269' '243.0677' '244.0353' '245.0458'
#  '246.0516' '247.0594' '248.0624' '249.0743' '251.0421' '254.0257'
#  '255.0287' '256.0338' '257.0478' '258.0498' '259.0608' '259.2436'
#  '260.0386' '261.0393' '262.0491' '263.0537' '264.0603' '265.0616'
#  '266.0720' '267.0272' '268.0413' '269.0502' '270.0538' '271.0377'
#  '272.0306' '273.0397' '273.2201' '273.2634' '274.0435' '274.2748'
#  '275.0563' '275.2736' '276.0565' '277.0659' '278.0479' '279.0389'
#  '279.0973' '284.0206' '285.0295' '286.0403' '287.0455' '288.0302'
#  '289.0389' '290.0419' '291.0466' '292.0531' '293.0538' '294.0637'
#  '295.0229' '296.0287' '297.0362' '298.0454' '299.0563' '301.0227'
#  '302.0159' '303.0184' '303.2312' '304.0301' '305.0435' '306.0433'
#  '307.0371' '307.1212' '308.0478' '308.1168' '309.0449' '309.1370'
#  '310.0742' '310.1357' '311.0130' '311.1516' '312.0225' '313.0337'
#  '314.0387' '315.0454' '316.0537' '316.1003' '316.2090' '317.0480'
#  '318.0517' '319.0414' '321.0332' '325.0040' '328.0020' '329.0229'
#  '330.0215' '331.0297' '331.1170' '332.0313' '332.0950' '332.3338'
#  '333.0266' '333.1222' '334.0233' '334.1111' '335.0136' '335.0695'
#  '336.0213' '337.0225' '337.0706' '339.0374' '339.0857' '340.3089'
#  '341.0906' '342.3255' '344.9885' '346.0029' '347.0108' '347.0677'
#  '348.0119' '349.0390' '349.9940' '350.0431' '350.9995' '351.1385'
#  '352.0063' '353.0146' '353.0721' '354.0080' '354.0737' '355.0027'
#  '355.0768' '355.9988' '356.9964' '357.0624' '357.9870' '360.0056'
#  '361.0087' '361.0668' '361.9717' '362.9775' '363.0524' '364.0014'
#  '364.0681' '365.0184' '365.0685' '365.9700' '366.0285' '366.0703'
#  '366.9731' '367.0818' '367.9774' '368.9916' '369.0587' '369.9904'
#  '370.0575' '370.9820' '371.0661' '371.9835' '372.9863' '373.9904'
#  '375.0044' '376.0027' '376.9855' '377.0703' '379.0653' '380.0606'
#  '381.0657' '382.0721' '383.0799' '383.9606' '384.0804' '384.9708'
#  '385.0822' '386.0081' '386.9952' '387.0725' '387.1928' '388.9561'
#  '389.9643' '390.9737' '391.0428' '391.9758' '392.0363' '392.9619'
#  '393.0658' '394.0619' '395.0680' '395.9797' '396.0666' '396.9882'
#  '397.0578' '397.9893' '398.0677' '399.0702' '400.0739' '401.0788'
#  '402.9348' '405.0673' '405.1816' '405.9378' '406.0697' '407.0558'
#  '407.1967' '408.9519' '409.0579' '409.1727' '410.0475' '411.0650'
#  '411.9507' '412.0659' '412.9616' '413.0680' '413.2633' '414.0625'
#  '415.0671' '416.0729' '417.0710' '420.0367' '421.0485' '422.0525'
#  '423.0667' '424.0641' '425.0628' '426.0626' '427.0635' '428.0476'
#  '429.0690' '433.0486' '435.0590' '437.0375' '438.0421' '439.0570'
#  '440.0549' '440.4030' '441.0630' '442.0630' '443.0551' '444.0666'
#  '445.0608' '445.1529' '446.0654' '447.0619' '448.0410' '449.0490'
#  '449.1508' '449.3544' '450.0488' '451.0590' '451.1610' '452.0610'
#  '453.0549' '455.0366' '457.0507' '459.0317' '460.0332' '461.0358'
#  '462.0395' '463.0443' '463.1664' '465.0382' '465.1795' '466.0368'
#  '467.0459' '468.0562' '469.0580' '470.0609' '471.0364' '473.0380'
#  '473.1425' '477.0158' '481.0294' '482.0163' '483.0330' '484.0411'
#  '485.0599' '485.3580' '486.0605' '487.0621' '487.1585' '488.0165'
#  '489.0298' '489.1071' '490.0345' '491.0306' '496.3372' '497.3396'
#  '498.0020' '499.0256' '500.0308' '501.0369' '502.0343' '503.0424'
#  '504.0026' '505.0127' '506.0141' '507.0164' '508.0197' '509.0142'
#  '510.0096' '511.0158' '512.0132' '513.0214' '517.0743' '519.0818'
#  '520.9935' '522.0106' '523.0186' '524.0176' '524.3675' '525.0175'
#  '525.9985' '527.0004' '528.0132' '529.0170' '530.0217' '530.3032'
#  '531.0173' '531.0776' '532.0038' '533.0012' '533.0819' '535.0900'
#  '537.0208' '537.9825' '538.9855' '540.4258' '541.9698' '542.9766'
#  '543.9945' '544.9929' '545.0745' '546.0025' '546.9926' '547.0845'
#  '547.9938' '548.9960' '549.0880' '550.0092' '551.0132' '551.0952'
#  '552.0181' '553.0034' '553.9998' '554.2875' '557.0665' '558.9540'
#  '559.0778' '559.9661' '560.9688' '561.0825' '561.9723' '562.9767'
#  '563.0803' '564.0651' '564.9677' '565.0818' '565.9747' '566.9828'
#  '567.9813' '568.9807' '571.9841' '572.9871' '573.9908' '574.9745'
#  '575.0688' '576.0744' '577.0809' '579.0860' '580.9368' '581.0840'
#  '581.2419' '581.9474' '582.2530' '582.9590' '583.9610' '584.9532'
#  '585.0588' '587.0671' '587.9561' '588.9623' '589.0684' '591.0623'
#  '593.0809' '594.0808' '595.0816' '597.0643' '598.0570' '599.0718'
#  '599.3925' '601.0612' '603.0646' '604.0622' '605.0714' '607.0599'
#  '609.0626' '615.0577' '617.0518' '619.0599' '620.0598' '621.0713'
#  '622.0728' '623.0859' '631.0347' '635.0444' '636.0461' '637.0596'
#  '637.3020' '638.0627' '638.3054' '639.0779' '639.3097' '640.3147'
#  '641.0331' '643.0466' '645.0522' '647.0388' '650.4418' '653.0389'
#  '655.0489' '655.3171' '657.0172' '658.0248' '659.0333' '659.2911'
#  '660.0424' '660.2892' '661.0524' '661.2994' '662.0519' '663.0409'
#  '664.0419' '665.0323' '666.0349' '667.0381' '675.0120' '675.2615'
#  '676.0220' '676.2717' '677.0327' '677.2827' '678.0215' '679.0223'
#  '680.0125' '681.0148' '682.0179' '683.0331' '684.0262' '685.0201'
#  '686.0261' '687.0215' '688.0289' '689.0372' '691.9973' '693.0084'
#  '696.9911' '698.0059' '699.0099' '700.0030' '701.0084' '702.0029'
#  '703.0097' '703.5655' '704.0173' '705.0255' '706.0229' '707.0211'
#  '708.0082' '709.0077' '711.0204' '713.0010' '713.9808' '714.9844'
#  '715.9888' '716.9822' '717.9764' '718.9828' '720.0018' '721.0097'
#  '722.0066' '723.0042' '723.9907' '725.0014' '726.0129' '727.0250'
#  '728.0260' '729.0159' '734.9579' '735.9644' '736.9716' '737.9794'
#  '738.9761' '740.9714' '741.9821' '742.9933' '743.9934' '744.9822'
#  '747.9885' '749.0038' '751.3358' '752.9524' '757.9567' '758.9668'
#  '759.9656' '763.9670' '764.9689' '773.0815' '775.0980' '790.3306'
#  '791.0672' '807.0380' '813.0526' '813.3141' '814.3231' '829.0290'
#  '834.2923' '835.0365' '835.3016' '836.2988' '837.0439' '841.0405'
#  '851.0099' '853.0236' '856.0102' '857.0198' '858.0298' '859.0277'
#  '861.0252' '863.0378' '869.0128' '872.9946' '874.0140' '875.0211'
#  '876.0159' '877.0113' '878.0072' '879.0167' '880.0137' '881.0243'
#  '882.0225' '882.5672' '883.0213' '884.0076' '885.0075' '888.9867'
#  '889.9894' '890.9927' '891.9965' '894.9983' '896.0043' '897.0110'
#  '898.0182' '899.0129' '900.0081' '901.0040' '902.0134' '903.0234'
#  '904.0340' '905.0320' '911.9808' '912.9832' '913.9861' '916.9850'
#  '917.9902' '918.9958' '920.0021' '920.9955' '924.0059' '925.0016'
#  '934.9747' '940.9789' '950.9432' '1033.0245' '1039.0396' '1050.0183'
#  '1051.0231' '1052.0283' '1055.0187' '1056.0259' '1057.0334' '1065.9956'
#  '1067.0081' '1068.0066' '1071.0052' '1072.0057' '1073.0210' '1074.0223'
#  '1075.0100' '1077.0151' '1078.0327' '1079.0364' '1080.0408' '1088.9844'
#  '1093.9899' '1095.0011' '1095.9983' '1249.0300' '1255.0399' '1271.0072']

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 16605 × 340
#     obs: 'x', 'y', 'TIC', 'sample', 'batch', 'age_group', 'disease_status', 'tissue', 'tic'
#     var: 'mzs'
#     layers: 'raw'

# %%
import numpy as np
import pandas as pd
from scipy.spatial import cKDTree
import matplotlib.pyplot as plt
from tqdm import tqdm


def compute_center_of_mass(x_coords, y_coords, intensities):
    total_intensity = np.sum(intensities)
    if total_intensity == 0:
        return np.nan, np.nan
    x_center = np.sum(x_coords * intensities) / total_intensity
    y_center = np.sum(y_coords * intensities) / total_intensity
    return x_center, y_center


def analyze_metrics(adata, export_border_points=False):
    num_mz = adata.shape[1]
    mz_values = adata.var["mzs"].values

    all_border_data = []
    rows = []

    tissue_centroid_x = adata.obs.loc[adata.obs["tissue"] == True, "x"].mean()
    tissue_centroid_y = adata.obs.loc[adata.obs["tissue"] == True, "y"].mean()

    for mz_index in tqdm(range(num_mz), desc="Processing m/z features"):
        row = {"mz": mz_values[mz_index]}

        # Global center of mass and distance to tissue centroid
        all_x = adata.obs["x"].values
        all_y = adata.obs["y"].values
        all_intensities = adata.X[:, mz_index].toarray().flatten() if hasattr(adata.X, "toarray") else adata.X[:, mz_index].flatten()
        x_com, y_com = compute_center_of_mass(all_x, all_y, all_intensities)

        if not np.isnan(x_com) and not np.isnan(y_com):
            dist_to_tissue_centroid = np.sqrt((x_com - tissue_centroid_x) ** 2 + (y_com - tissue_centroid_y) ** 2)
        else:
            dist_to_tissue_centroid = np.nan

        row["com_distance_to_tissue"] = dist_to_tissue_centroid

        # Background distance to tissue border for nonzero-intensity pixels
        bg_subset = adata[adata.obs["tissue"] == False]
        tissue_subset = adata[adata.obs["tissue"] == True]

        bg_x = bg_subset.obs["x"].values
        bg_y = bg_subset.obs["y"].values
        bg_intensities = bg_subset.X[:, mz_index].toarray().flatten() if hasattr(bg_subset.X, "toarray") else bg_subset.X[:, mz_index].flatten()

        tissue_x = tissue_subset.obs["x"].values
        tissue_y = tissue_subset.obs["y"].values

        if len(bg_intensities) > 0 and len(tissue_x) > 0:
            valid_mask = bg_intensities > 0
            valid_bg_coords = np.vstack([bg_x[valid_mask], bg_y[valid_mask]]).T
            tissue_coords = np.vstack([tissue_x, tissue_y]).T

            if valid_bg_coords.shape[0] > 0:
                tree = cKDTree(tissue_coords)
                distances, indices = tree.query(valid_bg_coords)

                nearest_tissue_points = tissue_coords[indices]

                row["bg_dist_max"] = np.max(distances)
                row["bg_dist_mean"] = np.mean(distances)
                row["bg_nonzero_area"] = valid_bg_coords.shape[0]

                if export_border_points:
                    for i in range(len(valid_bg_coords)):
                        all_border_data.append({
                            "mz": mz_values[mz_index],
                            "bg_x": valid_bg_coords[i, 0],
                            "bg_y": valid_bg_coords[i, 1],
                            "tissue_x": nearest_tissue_points[i, 0],
                            "tissue_y": nearest_tissue_points[i, 1],
                            "distance": distances[i]
                        })

            else:
                row["bg_dist_max"] = np.nan
                row["bg_dist_mean"] = np.nan
                row["bg_nonzero_area"] = 0
        else:
            row["bg_dist_max"] = np.nan
            row["bg_dist_mean"] = np.nan
            row["bg_nonzero_area"] = 0

        # Weighted centroids
        tissue_intensities = tissue_subset.X[:, mz_index].toarray().flatten() if hasattr(tissue_subset.X, "toarray") else tissue_subset.X[:, mz_index].flatten()
        tissue_centroid_x_weighted, tissue_centroid_y_weighted = compute_center_of_mass(tissue_x, tissue_y, tissue_intensities)
        row["weighted_com_x_tissue"] = tissue_centroid_x_weighted
        row["weighted_com_y_tissue"] = tissue_centroid_y_weighted
        row["weighted_com_x_all"] = x_com
        row["weighted_com_y_all"] = y_com

        rows.append(row)

    df_metrics = pd.DataFrame(rows)

    if export_border_points:
        df_border = pd.DataFrame(all_border_data)
        return df_metrics, df_border
    else:
        return df_metrics

# %%
pre_df_metrics, pre_df_border = analyze_metrics(adata, export_border_points=True)
# Out:
# Processing m/z features: 100%|██████████| 340/340 [00:07<00:00, 42.94it/s]

# %%
def mask_low_background_intensities(adata, fold_change=0.2):
    """
    Set background pixel intensities (tissue==0) to 0 if they are below fold_change * max tissue intensity per m/z.
    
    Parameters:
        adata : AnnData
            An AnnData object where .X is (n_pixels x n_mz) and .obs["tissue"] exists.
        fold_change : float
            The threshold multiplier to compare background intensity to max tissue intensity.
    """
    X = adata.X
    tissue_mask = adata.obs["tissue"] == 1
    background_mask = ~tissue_mask

    if sp.issparse(X):
        X = X.tocsr()

    # Compute max intensity of each m/z in tissue pixels
    max_tissue_intensity = X[tissue_mask.values].max(axis=0).A1 if sp.issparse(X) else X[tissue_mask.values].max(axis=0)

    # Define threshold per m/z
    thresholds = fold_change * max_tissue_intensity

    # Modify background pixels
    bg_indices = np.where(background_mask)[0]

    for i in bg_indices:
        row = X[i]
        if sp.issparse(X):
            row = row.tocoo()
            mask = row.data <= thresholds[row.col]
            row.data[mask] = 0
            X[i] = sp.csr_matrix((row.data, (np.zeros_like(row.col), row.col)), shape=(1, X.shape[1]))
        else:
            mask = row <= thresholds
            row[mask] = 0
            X[i] = row

    adata.X = X
    return adata

# %%
min_background_intensity = 0.1
adata = mask_low_background_intensities(adata, fold_change=min_background_intensity)

# %%
import numpy as np
import pandas as pd
from scipy.spatial import cKDTree
import matplotlib.pyplot as plt
from tqdm import tqdm


def compute_center_of_mass(x_coords, y_coords, intensities):
    total_intensity = np.sum(intensities)
    if total_intensity == 0:
        return np.nan, np.nan
    x_center = np.sum(x_coords * intensities) / total_intensity
    y_center = np.sum(y_coords * intensities) / total_intensity
    return x_center, y_center


def analyze_metrics(adata, export_border_points=False):
    num_mz = adata.shape[1]
    mz_values = adata.var["mzs"].values

    all_border_data = []
    rows = []

    for mz_index in tqdm(range(num_mz), desc="Processing m/z features"):

        # Initialize row for current m/z
        row = {"mz": mz_values[mz_index]}

        # Extract x, y, and intensity for current mz
        all_x = adata.obs["x"].values
        all_y = adata.obs["y"].values
        all_intensities = adata.X[:, mz_index].toarray().flatten() if hasattr(adata.X, "toarray") else adata.X[:, mz_index].flatten()

        # Compute global center of mass
        x_com, y_com = compute_center_of_mass(all_x, all_y, all_intensities)

        # Only tissue pixels
        tissue_mask = adata.obs["tissue"].values == True
        tissue_x = all_x[tissue_mask]
        tissue_y = all_y[tissue_mask]
        tissue_intensities = all_intensities[tissue_mask]

        # Compute weighted tissue centroid (center of mass within tissue)
        x_com_tissue, y_com_tissue = compute_center_of_mass(tissue_x, tissue_y, tissue_intensities)

        # Compute distance from global COM to tissue COM
        if not np.isnan(x_com) and not np.isnan(y_com):
            dist_to_tissue_centroid = np.sqrt((x_com - x_com_tissue) ** 2 + (y_com - y_com_tissue) ** 2)
        else:
            dist_to_tissue_centroid = np.nan

        row["com_distance_to_tissue"] = dist_to_tissue_centroid

        # Background distance to tissue border for nonzero-intensity pixels
        bg_subset = adata[adata.obs["tissue"] == False]
        tissue_subset = adata[adata.obs["tissue"] == True]

        bg_x = bg_subset.obs["x"].values
        bg_y = bg_subset.obs["y"].values
        bg_intensities = bg_subset.X[:, mz_index].toarray().flatten() if hasattr(bg_subset.X, "toarray") else bg_subset.X[:, mz_index].flatten()

        tissue_x = tissue_subset.obs["x"].values
        tissue_y = tissue_subset.obs["y"].values

        if len(bg_intensities) > 0 and len(tissue_x) > 0:
            valid_mask = bg_intensities > 0
            valid_bg_coords = np.vstack([bg_x[valid_mask], bg_y[valid_mask]]).T
            tissue_coords = np.vstack([tissue_x, tissue_y]).T

            if valid_bg_coords.shape[0] > 0:
                tree = cKDTree(tissue_coords)
                distances, indices = tree.query(valid_bg_coords)

                nearest_tissue_points = tissue_coords[indices]

                row["bg_dist_max"] = np.max(distances)
                row["bg_dist_mean"] = np.mean(distances)
                row["bg_nonzero_area"] = valid_bg_coords.shape[0]

                if export_border_points:
                    for i in range(len(valid_bg_coords)):
                        all_border_data.append({
                            "mz": mz_values[mz_index],
                            "bg_x": valid_bg_coords[i, 0],
                            "bg_y": valid_bg_coords[i, 1],
                            "tissue_x": nearest_tissue_points[i, 0],
                            "tissue_y": nearest_tissue_points[i, 1],
                            "distance": distances[i]
                        })

            else:
                row["bg_dist_max"] = np.nan
                row["bg_dist_mean"] = np.nan
                row["bg_nonzero_area"] = 0
        else:
            row["bg_dist_max"] = np.nan
            row["bg_dist_mean"] = np.nan
            row["bg_nonzero_area"] = 0

        # Weighted centroids
        tissue_intensities = tissue_subset.X[:, mz_index].toarray().flatten() if hasattr(tissue_subset.X, "toarray") else tissue_subset.X[:, mz_index].flatten()
        tissue_centroid_x_weighted, tissue_centroid_y_weighted = compute_center_of_mass(tissue_x, tissue_y, tissue_intensities)
        row["weighted_com_x_tissue"] = tissue_centroid_x_weighted
        row["weighted_com_y_tissue"] = tissue_centroid_y_weighted
        row["weighted_com_x_all"] = x_com
        row["weighted_com_y_all"] = y_com

        rows.append(row)

    df_metrics = pd.DataFrame(rows)

    if export_border_points:
        df_border = pd.DataFrame(all_border_data)
        return df_metrics, df_border
    else:
        return df_metrics

# %%
def visualize_distance_map(df_border, mz_value, n_arrows=100):
    subset = df_border[df_border["mz"] == mz_value]
    if subset.empty:
        print(f"No border data found for m/z {mz_value}")
        return

    fig, ax = plt.subplots(figsize=(8, 6))
    ax.scatter(subset["bg_x"], subset["bg_y"], c="blue", s=10, label="Background Pixels")
    ax.scatter(subset["tissue_x"], subset["tissue_y"], c="red", s=10, label="Nearest Tissue Border")

    # Draw arrows from bg pixel to nearest tissue
    sample = subset.sample(n=min(n_arrows, len(subset)))
    for _, row in sample.iterrows():
        ax.arrow(row["bg_x"], row["bg_y"],
                 row["tissue_x"] - row["bg_x"],
                 row["tissue_y"] - row["bg_y"],
                 color="gray", alpha=0.5, head_width=1)

    ax.set_title(f"Nearest Tissue Border Points for m/z {mz_value}")
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    ax.legend()
    ax.axis("equal")
    plt.tight_layout()
    plt.show()

# %%
df_metrics, df_border = analyze_metrics(adata, export_border_points=True)
# Out:
# Processing m/z features: 100%|██████████| 340/340 [00:04<00:00, 69.49it/s]

# %%
# Visualize arrows for m/z=885.55 (example)
visualize_distance_map(df_border, mz_value=772.5231)

# %%
from skimage.measure import find_contours
import matplotlib.pyplot as plt
import numpy as np

def visualize_mz_feature(adata, df_metrics, df_border, mz_value, cmap="hot"):
    # Find index of target m/z
    mz_idx = np.argmin(np.abs(adata.var["mzs"].values - mz_value))

    # Get coordinates and intensities
    x = adata.obs["x"].values
    y = adata.obs["y"].values
    intensities = adata.X[:, mz_idx].toarray().flatten() if hasattr(adata.X, "toarray") else adata.X[:, mz_idx].flatten()

    tissue_mask = adata.obs["tissue"].values

    # Extract COMs and border points
    mz_metrics = df_metrics[df_metrics["mz"] == mz_value].iloc[0]
    com_all = (mz_metrics["weighted_com_x_all"], mz_metrics["weighted_com_y_all"])
    com_tissue = (mz_metrics["weighted_com_x_tissue"], mz_metrics["weighted_com_y_tissue"])

    df_mz_border = df_border[df_border["mz"] == mz_value]
    max_row = df_mz_border.loc[df_mz_border["distance"].idxmax()]
    bg_point = (max_row["bg_x"], max_row["bg_y"])
    nearest_tissue_point = (max_row["tissue_x"], max_row["tissue_y"])

    # Create 2D grid (image) for tissue mask
    grid_x = np.unique(x)
    grid_y = np.unique(y)
    x_to_idx = {v: i for i, v in enumerate(grid_x)}
    y_to_idx = {v: i for i, v in enumerate(grid_y)}
    mask_2d = np.zeros((len(grid_y), len(grid_x)), dtype=bool)

    for xi, yi, is_tissue in zip(x, y, tissue_mask):
        if is_tissue:
            mask_2d[y_to_idx[yi], x_to_idx[xi]] = True

    contours = find_contours(mask_2d.astype(float), level=0.5)

    # Create figure
    plt.figure(figsize=(10, 8))

    # Plot heatmap with square pixels
    plt.scatter(x, y, c=intensities, s=8, marker='s', cmap=cmap)
    plt.colorbar(label=f"Intensity @ m/z {mz_value:.2f}")

    # Plot center of mass
    plt.scatter(*com_all, color="cyan", s=150, marker="*", label="COM (all)")
    plt.scatter(*com_tissue, color="lime", s=150, marker="*", label="COM (tissue)")

    # Max distance point and nearest tissue point
    plt.plot([bg_point[0], nearest_tissue_point[0]], [bg_point[1], nearest_tissue_point[1]], 
             color="orange", linestyle="--", label="Max dist to tissue")
    plt.scatter(*bg_point, color="red", s=80, edgecolor="black", label="Furthest BG pt")
    plt.scatter(*nearest_tissue_point, color="green", s=80, edgecolor="black", label="Nearest tissue pt")

    # Plot tissue margin line
    for contour in contours:
        contour_x = grid_x[(contour[:, 1]).astype(int)]
        contour_y = grid_y[(contour[:, 0]).astype(int)]
        plt.plot(contour_x, contour_y, color="red", linewidth=2, label="Tissue border")

    plt.legend()
    plt.title(f"m/z {mz_value:.2f} Heatmap with COMs and Furthest BG Point")
    plt.xlabel("x")
    plt.ylabel("y")
    plt.gca().set_aspect('equal')
    plt.gca().invert_yaxis()
    plt.tight_layout()
    plt.show()

# %%
custom_cmap = LinearSegmentedColormap.from_list("custom_scale", [
    (0.0, "#454545"),   # white
    (0.00000001, "#000000"),  # black
    (0.10, "#000080"),  # navy
    (0.15, "#0000FF"),  # blue
    (0.30, "#8000FF"),  # purple-ish
    (0.45, "#FF0000"),  # red
    (0.60, "#FF8000"),  # orange
    (0.75, "#FFFF00"),  # yellow
    (1.0, "#FFFFFF")   # white
])
#custom_cmap = "binary"
visualize_mz_feature(adata, df_metrics, df_border, mz_value=772.5231, cmap=custom_cmap)

# %%
def visualize_mz_feature(adata, df_metrics, df_border, mz_value, cmap="hot", save_path=None):
    from skimage.measure import find_contours
    import matplotlib.pyplot as plt
    import numpy as np

    # Find index of target m/z
    mz_idx = np.argmin(np.abs(adata.var["mzs"].values - mz_value))

    # Get coordinates and intensities
    x = adata.obs["x"].values
    y = adata.obs["y"].values
    intensities = adata.X[:, mz_idx].toarray().flatten() if hasattr(adata.X, "toarray") else adata.X[:, mz_idx].flatten()

    tissue_mask = adata.obs["tissue"].values

    # Extract COMs and border points
    mz_metrics = df_metrics[df_metrics["mz"] == mz_value].iloc[0]
    com_all = (mz_metrics["weighted_com_x_all"], mz_metrics["weighted_com_y_all"])
    com_tissue = (mz_metrics["weighted_com_x_tissue"], mz_metrics["weighted_com_y_tissue"])

    df_mz_border = df_border[df_border["mz"] == mz_value]
    if df_mz_border.empty:
        print(f"⚠️ Skipping m/z {mz_value:.4f} — no matching metric data found.")
    else:
        max_row = df_mz_border.loc[df_mz_border["distance"].idxmax()]
        bg_point = (max_row["bg_x"], max_row["bg_y"])
        nearest_tissue_point = (max_row["tissue_x"], max_row["tissue_y"])

    # Create 2D grid (image) for tissue mask
    grid_x = np.unique(x)
    grid_y = np.unique(y)
    x_to_idx = {v: i for i, v in enumerate(grid_x)}
    y_to_idx = {v: i for i, v in enumerate(grid_y)}
    mask_2d = np.zeros((len(grid_y), len(grid_x)), dtype=bool)

    for xi, yi, is_tissue in zip(x, y, tissue_mask):
        if is_tissue:
            mask_2d[y_to_idx[yi], x_to_idx[xi]] = True

    contours = find_contours(mask_2d.astype(float), level=0.5)

    # Create figure
    plt.figure(figsize=(10, 8))

    # Plot heatmap
    plt.scatter(x, y, c=intensities, s=8, marker='s', cmap=cmap)
    plt.colorbar(label=f"Intensity @ m/z {mz_value:.2f}")

    # Plot COMs and max distance markers
    plt.scatter(*com_all, color="cyan", s=150, marker="*", label="COM (all)")
    plt.scatter(*com_tissue, color="lime", s=150, marker="*", label="COM (tissue)")
    if not df_mz_border.empty:
        plt.plot([bg_point[0], nearest_tissue_point[0]], [bg_point[1], nearest_tissue_point[1]], 
                color="orange", linestyle="--", label="Max dist to tissue")
        plt.scatter(*bg_point, color="red", s=80, edgecolor="black", label="Furthest BG pt")
        plt.scatter(*nearest_tissue_point, color="green", s=80, edgecolor="black", label="Nearest tissue pt")

    # Plot tissue contour
    for contour in contours:
        contour_x = grid_x[(contour[:, 1]).astype(int)]
        contour_y = grid_y[(contour[:, 0]).astype(int)]
        plt.plot(contour_x, contour_y, color="red", linewidth=2, label="Tissue border")

    plt.legend()
    plt.title(f"m/z {mz_value:.2f} Heatmap with COMs and Furthest BG Point")
    plt.xlabel("x")
    plt.ylabel("y")
    plt.gca().set_aspect('equal')
    plt.gca().invert_yaxis()
    plt.tight_layout()

    # Save or show
    if save_path:
        plt.savefig(save_path, dpi=300)
        plt.close()
    else:
        plt.show()

# %%
df_metrics
# Out:
#             mz  com_distance_to_tissue  bg_dist_max  bg_dist_mean  \
# 0     136.0608                1.929250    18.973666      3.783530
# 1     161.1338                3.572033    38.600518     10.000411
# 2     180.0717                4.648707    47.853944     11.554301
# 3     184.0720                0.603764    24.698178      3.614155
# 4     185.0686                1.280453    47.853944      9.375943
# ..         ...                     ...          ...           ...
# 335  1520.1588                0.452861    18.681542      2.061995
# 336  1521.1633                0.554544    24.758837      1.856722
# 337  1522.1682                0.430454    25.298221      2.156469
# 338  1542.1475                0.144879    24.041631      1.904130
# 339  1544.1542                0.089167    21.189620      2.071524
#
#      bg_nonzero_area  weighted_com_x_tissue  weighted_com_y_tissue  \
# 0               1280              63.756078              51.339852
# 1               1686              63.948514              57.628637
# 2               5967              63.771803              56.259768
# 3               1276              63.856256              55.146900
# 4               3299              64.153258              54.662784
# ..               ...                    ...                    ...
# 335              464              64.172342              54.125200
# 336              386              64.084962              54.466800
# 337              436              64.022174              54.794841
# 338              298              63.777770              53.027534
# 339              357              64.107872              52.546776
#
#      weighted_com_x_all  weighted_com_y_all
# 0             63.778737           49.410735
# 1             64.442661           61.166325
# 2             64.480142           60.854192
# 3             64.211155           54.658456
# 4             64.841303           53.582898
# ..                  ...                 ...
# 335           64.382654           54.526262
# 336           64.463821           54.871751
# 337           64.366197           55.053566
# 338           63.722726           53.161548
# 339           64.196068           52.559900
#
# [340 rows x 9 columns]

# %%
import pandas as pd

# Replace 'your_file.csv' with the path to your CSV file
file_path = '0.1_mean_bg_dis_area.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Display the first few rows of the DataFrame
print(df.head())
# Out:
#          mz       0.9      0.91      0.92      0.93      0.94      0.95  \
# 0  370.3516  0.747640  0.744836  0.742032  0.739228  0.736424  0.733620
# 1  371.3606  0.702121  0.698943  0.695765  0.692587  0.689409  0.686231
# 2  367.3328  0.707426  0.704544  0.701663  0.698781  0.695899  0.693017
# 3  365.3188  0.492166  0.486938  0.481711  0.476483  0.471255  0.466028
# 4  369.3523  0.663787  0.660550  0.657313  0.654076  0.650839  0.647602
#
#        0.96      0.97      0.98      0.99
# 0  0.730816  0.728012  0.725208  0.722404
# 1  0.683053  0.679875  0.676697  0.673519
# 2  0.690135  0.687254  0.684372  0.681490
# 3  0.460800  0.455573  0.450345  0.445117
# 4  0.644364  0.641127  0.637890  0.634653

# %%
# Merge the dataframes on the 'm/z' column
df_metrics = df_metrics.merge(df, on='mz', how='left')

# Display the updated DataFrame
print(df_metrics.head())
# Out:
#          mz  com_distance_to_tissue  bg_dist_max  bg_dist_mean  \
# 0  136.0608                1.929250    18.973666      3.783530
# 1  161.1338                3.572033    38.600518     10.000411
# 2  180.0717                4.648707    47.853944     11.554301
# 3  184.0720                0.603764    24.698178      3.614155
# 4  185.0686                1.280453    47.853944      9.375943
#
#    bg_nonzero_area  weighted_com_x_tissue  weighted_com_y_tissue  \
# 0             1280              63.756078              51.339852
# 1             1686              63.948514              57.628637
# 2             5967              63.771803              56.259768
# 3             1276              63.856256              55.146900
# 4             3299              64.153258              54.662784
#
#    weighted_com_x_all  weighted_com_y_all       0.9      0.91      0.92  \
# 0           63.778737           49.410735  0.199847  0.199411  0.198975
# 1           64.442661           61.166325  0.325376  0.320379  0.315382
# 2           64.480142           60.854192  0.989132  0.990219  0.991305
# 3           64.211155           54.658456  0.195508  0.195196  0.194884
# 4           64.841303           53.582898  0.559228  0.557508  0.555788
#
#        0.93      0.94      0.95      0.96      0.97      0.98      0.99
# 0  0.198539  0.198103  0.197667  0.197231  0.196795  0.196359  0.195923
# 1  0.310385  0.305388  0.300391  0.295393  0.290396  0.285399  0.280402
# 2  0.992392  0.993479  0.994566  0.995653  0.996740  0.997826  0.998913
# 3  0.194572  0.194260  0.193948  0.193636  0.193324  0.193011  0.192699
# 4  0.554068  0.552347  0.550627  0.548907  0.547186  0.545466  0.543746

# %%
import os
import pandas as pd
from matplotlib.colors import LinearSegmentedColormap

sorting_list = ['0.9', '0.91', '0.92', '0.93', '0.94', '0.95', '0.96', '0.97', '0.98', '0.99']

for sort in sorting_list:
    output_folder = f"output_{min_background_intensity}_score_{sort}"

    if os.path.exists(output_folder):
        print(f"⚠️ Warning: Output folder '{output_folder}' already exists. Overwriting.")
    else:
        os.makedirs(output_folder, exist_ok=True)

    df_sorted = df_metrics.sort_values(by=sort, ascending=False)
    rank_num = 1

    for mz in df_sorted["mz"]:
        filename = f"{rank_num}_mz_{mz:.4f}.png"
        filepath = os.path.join(output_folder, filename)
        
        custom_cmap = LinearSegmentedColormap.from_list("custom_scale", [
            (0.0, "#454545"),   # white
            (0.00000001, "#000000"),  # black
            (0.10, "#000080"),  # navy
            (0.15, "#0000FF"),  # blue
            (0.30, "#8000FF"),  # purple-ish
            (0.45, "#FF0000"),  # red
            (0.60, "#FF8000"),  # orange
            (0.75, "#FFFF00"),  # yellow
            (1.0, "#FFFFFF")   # white
        ])
        
        visualize_mz_feature(adata, df_metrics, df_border, mz_value=mz, cmap=custom_cmap, save_path=filepath)
        print(f"Saved: {filepath}")
        rank_num += 1
# Out:
# Saved: output_0.1_score_0.9/1_mz_180.0717.png
# Saved: output_0.1_score_0.9/2_mz_370.3516.png
# Saved: output_0.1_score_0.9/3_mz_367.3328.png
# Saved: output_0.1_score_0.9/4_mz_371.3606.png
# Saved: output_0.1_score_0.9/5_mz_369.3523.png
# Saved: output_0.1_score_0.9/6_mz_284.0794.png
# Saved: output_0.1_score_0.9/7_mz_368.3461.png
# Saved: output_0.1_score_0.9/8_mz_341.3084.png
# Saved: output_0.1_score_0.9/9_mz_385.3478.png
# Saved: output_0.1_score_0.9/10_mz_243.2107.png
# Saved: output_0.1_score_0.9/11_mz_185.0686.png
# Saved: output_0.1_score_0.9/12_mz_365.3188.png
# Saved: output_0.1_score_0.9/13_mz_328.3184.png
# Saved: output_0.1_score_0.9/14_mz_383.3277.png
# Saved: output_0.1_score_0.9/15_mz_386.3513.png
# Saved: output_0.1_score_0.9/16_mz_808.5768.png
# Saved: output_0.1_score_0.9/17_mz_366.3293.png
# Saved: output_0.1_score_0.9/18_mz_384.3286.png
# Saved: output_0.1_score_0.9/19_mz_256.0827.png
# Saved: output_0.1_score_0.9/20_mz_283.0942.png
# Saved: output_0.1_score_0.9/21_mz_735.5735.png
# Saved: output_0.1_score_0.9/22_mz_257.2299.png
# Saved: output_0.1_score_0.9/23_mz_734.5673.png
# Saved: output_0.1_score_0.9/24_mz_736.5804.png
# Saved: output_0.1_score_0.9/25_mz_255.2101.png
# Saved: output_0.1_score_0.9/26_mz_809.5828.png
# Saved: output_0.1_score_0.9/27_mz_327.2354.png
# Saved: output_0.1_score_0.9/28_mz_731.6000.png
# Saved: output_0.1_score_0.9/29_mz_247.2447.png
# Saved: output_0.1_score_0.9/30_mz_932.5598.png
# Saved: output_0.1_score_0.9/31_mz_762.5918.png
# Saved: output_0.1_score_0.9/32_mz_732.6042.png
# Saved: output_0.1_score_0.9/33_mz_161.1338.png
# Saved: output_0.1_score_0.9/34_mz_651.5335.png
# Saved: output_0.1_score_0.9/35_mz_763.6049.png
# Saved: output_0.1_score_0.9/36_mz_264.1099.png
# Saved: output_0.1_score_0.9/37_mz_427.9302.png
# Saved: output_0.1_score_0.9/38_mz_385.2707.png
# Saved: output_0.1_score_0.9/39_mz_428.9334.png
# Saved: output_0.1_score_0.9/40_mz_215.1771.png
# Saved: output_0.1_score_0.9/41_mz_758.5699.png
# Saved: output_0.1_score_0.9/42_mz_326.3040.png
# Saved: output_0.1_score_0.9/43_mz_354.3367.png
# Saved: output_0.1_score_0.9/44_mz_652.5370.png
# Saved: output_0.1_score_0.9/45_mz_313.2732.png
# Saved: output_0.1_score_0.9/46_mz_353.3347.png
# Saved: output_0.1_score_0.9/47_mz_756.5510.png
# Saved: output_0.1_score_0.9/48_mz_757.5601.png
# Saved: output_0.1_score_0.9/49_mz_346.0598.png
# Saved: output_0.1_score_0.9/50_mz_398.3291.png
# Saved: output_0.1_score_0.9/51_mz_759.5684.png
# Saved: output_0.1_score_0.9/52_mz_760.5916.png
# Saved: output_0.1_score_0.9/53_mz_761.5914.png
# Saved: output_0.1_score_0.9/54_mz_626.5129.png
# Saved: output_0.1_score_0.9/55_mz_406.9501.png
# Saved: output_0.1_score_0.9/56_mz_350.0839.png
# Saved: output_0.1_score_0.9/57_mz_356.3532.png
# Saved: output_0.1_score_0.9/58_mz_733.5854.png
# Saved: output_0.1_score_0.9/59_mz_407.9548.png
# Saved: output_0.1_score_0.9/60_mz_625.5188.png
# Saved: output_0.1_score_0.9/61_mz_784.5720.png
# Saved: output_0.1_score_0.9/62_mz_361.2742.png
# Saved: output_0.1_score_0.9/63_mz_240.0953.png
# Saved: output_0.1_score_0.9/64_mz_404.9267.png
# Saved: output_0.1_score_0.9/65_mz_282.2793.png
# Saved: output_0.1_score_0.9/66_mz_774.9400.png
# Saved: output_0.1_score_0.9/67_mz_508.2855.png
# Saved: output_0.1_score_0.9/68_mz_783.5694.png
# Saved: output_0.1_score_0.9/69_mz_136.0608.png
# Saved: output_0.1_score_0.9/70_mz_386.2827.png
# Saved: output_0.1_score_0.9/71_mz_251.9214.png
# Saved: output_0.1_score_0.9/72_mz_482.3231.png
# Saved: output_0.1_score_0.9/73_mz_502.2887.png
# Saved: output_0.1_score_0.9/74_mz_184.0720.png
# Saved: output_0.1_score_0.9/75_mz_252.9273.png
# Saved: output_0.1_score_0.9/76_mz_718.5380.png
# Saved: output_0.1_score_0.9/77_mz_785.5751.png
# Saved: output_0.1_score_0.9/78_mz_389.3006.png
# Saved: output_0.1_score_0.9/79_mz_269.1003.png
# Saved: output_0.1_score_0.9/80_mz_600.9327.png
# Saved: output_0.1_score_0.9/81_mz_526.2990.png
# Saved: output_0.1_score_0.9/82_mz_623.5002.png
# Saved: output_0.1_score_0.9/83_mz_653.5411.png
# Saved: output_0.1_score_0.9/84_mz_768.5477.png
# Saved: output_0.1_score_0.9/85_mz_782.5675.png
# Saved: output_0.1_score_0.9/86_mz_627.5297.png
# Saved: output_0.1_score_0.9/87_mz_750.5461.png
# Saved: output_0.1_score_0.9/88_mz_597.9289.png
# Saved: output_0.1_score_0.9/89_mz_958.5659.png
# Saved: output_0.1_score_0.9/90_mz_792.5538.png
# Saved: output_0.1_score_0.9/91_mz_655.5630.png
# Saved: output_0.1_score_0.9/92_mz_836.5261.png
# Saved: output_0.1_score_0.9/93_mz_366.1371.png
# Saved: output_0.1_score_0.9/94_mz_754.5827.png
# Saved: output_0.1_score_0.9/95_mz_599.9377.png
# Saved: output_0.1_score_0.9/96_mz_518.3260.png
# Saved: output_0.1_score_0.9/97_mz_753.5875.png
# Saved: output_0.1_score_0.9/98_mz_229.9417.png
# Saved: output_0.1_score_0.9/99_mz_725.5188.png
# Saved: output_0.1_score_0.9/100_mz_764.6067.png
# Saved: output_0.1_score_0.9/101_mz_598.9329.png
# Saved: output_0.1_score_0.9/102_mz_746.5800.png
# Saved: output_0.1_score_0.9/103_mz_749.5297.png
# Saved: output_0.1_score_0.9/104_mz_230.9492.png
# Saved: output_0.1_score_0.9/105_mz_628.5364.png
# Saved: output_0.1_score_0.9/106_mz_231.9456.png
# Saved: output_0.1_score_0.9/107_mz_548.5356.png
# Saved: output_0.1_score_0.9/108_mz_264.2661.png
# Saved: output_0.1_score_0.9/109_mz_464.3135.png
# Saved: output_0.1_score_0.9/110_mz_203.2236.png
# Saved: output_0.1_score_0.9/111_mz_649.5179.png
# Saved: output_0.1_score_0.9/112_mz_397.3363.png
# Saved: output_0.1_score_0.9/113_mz_224.1000.png
# Saved: output_0.1_score_0.9/114_mz_549.5485.png
# Saved: output_0.1_score_0.9/115_mz_232.9441.png
# Saved: output_0.1_score_0.9/116_mz_222.0783.png
# Saved: output_0.1_score_0.9/117_mz_629.5439.png
# Saved: output_0.1_score_0.9/118_mz_242.1088.png
# Saved: output_0.1_score_0.9/119_mz_355.3483.png
# Saved: output_0.1_score_0.9/120_mz_408.0254.png
# Saved: output_0.1_score_0.9/121_mz_443.9010.png
# Saved: output_0.1_score_0.9/122_mz_444.9043.png
# Saved: output_0.1_score_0.9/123_mz_635.5397.png
# Saved: output_0.1_score_0.9/124_mz_268.1057.png
# Saved: output_0.1_score_0.9/125_mz_352.3177.png
# Saved: output_0.1_score_0.9/126_mz_765.5245.png
# Saved: output_0.1_score_0.9/127_mz_776.5574.png
# Saved: output_0.1_score_0.9/128_mz_786.6035.png
# Saved: output_0.1_score_0.9/129_mz_793.5621.png
# Saved: output_0.1_score_0.9/130_mz_424.9368.png
# Saved: output_0.1_score_0.9/131_mz_396.3100.png
# Saved: output_0.1_score_0.9/132_mz_752.5570.png
# Saved: output_0.1_score_0.9/133_mz_837.5366.png
# Saved: output_0.1_score_0.9/134_mz_966.9248.png
# Saved: output_0.1_score_0.9/135_mz_348.0689.png
# Saved: output_0.1_score_0.9/136_mz_790.5270.png
# Saved: output_0.1_score_0.9/137_mz_787.5956.png
# Saved: output_0.1_score_0.9/138_mz_764.5222.png
# Saved: output_0.1_score_0.9/139_mz_724.5195.png
# Saved: output_0.1_score_0.9/140_mz_747.5825.png
# Saved: output_0.1_score_0.9/141_mz_748.5259.png
# Saved: output_0.1_score_0.9/142_mz_258.1130.png
# Saved: output_0.1_score_0.9/143_mz_744.5532.png
# Saved: output_0.1_score_0.9/144_mz_751.5392.png
# Saved: output_0.1_score_0.9/145_mz_804.5468.png
# Saved: output_0.1_score_0.9/146_mz_250.0883.png
# Saved: output_0.1_score_0.9/147_mz_606.5544.png
# Saved: output_0.1_score_0.9/148_mz_729.5701.png
# Saved: output_0.1_score_0.9/149_mz_466.3291.png
# Saved: output_0.1_score_0.9/150_mz_422.9320.png
# Saved: output_0.1_score_0.9/151_mz_812.5920.png
# Saved: output_0.1_score_0.9/152_mz_790.9199.png
# Saved: output_0.1_score_0.9/153_mz_611.5435.png
# Saved: output_0.1_score_0.9/154_mz_835.6044.png
# Saved: output_0.1_score_0.9/155_mz_794.5587.png
# Saved: output_0.1_score_0.9/156_mz_634.6154.png
# Saved: output_0.1_score_0.9/157_mz_464.0783.png
# Saved: output_0.1_score_0.9/158_mz_720.5643.png
# Saved: output_0.1_score_0.9/159_mz_926.5427.png
# Saved: output_0.1_score_0.9/160_mz_810.6019.png
# Saved: output_0.1_score_0.9/161_mz_778.5663.png
# Saved: output_0.1_score_0.9/162_mz_198.1210.png
# Saved: output_0.1_score_0.9/163_mz_284.2929.png
# Saved: output_0.1_score_0.9/164_mz_811.5966.png
# Saved: output_0.1_score_0.9/165_mz_614.9061.png
# Saved: output_0.1_score_0.9/166_mz_805.5502.png
# Saved: output_0.1_score_0.9/167_mz_766.5276.png
# Saved: output_0.1_score_0.9/168_mz_834.5950.png
# Saved: output_0.1_score_0.9/169_mz_270.1184.png
# Saved: output_0.1_score_0.9/170_mz_664.1207.png
# Saved: output_0.1_score_0.9/171_mz_564.2518.png
# Saved: output_0.1_score_0.9/172_mz_948.5346.png
# Saved: output_0.1_score_0.9/173_mz_280.0902.png
# Saved: output_0.1_score_0.9/174_mz_587.5433.png
# Saved: output_0.1_score_0.9/175_mz_267.8913.png
# Saved: output_0.1_score_0.9/176_mz_268.8998.png
# Saved: output_0.1_score_0.9/177_mz_788.6130.png
# Saved: output_0.1_score_0.9/178_mz_605.5548.png
# Saved: output_0.1_score_0.9/179_mz_790.6252.png
# Saved: output_0.1_score_0.9/180_mz_1495.1523.png
# Saved: output_0.1_score_0.9/181_mz_702.5467.png
# Saved: output_0.1_score_0.9/182_mz_728.5562.png
# Saved: output_0.1_score_0.9/183_mz_789.6188.png
# Saved: output_0.1_score_0.9/184_mz_602.0143.png
# Saved: output_0.1_score_0.9/185_mz_847.5362.png
# Saved: output_0.1_score_0.9/186_mz_542.0715.png
# Saved: output_0.1_score_0.9/187_mz_791.5339.png
# Saved: output_0.1_score_0.9/188_mz_777.5555.png
# Saved: output_0.1_score_0.9/189_mz_630.6179.png
# Saved: output_0.1_score_0.9/190_mz_1494.1565.png
# Saved: output_0.1_score_0.9/191_mz_846.5322.png
# Saved: output_0.1_score_0.9/192_mz_697.4753.png
# Saved: output_0.1_score_0.9/193_mz_402.0237.png
# Saved: output_0.1_score_0.9/194_mz_423.9832.png
# Saved: output_0.1_score_0.9/195_mz_201.9372.png
# Saved: output_0.1_score_0.9/196_mz_621.6046.png
# Saved: output_0.1_score_0.9/197_mz_812.5174.png
# Saved: output_0.1_score_0.9/198_mz_534.2923.png
# Saved: output_0.1_score_0.9/199_mz_815.5320.png
# Saved: output_0.1_score_0.9/200_mz_631.6271.png
# Saved: output_0.1_score_0.9/201_mz_702.0723.png
# Saved: output_0.1_score_0.9/202_mz_836.6271.png
# Saved: output_0.1_score_0.9/203_mz_832.5781.png
# Saved: output_0.1_score_0.9/204_mz_974.5565.png
# Saved: output_0.1_score_0.9/205_mz_222.0327.png
# Saved: output_0.1_score_0.9/206_mz_730.5729.png
# Saved: output_0.1_score_0.9/207_mz_1520.1588.png
# Saved: output_0.1_score_0.9/208_mz_833.5862.png
# Saved: output_0.1_score_0.9/209_mz_1522.1682.png
# Saved: output_0.1_score_0.9/210_mz_620.6035.png
# Saved: output_0.1_score_0.9/211_mz_580.0320.png
# Saved: output_0.1_score_0.9/212_mz_646.6168.png
# Saved: output_0.1_score_0.9/213_mz_740.4961.png
# Saved: output_0.1_score_0.9/214_mz_339.2947.png
# Saved: output_0.1_score_0.9/215_mz_551.5052.png
# Saved: output_0.1_score_0.9/216_mz_975.5518.png
# Saved: output_0.1_score_0.9/217_mz_648.6279.png
# Saved: output_0.1_score_0.9/218_mz_834.5319.png
# Saved: output_0.1_score_0.9/219_mz_767.5312.png
# Saved: output_0.1_score_0.9/220_mz_780.5778.png
# Saved: output_0.1_score_0.9/221_mz_966.5311.png
# Saved: output_0.1_score_0.9/222_mz_897.4819.png
# Saved: output_0.1_score_0.9/223_mz_1544.1542.png
# Saved: output_0.1_score_0.9/224_mz_1521.1633.png
# Saved: output_0.1_score_0.9/225_mz_875.4991.png
# Saved: output_0.1_score_0.9/226_mz_814.5224.png
# Saved: output_0.1_score_0.9/227_mz_775.5356.png
# Saved: output_0.1_score_0.9/228_mz_858.5287.png
# Saved: output_0.1_score_0.9/229_mz_808.5023.png
# Saved: output_0.1_score_0.9/230_mz_950.5529.png
# Saved: output_0.1_score_0.9/231_mz_781.5784.png
# Saved: output_0.1_score_0.9/232_mz_813.5133.png
# Saved: output_0.1_score_0.9/233_mz_801.5524.png
# Saved: output_0.1_score_0.9/234_mz_782.6530.png
# Saved: output_0.1_score_0.9/235_mz_802.5665.png
# Saved: output_0.1_score_0.9/236_mz_774.5268.png
# Saved: output_0.1_score_0.9/237_mz_828.5011.png
# Saved: output_0.1_score_0.9/238_mz_560.0797.png
# Saved: output_0.1_score_0.9/239_mz_617.9849.png
# Saved: output_0.1_score_0.9/240_mz_876.5071.png
# Saved: output_0.1_score_0.9/241_mz_832.6662.png
# Saved: output_0.1_score_0.9/242_mz_770.5583.png
# Saved: output_0.1_score_0.9/243_mz_808.6637.png
# Saved: output_0.1_score_0.9/244_mz_788.5027.png
# Saved: output_0.1_score_0.9/245_mz_1542.1475.png
# Saved: output_0.1_score_0.9/246_mz_560.3174.png
# Saved: output_0.1_score_0.9/247_mz_816.5298.png
# Saved: output_0.1_score_0.9/248_mz_792.6645.png
# Saved: output_0.1_score_0.9/249_mz_828.5639.png
# Saved: output_0.1_score_0.9/250_mz_822.5297.png
# Saved: output_0.1_score_0.9/251_mz_925.5197.png
# Saved: output_0.1_score_0.9/252_mz_579.5273.png
# Saved: output_0.1_score_0.9/253_mz_874.5046.png
# Saved: output_0.1_score_0.9/254_mz_762.4953.png
# Saved: output_0.1_score_0.9/255_mz_896.4880.png
# Saved: output_0.1_score_0.9/256_mz_802.4798.png
# Saved: output_0.1_score_0.9/257_mz_856.5085.png
# Saved: output_0.1_score_0.9/258_mz_830.5131.png
# Saved: output_0.1_score_0.9/259_mz_831.5201.png
# Saved: output_0.1_score_0.9/260_mz_837.6503.png
# Saved: output_0.1_score_0.9/261_mz_818.5523.png
# Saved: output_0.1_score_0.9/262_mz_800.5515.png
# Saved: output_0.1_score_0.9/263_mz_771.5526.png
# Saved: output_0.1_score_0.9/264_mz_480.3211.png
# Saved: output_0.1_score_0.9/265_mz_786.4932.png
# Saved: output_0.1_score_0.9/266_mz_789.4961.png
# Saved: output_0.1_score_0.9/267_mz_778.4689.png
# Saved: output_0.1_score_0.9/268_mz_773.5307.png
# Saved: output_0.1_score_0.9/269_mz_829.5068.png
# Saved: output_0.1_score_0.9/270_mz_832.5150.png
# Saved: output_0.1_score_0.9/271_mz_296.0663.png
# Saved: output_0.1_score_0.9/272_mz_799.5511.png
# Saved: output_0.1_score_0.9/273_mz_723.4974.png
# Saved: output_0.1_score_0.9/274_mz_578.5188.png
# Saved: output_0.1_score_0.9/275_mz_562.3243.png
# Saved: output_0.1_score_0.9/276_mz_805.4882.png
# Saved: output_0.1_score_0.9/277_mz_804.4848.png
# Saved: output_0.1_score_0.9/278_mz_769.5648.png
# Saved: output_0.1_score_0.9/279_mz_822.6423.png
# Saved: output_0.1_score_0.9/280_mz_742.5174.png
# Saved: output_0.1_score_0.9/281_mz_796.5415.png
# Saved: output_0.1_score_0.9/282_mz_820.5273.png
# Saved: output_0.1_score_0.9/283_mz_964.4960.png
# Saved: output_0.1_score_0.9/284_mz_798.5391.png
# Saved: output_0.1_score_0.9/285_mz_821.5281.png
# Saved: output_0.1_score_0.9/286_mz_806.5172.png
# Saved: output_0.1_score_0.9/287_mz_772.5231.png
# Saved: output_0.1_score_0.9/288_mz_826.4664.png
# Saved: output_0.1_score_0.9/289_mz_824.5594.png
# Saved: output_0.1_score_0.9/290_mz_810.6888.png
# Saved: output_0.1_score_0.9/291_mz_741.4946.png
# Saved: output_0.1_score_0.9/292_mz_787.4854.png
# Saved: output_0.1_score_0.9/293_mz_852.4881.png
# Saved: output_0.1_score_0.9/294_mz_854.4907.png
# Saved: output_0.1_score_0.9/295_mz_807.5094.png
# Saved: output_0.1_score_0.9/296_mz_912.4556.png
# Saved: output_0.1_score_0.9/297_mz_873.5623.png
# Saved: output_0.1_score_0.9/298_mz_844.5262.png
# Saved: output_0.1_score_0.9/299_mz_577.5215.png
# Saved: output_0.1_score_0.9/300_mz_872.5560.png
# Saved: output_0.1_score_0.9/301_mz_825.5629.png
# Saved: output_0.1_score_0.9/302_mz_963.4792.png
# Saved: output_0.1_score_0.9/303_mz_850.4877.png
# Saved: output_0.1_score_0.9/304_mz_845.5290.png
# Saved: output_0.1_score_0.9/305_mz_522.3597.png
# Saved: output_0.1_score_0.9/306_mz_797.5770.png
# Saved: output_0.1_score_0.9/307_mz_826.5668.png
# Saved: output_0.1_score_0.9/308_mz_827.5714.png
# Saved: output_0.1_score_0.9/309_mz_714.4474.png
# Saved: output_0.1_score_0.9/310_mz_840.4328.png
# Saved: output_0.1_score_0.9/311_mz_823.6320.png
# Saved: output_0.1_score_0.9/312_mz_599.4994.png
# Saved: output_0.1_score_0.9/313_mz_913.4582.png
# Saved: output_0.1_score_0.9/314_mz_850.5641.png
# Saved: output_0.1_score_0.9/315_mz_824.4467.png
# Saved: output_0.1_score_0.9/316_mz_870.4678.png
# Saved: output_0.1_score_0.9/317_mz_850.6533.png
# Saved: output_0.1_score_0.9/318_mz_849.5585.png
# Saved: output_0.1_score_0.9/319_mz_604.5345.png
# Saved: output_0.1_score_0.9/320_mz_853.4827.png
# Saved: output_0.1_score_0.9/321_mz_713.4442.png
# Saved: output_0.1_score_0.9/322_mz_866.4661.png
# Saved: output_0.1_score_0.9/323_mz_853.6358.png
# Saved: output_0.1_score_0.9/324_mz_868.4722.png
# Saved: output_0.1_score_0.9/325_mz_848.5533.png
# Saved: output_0.1_score_0.9/326_mz_851.6469.png
# Saved: output_0.1_score_0.9/327_mz_739.4628.png
# Saved: output_0.1_score_0.9/328_mz_869.4633.png
# Saved: output_0.1_score_0.9/329_mz_603.5365.png
# Saved: output_0.1_score_0.9/330_mz_865.6309.png
# Saved: output_0.1_score_0.9/331_mz_849.6475.png
# Saved: output_0.1_score_0.9/332_mz_710.4850.png
# Saved: output_0.1_score_0.9/333_mz_848.6424.png
# Saved: output_0.1_score_0.9/334_mz_840.6227.png
# Saved: output_0.1_score_0.9/335_mz_852.6411.png
# Saved: output_0.1_score_0.9/336_mz_867.6489.png
# Saved: output_0.1_score_0.9/337_mz_839.6229.png
# Saved: output_0.1_score_0.9/338_mz_838.6237.png
# Saved: output_0.1_score_0.9/339_mz_866.6460.png
# Saved: output_0.1_score_0.9/340_mz_864.6292.png
# Saved: output_0.1_score_0.91/1_mz_180.0717.png
# Saved: output_0.1_score_0.91/2_mz_370.3516.png
# Saved: output_0.1_score_0.91/3_mz_367.3328.png
# Saved: output_0.1_score_0.91/4_mz_371.3606.png
# Saved: output_0.1_score_0.91/5_mz_369.3523.png
# Saved: output_0.1_score_0.91/6_mz_284.0794.png
# Saved: output_0.1_score_0.91/7_mz_368.3461.png
# Saved: output_0.1_score_0.91/8_mz_341.3084.png
# Saved: output_0.1_score_0.91/9_mz_385.3478.png
# Saved: output_0.1_score_0.91/10_mz_243.2107.png
# Saved: output_0.1_score_0.91/11_mz_185.0686.png
# Saved: output_0.1_score_0.91/12_mz_365.3188.png
# Saved: output_0.1_score_0.91/13_mz_328.3184.png
# Saved: output_0.1_score_0.91/14_mz_383.3277.png
# Saved: output_0.1_score_0.91/15_mz_386.3513.png
# Saved: output_0.1_score_0.91/16_mz_808.5768.png
# Saved: output_0.1_score_0.91/17_mz_366.3293.png
# Saved: output_0.1_score_0.91/18_mz_384.3286.png
# Saved: output_0.1_score_0.91/19_mz_256.0827.png
# Saved: output_0.1_score_0.91/20_mz_283.0942.png
# Saved: output_0.1_score_0.91/21_mz_735.5735.png
# Saved: output_0.1_score_0.91/22_mz_734.5673.png
# Saved: output_0.1_score_0.91/23_mz_257.2299.png
# Saved: output_0.1_score_0.91/24_mz_736.5804.png
# Saved: output_0.1_score_0.91/25_mz_809.5828.png
# Saved: output_0.1_score_0.91/26_mz_255.2101.png
# Saved: output_0.1_score_0.91/27_mz_327.2354.png
# Saved: output_0.1_score_0.91/28_mz_731.6000.png
# Saved: output_0.1_score_0.91/29_mz_762.5918.png
# Saved: output_0.1_score_0.91/30_mz_932.5598.png
# Saved: output_0.1_score_0.91/31_mz_247.2447.png
# Saved: output_0.1_score_0.91/32_mz_732.6042.png
# Saved: output_0.1_score_0.91/33_mz_651.5335.png
# Saved: output_0.1_score_0.91/34_mz_161.1338.png
# Saved: output_0.1_score_0.91/35_mz_763.6049.png
# Saved: output_0.1_score_0.91/36_mz_264.1099.png
# Saved: output_0.1_score_0.91/37_mz_427.9302.png
# Saved: output_0.1_score_0.91/38_mz_385.2707.png
# Saved: output_0.1_score_0.91/39_mz_428.9334.png
# Saved: output_0.1_score_0.91/40_mz_215.1771.png
# Saved: output_0.1_score_0.91/41_mz_758.5699.png
# Saved: output_0.1_score_0.91/42_mz_326.3040.png
# Saved: output_0.1_score_0.91/43_mz_652.5370.png
# Saved: output_0.1_score_0.91/44_mz_354.3367.png
# Saved: output_0.1_score_0.91/45_mz_313.2732.png
# Saved: output_0.1_score_0.91/46_mz_756.5510.png
# Saved: output_0.1_score_0.91/47_mz_353.3347.png
# Saved: output_0.1_score_0.91/48_mz_757.5601.png
# Saved: output_0.1_score_0.91/49_mz_760.5916.png
# Saved: output_0.1_score_0.91/50_mz_759.5684.png
# Saved: output_0.1_score_0.91/51_mz_346.0598.png
# Saved: output_0.1_score_0.91/52_mz_398.3291.png
# Saved: output_0.1_score_0.91/53_mz_761.5914.png
# Saved: output_0.1_score_0.91/54_mz_406.9501.png
# Saved: output_0.1_score_0.91/55_mz_626.5129.png
# Saved: output_0.1_score_0.91/56_mz_350.0839.png
# Saved: output_0.1_score_0.91/57_mz_407.9548.png
# Saved: output_0.1_score_0.91/58_mz_733.5854.png
# Saved: output_0.1_score_0.91/59_mz_356.3532.png
# Saved: output_0.1_score_0.91/60_mz_625.5188.png
# Saved: output_0.1_score_0.91/61_mz_784.5720.png
# Saved: output_0.1_score_0.91/62_mz_361.2742.png
# Saved: output_0.1_score_0.91/63_mz_240.0953.png
# Saved: output_0.1_score_0.91/64_mz_404.9267.png
# Saved: output_0.1_score_0.91/65_mz_282.2793.png
# Saved: output_0.1_score_0.91/66_mz_774.9400.png
# Saved: output_0.1_score_0.91/67_mz_508.2855.png
# Saved: output_0.1_score_0.91/68_mz_783.5694.png
# Saved: output_0.1_score_0.91/69_mz_136.0608.png
# Saved: output_0.1_score_0.91/70_mz_386.2827.png
# Saved: output_0.1_score_0.91/71_mz_251.9214.png
# Saved: output_0.1_score_0.91/72_mz_502.2887.png
# Saved: output_0.1_score_0.91/73_mz_482.3231.png
# Saved: output_0.1_score_0.91/74_mz_184.0720.png
# Saved: output_0.1_score_0.91/75_mz_252.9273.png
# Saved: output_0.1_score_0.91/76_mz_389.3006.png
# Saved: output_0.1_score_0.91/77_mz_718.5380.png
# Saved: output_0.1_score_0.91/78_mz_785.5751.png
# Saved: output_0.1_score_0.91/79_mz_269.1003.png
# Saved: output_0.1_score_0.91/80_mz_600.9327.png
# Saved: output_0.1_score_0.91/81_mz_526.2990.png
# Saved: output_0.1_score_0.91/82_mz_623.5002.png
# Saved: output_0.1_score_0.91/83_mz_653.5411.png
# Saved: output_0.1_score_0.91/84_mz_768.5477.png
# Saved: output_0.1_score_0.91/85_mz_782.5675.png
# Saved: output_0.1_score_0.91/86_mz_627.5297.png
# Saved: output_0.1_score_0.91/87_mz_750.5461.png
# Saved: output_0.1_score_0.91/88_mz_597.9289.png
# Saved: output_0.1_score_0.91/89_mz_792.5538.png
# Saved: output_0.1_score_0.91/90_mz_655.5630.png
# Saved: output_0.1_score_0.91/91_mz_958.5659.png
# Saved: output_0.1_score_0.91/92_mz_836.5261.png
# Saved: output_0.1_score_0.91/93_mz_366.1371.png
# Saved: output_0.1_score_0.91/94_mz_754.5827.png
# Saved: output_0.1_score_0.91/95_mz_599.9377.png
# Saved: output_0.1_score_0.91/96_mz_518.3260.png
# Saved: output_0.1_score_0.91/97_mz_229.9417.png
# Saved: output_0.1_score_0.91/98_mz_725.5188.png
# Saved: output_0.1_score_0.91/99_mz_753.5875.png
# Saved: output_0.1_score_0.91/100_mz_764.6067.png
# Saved: output_0.1_score_0.91/101_mz_598.9329.png
# Saved: output_0.1_score_0.91/102_mz_746.5800.png
# Saved: output_0.1_score_0.91/103_mz_749.5297.png
# Saved: output_0.1_score_0.91/104_mz_230.9492.png
# Saved: output_0.1_score_0.91/105_mz_628.5364.png
# Saved: output_0.1_score_0.91/106_mz_231.9456.png
# Saved: output_0.1_score_0.91/107_mz_548.5356.png
# Saved: output_0.1_score_0.91/108_mz_264.2661.png
# Saved: output_0.1_score_0.91/109_mz_203.2236.png
# Saved: output_0.1_score_0.91/110_mz_464.3135.png
# Saved: output_0.1_score_0.91/111_mz_649.5179.png
# Saved: output_0.1_score_0.91/112_mz_224.1000.png
# Saved: output_0.1_score_0.91/113_mz_397.3363.png
# Saved: output_0.1_score_0.91/114_mz_232.9441.png
# Saved: output_0.1_score_0.91/115_mz_549.5485.png
# Saved: output_0.1_score_0.91/116_mz_629.5439.png
# Saved: output_0.1_score_0.91/117_mz_222.0783.png
# Saved: output_0.1_score_0.91/118_mz_242.1088.png
# Saved: output_0.1_score_0.91/119_mz_443.9010.png
# Saved: output_0.1_score_0.91/120_mz_408.0254.png
# Saved: output_0.1_score_0.91/121_mz_444.9043.png
# Saved: output_0.1_score_0.91/122_mz_355.3483.png
# Saved: output_0.1_score_0.91/123_mz_635.5397.png
# Saved: output_0.1_score_0.91/124_mz_268.1057.png
# Saved: output_0.1_score_0.91/125_mz_765.5245.png
# Saved: output_0.1_score_0.91/126_mz_776.5574.png
# Saved: output_0.1_score_0.91/127_mz_786.6035.png
# Saved: output_0.1_score_0.91/128_mz_352.3177.png
# Saved: output_0.1_score_0.91/129_mz_793.5621.png
# Saved: output_0.1_score_0.91/130_mz_424.9368.png
# Saved: output_0.1_score_0.91/131_mz_752.5570.png
# Saved: output_0.1_score_0.91/132_mz_837.5366.png
# Saved: output_0.1_score_0.91/133_mz_966.9248.png
# Saved: output_0.1_score_0.91/134_mz_396.3100.png
# Saved: output_0.1_score_0.91/135_mz_348.0689.png
# Saved: output_0.1_score_0.91/136_mz_790.5270.png
# Saved: output_0.1_score_0.91/137_mz_787.5956.png
# Saved: output_0.1_score_0.91/138_mz_764.5222.png
# Saved: output_0.1_score_0.91/139_mz_724.5195.png
# Saved: output_0.1_score_0.91/140_mz_747.5825.png
# Saved: output_0.1_score_0.91/141_mz_748.5259.png
# Saved: output_0.1_score_0.91/142_mz_258.1130.png
# Saved: output_0.1_score_0.91/143_mz_744.5532.png
# Saved: output_0.1_score_0.91/144_mz_751.5392.png
# Saved: output_0.1_score_0.91/145_mz_804.5468.png
# Saved: output_0.1_score_0.91/146_mz_250.0883.png
# Saved: output_0.1_score_0.91/147_mz_606.5544.png
# Saved: output_0.1_score_0.91/148_mz_729.5701.png
# Saved: output_0.1_score_0.91/149_mz_466.3291.png
# Saved: output_0.1_score_0.91/150_mz_422.9320.png
# Saved: output_0.1_score_0.91/151_mz_812.5920.png
# Saved: output_0.1_score_0.91/152_mz_790.9199.png
# Saved: output_0.1_score_0.91/153_mz_835.6044.png
# Saved: output_0.1_score_0.91/154_mz_611.5435.png
# Saved: output_0.1_score_0.91/155_mz_794.5587.png
# Saved: output_0.1_score_0.91/156_mz_810.6019.png
# Saved: output_0.1_score_0.91/157_mz_720.5643.png
# Saved: output_0.1_score_0.91/158_mz_464.0783.png
# Saved: output_0.1_score_0.91/159_mz_634.6154.png
# Saved: output_0.1_score_0.91/160_mz_778.5663.png
# Saved: output_0.1_score_0.91/161_mz_926.5427.png
# Saved: output_0.1_score_0.91/162_mz_198.1210.png
# Saved: output_0.1_score_0.91/163_mz_811.5966.png
# Saved: output_0.1_score_0.91/164_mz_284.2929.png
# Saved: output_0.1_score_0.91/165_mz_614.9061.png
# Saved: output_0.1_score_0.91/166_mz_805.5502.png
# Saved: output_0.1_score_0.91/167_mz_766.5276.png
# Saved: output_0.1_score_0.91/168_mz_834.5950.png
# Saved: output_0.1_score_0.91/169_mz_270.1184.png
# Saved: output_0.1_score_0.91/170_mz_564.2518.png
# Saved: output_0.1_score_0.91/171_mz_664.1207.png
# Saved: output_0.1_score_0.91/172_mz_948.5346.png
# Saved: output_0.1_score_0.91/173_mz_280.0902.png
# Saved: output_0.1_score_0.91/174_mz_587.5433.png
# Saved: output_0.1_score_0.91/175_mz_267.8913.png
# Saved: output_0.1_score_0.91/176_mz_788.6130.png
# Saved: output_0.1_score_0.91/177_mz_268.8998.png
# Saved: output_0.1_score_0.91/178_mz_605.5548.png
# Saved: output_0.1_score_0.91/179_mz_790.6252.png
# Saved: output_0.1_score_0.91/180_mz_1495.1523.png
# Saved: output_0.1_score_0.91/181_mz_789.6188.png
# Saved: output_0.1_score_0.91/182_mz_728.5562.png
# Saved: output_0.1_score_0.91/183_mz_702.5467.png
# Saved: output_0.1_score_0.91/184_mz_847.5362.png
# Saved: output_0.1_score_0.91/185_mz_602.0143.png
# Saved: output_0.1_score_0.91/186_mz_791.5339.png
# Saved: output_0.1_score_0.91/187_mz_542.0715.png
# Saved: output_0.1_score_0.91/188_mz_777.5555.png
# Saved: output_0.1_score_0.91/189_mz_630.6179.png
# Saved: output_0.1_score_0.91/190_mz_1494.1565.png
# Saved: output_0.1_score_0.91/191_mz_846.5322.png
# Saved: output_0.1_score_0.91/192_mz_697.4753.png
# Saved: output_0.1_score_0.91/193_mz_402.0237.png
# Saved: output_0.1_score_0.91/194_mz_423.9832.png
# Saved: output_0.1_score_0.91/195_mz_201.9372.png
# Saved: output_0.1_score_0.91/196_mz_534.2923.png
# Saved: output_0.1_score_0.91/197_mz_812.5174.png
# Saved: output_0.1_score_0.91/198_mz_621.6046.png
# Saved: output_0.1_score_0.91/199_mz_815.5320.png
# Saved: output_0.1_score_0.91/200_mz_702.0723.png
# Saved: output_0.1_score_0.91/201_mz_631.6271.png
# Saved: output_0.1_score_0.91/202_mz_836.6271.png
# Saved: output_0.1_score_0.91/203_mz_832.5781.png
# Saved: output_0.1_score_0.91/204_mz_974.5565.png
# Saved: output_0.1_score_0.91/205_mz_222.0327.png
# Saved: output_0.1_score_0.91/206_mz_730.5729.png
# Saved: output_0.1_score_0.91/207_mz_1520.1588.png
# Saved: output_0.1_score_0.91/208_mz_833.5862.png
# Saved: output_0.1_score_0.91/209_mz_1522.1682.png
# Saved: output_0.1_score_0.91/210_mz_620.6035.png
# Saved: output_0.1_score_0.91/211_mz_580.0320.png
# Saved: output_0.1_score_0.91/212_mz_740.4961.png
# Saved: output_0.1_score_0.91/213_mz_339.2947.png
# Saved: output_0.1_score_0.91/214_mz_646.6168.png
# Saved: output_0.1_score_0.91/215_mz_551.5052.png
# Saved: output_0.1_score_0.91/216_mz_975.5518.png
# Saved: output_0.1_score_0.91/217_mz_648.6279.png
# Saved: output_0.1_score_0.91/218_mz_834.5319.png
# Saved: output_0.1_score_0.91/219_mz_767.5312.png
# Saved: output_0.1_score_0.91/220_mz_780.5778.png
# Saved: output_0.1_score_0.91/221_mz_966.5311.png
# Saved: output_0.1_score_0.91/222_mz_897.4819.png
# Saved: output_0.1_score_0.91/223_mz_1521.1633.png
# Saved: output_0.1_score_0.91/224_mz_1544.1542.png
# Saved: output_0.1_score_0.91/225_mz_875.4991.png
# Saved: output_0.1_score_0.91/226_mz_814.5224.png
# Saved: output_0.1_score_0.91/227_mz_775.5356.png
# Saved: output_0.1_score_0.91/228_mz_858.5287.png
# Saved: output_0.1_score_0.91/229_mz_808.5023.png
# Saved: output_0.1_score_0.91/230_mz_801.5524.png
# Saved: output_0.1_score_0.91/231_mz_781.5784.png
# Saved: output_0.1_score_0.91/232_mz_813.5133.png
# Saved: output_0.1_score_0.91/233_mz_950.5529.png
# Saved: output_0.1_score_0.91/234_mz_802.5665.png
# Saved: output_0.1_score_0.91/235_mz_782.6530.png
# Saved: output_0.1_score_0.91/236_mz_774.5268.png
# Saved: output_0.1_score_0.91/237_mz_828.5011.png
# Saved: output_0.1_score_0.91/238_mz_770.5583.png
# Saved: output_0.1_score_0.91/239_mz_876.5071.png
# Saved: output_0.1_score_0.91/240_mz_560.0797.png
# Saved: output_0.1_score_0.91/241_mz_617.9849.png
# Saved: output_0.1_score_0.91/242_mz_788.5027.png
# Saved: output_0.1_score_0.91/243_mz_832.6662.png
# Saved: output_0.1_score_0.91/244_mz_808.6637.png
# Saved: output_0.1_score_0.91/245_mz_1542.1475.png
# Saved: output_0.1_score_0.91/246_mz_560.3174.png
# Saved: output_0.1_score_0.91/247_mz_816.5298.png
# Saved: output_0.1_score_0.91/248_mz_828.5639.png
# Saved: output_0.1_score_0.91/249_mz_822.5297.png
# Saved: output_0.1_score_0.91/250_mz_874.5046.png
# Saved: output_0.1_score_0.91/251_mz_792.6645.png
# Saved: output_0.1_score_0.91/252_mz_925.5197.png
# Saved: output_0.1_score_0.91/253_mz_896.4880.png
# Saved: output_0.1_score_0.91/254_mz_579.5273.png
# Saved: output_0.1_score_0.91/255_mz_802.4798.png
# Saved: output_0.1_score_0.91/256_mz_762.4953.png
# Saved: output_0.1_score_0.91/257_mz_830.5131.png
# Saved: output_0.1_score_0.91/258_mz_831.5201.png
# Saved: output_0.1_score_0.91/259_mz_800.5515.png
# Saved: output_0.1_score_0.91/260_mz_856.5085.png
# Saved: output_0.1_score_0.91/261_mz_818.5523.png
# Saved: output_0.1_score_0.91/262_mz_837.6503.png
# Saved: output_0.1_score_0.91/263_mz_771.5526.png
# Saved: output_0.1_score_0.91/264_mz_480.3211.png
# Saved: output_0.1_score_0.91/265_mz_786.4932.png
# Saved: output_0.1_score_0.91/266_mz_773.5307.png
# Saved: output_0.1_score_0.91/267_mz_789.4961.png
# Saved: output_0.1_score_0.91/268_mz_832.5150.png
# Saved: output_0.1_score_0.91/269_mz_778.4689.png
# Saved: output_0.1_score_0.91/270_mz_829.5068.png
# Saved: output_0.1_score_0.91/271_mz_799.5511.png
# Saved: output_0.1_score_0.91/272_mz_296.0663.png
# Saved: output_0.1_score_0.91/273_mz_578.5188.png
# Saved: output_0.1_score_0.91/274_mz_562.3243.png
# Saved: output_0.1_score_0.91/275_mz_723.4974.png
# Saved: output_0.1_score_0.91/276_mz_805.4882.png
# Saved: output_0.1_score_0.91/277_mz_769.5648.png
# Saved: output_0.1_score_0.91/278_mz_804.4848.png
# Saved: output_0.1_score_0.91/279_mz_742.5174.png
# Saved: output_0.1_score_0.91/280_mz_796.5415.png
# Saved: output_0.1_score_0.91/281_mz_820.5273.png
# Saved: output_0.1_score_0.91/282_mz_798.5391.png
# Saved: output_0.1_score_0.91/283_mz_821.5281.png
# Saved: output_0.1_score_0.91/284_mz_806.5172.png
# Saved: output_0.1_score_0.91/285_mz_822.6423.png
# Saved: output_0.1_score_0.91/286_mz_772.5231.png
# Saved: output_0.1_score_0.91/287_mz_964.4960.png
# Saved: output_0.1_score_0.91/288_mz_826.4664.png
# Saved: output_0.1_score_0.91/289_mz_824.5594.png
# Saved: output_0.1_score_0.91/290_mz_810.6888.png
# Saved: output_0.1_score_0.91/291_mz_741.4946.png
# Saved: output_0.1_score_0.91/292_mz_787.4854.png
# Saved: output_0.1_score_0.91/293_mz_852.4881.png
# Saved: output_0.1_score_0.91/294_mz_807.5094.png
# Saved: output_0.1_score_0.91/295_mz_854.4907.png
# Saved: output_0.1_score_0.91/296_mz_912.4556.png
# Saved: output_0.1_score_0.91/297_mz_844.5262.png
# Saved: output_0.1_score_0.91/298_mz_873.5623.png
# Saved: output_0.1_score_0.91/299_mz_577.5215.png
# Saved: output_0.1_score_0.91/300_mz_872.5560.png
# Saved: output_0.1_score_0.91/301_mz_825.5629.png
# Saved: output_0.1_score_0.91/302_mz_963.4792.png
# Saved: output_0.1_score_0.91/303_mz_850.4877.png
# Saved: output_0.1_score_0.91/304_mz_845.5290.png
# Saved: output_0.1_score_0.91/305_mz_522.3597.png
# Saved: output_0.1_score_0.91/306_mz_797.5770.png
# Saved: output_0.1_score_0.91/307_mz_826.5668.png
# Saved: output_0.1_score_0.91/308_mz_827.5714.png
# Saved: output_0.1_score_0.91/309_mz_714.4474.png
# Saved: output_0.1_score_0.91/310_mz_840.4328.png
# Saved: output_0.1_score_0.91/311_mz_823.6320.png
# Saved: output_0.1_score_0.91/312_mz_599.4994.png
# Saved: output_0.1_score_0.91/313_mz_913.4582.png
# Saved: output_0.1_score_0.91/314_mz_850.5641.png
# Saved: output_0.1_score_0.91/315_mz_824.4467.png
# Saved: output_0.1_score_0.91/316_mz_870.4678.png
# Saved: output_0.1_score_0.91/317_mz_849.5585.png
# Saved: output_0.1_score_0.91/318_mz_850.6533.png
# Saved: output_0.1_score_0.91/319_mz_853.4827.png
# Saved: output_0.1_score_0.91/320_mz_604.5345.png
# Saved: output_0.1_score_0.91/321_mz_713.4442.png
# Saved: output_0.1_score_0.91/322_mz_866.4661.png
# Saved: output_0.1_score_0.91/323_mz_868.4722.png
# Saved: output_0.1_score_0.91/324_mz_853.6358.png
# Saved: output_0.1_score_0.91/325_mz_848.5533.png
# Saved: output_0.1_score_0.91/326_mz_851.6469.png
# Saved: output_0.1_score_0.91/327_mz_739.4628.png
# Saved: output_0.1_score_0.91/328_mz_869.4633.png
# Saved: output_0.1_score_0.91/329_mz_603.5365.png
# Saved: output_0.1_score_0.91/330_mz_865.6309.png
# Saved: output_0.1_score_0.91/331_mz_849.6475.png
# Saved: output_0.1_score_0.91/332_mz_710.4850.png
# Saved: output_0.1_score_0.91/333_mz_852.6411.png
# Saved: output_0.1_score_0.91/334_mz_848.6424.png
# Saved: output_0.1_score_0.91/335_mz_840.6227.png
# Saved: output_0.1_score_0.91/336_mz_867.6489.png
# Saved: output_0.1_score_0.91/337_mz_839.6229.png
# Saved: output_0.1_score_0.91/338_mz_838.6237.png
# Saved: output_0.1_score_0.91/339_mz_866.6460.png
# Saved: output_0.1_score_0.91/340_mz_864.6292.png
# Saved: output_0.1_score_0.92/1_mz_180.0717.png
# Saved: output_0.1_score_0.92/2_mz_370.3516.png
# Saved: output_0.1_score_0.92/3_mz_367.3328.png
# Saved: output_0.1_score_0.92/4_mz_371.3606.png
# Saved: output_0.1_score_0.92/5_mz_369.3523.png
# Saved: output_0.1_score_0.92/6_mz_284.0794.png
# Saved: output_0.1_score_0.92/7_mz_368.3461.png
# Saved: output_0.1_score_0.92/8_mz_341.3084.png
# Saved: output_0.1_score_0.92/9_mz_385.3478.png
# Saved: output_0.1_score_0.92/10_mz_243.2107.png
# Saved: output_0.1_score_0.92/11_mz_185.0686.png
# Saved: output_0.1_score_0.92/12_mz_365.3188.png
# Saved: output_0.1_score_0.92/13_mz_328.3184.png
# Saved: output_0.1_score_0.92/14_mz_383.3277.png
# Saved: output_0.1_score_0.92/15_mz_386.3513.png
# Saved: output_0.1_score_0.92/16_mz_808.5768.png
# Saved: output_0.1_score_0.92/17_mz_366.3293.png
# Saved: output_0.1_score_0.92/18_mz_384.3286.png
# Saved: output_0.1_score_0.92/19_mz_256.0827.png
# Saved: output_0.1_score_0.92/20_mz_283.0942.png
# Saved: output_0.1_score_0.92/21_mz_735.5735.png
# Saved: output_0.1_score_0.92/22_mz_734.5673.png
# Saved: output_0.1_score_0.92/23_mz_257.2299.png
# Saved: output_0.1_score_0.92/24_mz_736.5804.png
# Saved: output_0.1_score_0.92/25_mz_809.5828.png
# Saved: output_0.1_score_0.92/26_mz_255.2101.png
# Saved: output_0.1_score_0.92/27_mz_731.6000.png
# Saved: output_0.1_score_0.92/28_mz_327.2354.png
# Saved: output_0.1_score_0.92/29_mz_762.5918.png
# Saved: output_0.1_score_0.92/30_mz_932.5598.png
# Saved: output_0.1_score_0.92/31_mz_247.2447.png
# Saved: output_0.1_score_0.92/32_mz_732.6042.png
# Saved: output_0.1_score_0.92/33_mz_651.5335.png
# Saved: output_0.1_score_0.92/34_mz_161.1338.png
# Saved: output_0.1_score_0.92/35_mz_763.6049.png
# Saved: output_0.1_score_0.92/36_mz_427.9302.png
# Saved: output_0.1_score_0.92/37_mz_264.1099.png
# Saved: output_0.1_score_0.92/38_mz_385.2707.png
# Saved: output_0.1_score_0.92/39_mz_428.9334.png
# Saved: output_0.1_score_0.92/40_mz_758.5699.png
# Saved: output_0.1_score_0.92/41_mz_215.1771.png
# Saved: output_0.1_score_0.92/42_mz_326.3040.png
# Saved: output_0.1_score_0.92/43_mz_652.5370.png
# Saved: output_0.1_score_0.92/44_mz_313.2732.png
# Saved: output_0.1_score_0.92/45_mz_354.3367.png
# Saved: output_0.1_score_0.92/46_mz_756.5510.png
# Saved: output_0.1_score_0.92/47_mz_757.5601.png
# Saved: output_0.1_score_0.92/48_mz_353.3347.png
# Saved: output_0.1_score_0.92/49_mz_760.5916.png
# Saved: output_0.1_score_0.92/50_mz_759.5684.png
# Saved: output_0.1_score_0.92/51_mz_398.3291.png
# Saved: output_0.1_score_0.92/52_mz_346.0598.png
# Saved: output_0.1_score_0.92/53_mz_761.5914.png
# Saved: output_0.1_score_0.92/54_mz_406.9501.png
# Saved: output_0.1_score_0.92/55_mz_626.5129.png
# Saved: output_0.1_score_0.92/56_mz_350.0839.png
# Saved: output_0.1_score_0.92/57_mz_407.9548.png
# Saved: output_0.1_score_0.92/58_mz_733.5854.png
# Saved: output_0.1_score_0.92/59_mz_356.3532.png
# Saved: output_0.1_score_0.92/60_mz_625.5188.png
# Saved: output_0.1_score_0.92/61_mz_784.5720.png
# Saved: output_0.1_score_0.92/62_mz_361.2742.png
# Saved: output_0.1_score_0.92/63_mz_240.0953.png
# Saved: output_0.1_score_0.92/64_mz_404.9267.png
# Saved: output_0.1_score_0.92/65_mz_282.2793.png
# Saved: output_0.1_score_0.92/66_mz_774.9400.png
# Saved: output_0.1_score_0.92/67_mz_508.2855.png
# Saved: output_0.1_score_0.92/68_mz_783.5694.png
# Saved: output_0.1_score_0.92/69_mz_136.0608.png
# Saved: output_0.1_score_0.92/70_mz_251.9214.png
# Saved: output_0.1_score_0.92/71_mz_386.2827.png
# Saved: output_0.1_score_0.92/72_mz_502.2887.png
# Saved: output_0.1_score_0.92/73_mz_482.3231.png
# Saved: output_0.1_score_0.92/74_mz_184.0720.png
# Saved: output_0.1_score_0.92/75_mz_252.9273.png
# Saved: output_0.1_score_0.92/76_mz_389.3006.png
# Saved: output_0.1_score_0.92/77_mz_718.5380.png
# Saved: output_0.1_score_0.92/78_mz_785.5751.png
# Saved: output_0.1_score_0.92/79_mz_600.9327.png
# Saved: output_0.1_score_0.92/80_mz_269.1003.png
# Saved: output_0.1_score_0.92/81_mz_526.2990.png
# Saved: output_0.1_score_0.92/82_mz_623.5002.png
# Saved: output_0.1_score_0.92/83_mz_653.5411.png
# Saved: output_0.1_score_0.92/84_mz_768.5477.png
# Saved: output_0.1_score_0.92/85_mz_627.5297.png
# Saved: output_0.1_score_0.92/86_mz_782.5675.png
# Saved: output_0.1_score_0.92/87_mz_750.5461.png
# Saved: output_0.1_score_0.92/88_mz_597.9289.png
# Saved: output_0.1_score_0.92/89_mz_792.5538.png
# Saved: output_0.1_score_0.92/90_mz_655.5630.png
# Saved: output_0.1_score_0.92/91_mz_836.5261.png
# Saved: output_0.1_score_0.92/92_mz_958.5659.png
# Saved: output_0.1_score_0.92/93_mz_366.1371.png
# Saved: output_0.1_score_0.92/94_mz_599.9377.png
# Saved: output_0.1_score_0.92/95_mz_518.3260.png
# Saved: output_0.1_score_0.92/96_mz_754.5827.png
# Saved: output_0.1_score_0.92/97_mz_229.9417.png
# Saved: output_0.1_score_0.92/98_mz_725.5188.png
# Saved: output_0.1_score_0.92/99_mz_598.9329.png
# Saved: output_0.1_score_0.92/100_mz_764.6067.png
# Saved: output_0.1_score_0.92/101_mz_746.5800.png
# Saved: output_0.1_score_0.92/102_mz_753.5875.png
# Saved: output_0.1_score_0.92/103_mz_749.5297.png
# Saved: output_0.1_score_0.92/104_mz_628.5364.png
# Saved: output_0.1_score_0.92/105_mz_230.9492.png
# Saved: output_0.1_score_0.92/106_mz_231.9456.png
# Saved: output_0.1_score_0.92/107_mz_548.5356.png
# Saved: output_0.1_score_0.92/108_mz_203.2236.png
# Saved: output_0.1_score_0.92/109_mz_264.2661.png
# Saved: output_0.1_score_0.92/110_mz_464.3135.png
# Saved: output_0.1_score_0.92/111_mz_224.1000.png
# Saved: output_0.1_score_0.92/112_mz_649.5179.png
# Saved: output_0.1_score_0.92/113_mz_397.3363.png
# Saved: output_0.1_score_0.92/114_mz_232.9441.png
# Saved: output_0.1_score_0.92/115_mz_629.5439.png
# Saved: output_0.1_score_0.92/116_mz_549.5485.png
# Saved: output_0.1_score_0.92/117_mz_443.9010.png
# Saved: output_0.1_score_0.92/118_mz_222.0783.png
# Saved: output_0.1_score_0.92/119_mz_242.1088.png
# Saved: output_0.1_score_0.92/120_mz_444.9043.png
# Saved: output_0.1_score_0.92/121_mz_408.0254.png
# Saved: output_0.1_score_0.92/122_mz_635.5397.png
# Saved: output_0.1_score_0.92/123_mz_355.3483.png
# Saved: output_0.1_score_0.92/124_mz_268.1057.png
# Saved: output_0.1_score_0.92/125_mz_786.6035.png
# Saved: output_0.1_score_0.92/126_mz_776.5574.png
# Saved: output_0.1_score_0.92/127_mz_765.5245.png
# Saved: output_0.1_score_0.92/128_mz_793.5621.png
# Saved: output_0.1_score_0.92/129_mz_352.3177.png
# Saved: output_0.1_score_0.92/130_mz_424.9368.png
# Saved: output_0.1_score_0.92/131_mz_752.5570.png
# Saved: output_0.1_score_0.92/132_mz_966.9248.png
# Saved: output_0.1_score_0.92/133_mz_837.5366.png
# Saved: output_0.1_score_0.92/134_mz_396.3100.png
# Saved: output_0.1_score_0.92/135_mz_790.5270.png
# Saved: output_0.1_score_0.92/136_mz_348.0689.png
# Saved: output_0.1_score_0.92/137_mz_787.5956.png
# Saved: output_0.1_score_0.92/138_mz_764.5222.png
# Saved: output_0.1_score_0.92/139_mz_724.5195.png
# Saved: output_0.1_score_0.92/140_mz_747.5825.png
# Saved: output_0.1_score_0.92/141_mz_748.5259.png
# Saved: output_0.1_score_0.92/142_mz_258.1130.png
# Saved: output_0.1_score_0.92/143_mz_744.5532.png
# Saved: output_0.1_score_0.92/144_mz_751.5392.png
# Saved: output_0.1_score_0.92/145_mz_804.5468.png
# Saved: output_0.1_score_0.92/146_mz_250.0883.png
# Saved: output_0.1_score_0.92/147_mz_606.5544.png
# Saved: output_0.1_score_0.92/148_mz_729.5701.png
# Saved: output_0.1_score_0.92/149_mz_466.3291.png
# Saved: output_0.1_score_0.92/150_mz_422.9320.png
# Saved: output_0.1_score_0.92/151_mz_812.5920.png
# Saved: output_0.1_score_0.92/152_mz_790.9199.png
# Saved: output_0.1_score_0.92/153_mz_835.6044.png
# Saved: output_0.1_score_0.92/154_mz_794.5587.png
# Saved: output_0.1_score_0.92/155_mz_810.6019.png
# Saved: output_0.1_score_0.92/156_mz_611.5435.png
# Saved: output_0.1_score_0.92/157_mz_720.5643.png
# Saved: output_0.1_score_0.92/158_mz_464.0783.png
# Saved: output_0.1_score_0.92/159_mz_811.5966.png
# Saved: output_0.1_score_0.92/160_mz_778.5663.png
# Saved: output_0.1_score_0.92/161_mz_926.5427.png
# Saved: output_0.1_score_0.92/162_mz_634.6154.png
# Saved: output_0.1_score_0.92/163_mz_198.1210.png
# Saved: output_0.1_score_0.92/164_mz_284.2929.png
# Saved: output_0.1_score_0.92/165_mz_614.9061.png
# Saved: output_0.1_score_0.92/166_mz_805.5502.png
# Saved: output_0.1_score_0.92/167_mz_766.5276.png
# Saved: output_0.1_score_0.92/168_mz_834.5950.png
# Saved: output_0.1_score_0.92/169_mz_564.2518.png
# Saved: output_0.1_score_0.92/170_mz_270.1184.png
# Saved: output_0.1_score_0.92/171_mz_664.1207.png
# Saved: output_0.1_score_0.92/172_mz_948.5346.png
# Saved: output_0.1_score_0.92/173_mz_280.0902.png
# Saved: output_0.1_score_0.92/174_mz_587.5433.png
# Saved: output_0.1_score_0.92/175_mz_267.8913.png
# Saved: output_0.1_score_0.92/176_mz_788.6130.png
# Saved: output_0.1_score_0.92/177_mz_605.5548.png
# Saved: output_0.1_score_0.92/178_mz_268.8998.png
# Saved: output_0.1_score_0.92/179_mz_790.6252.png
# Saved: output_0.1_score_0.92/180_mz_1495.1523.png
# Saved: output_0.1_score_0.92/181_mz_789.6188.png
# Saved: output_0.1_score_0.92/182_mz_728.5562.png
# Saved: output_0.1_score_0.92/183_mz_702.5467.png
# Saved: output_0.1_score_0.92/184_mz_847.5362.png
# Saved: output_0.1_score_0.92/185_mz_602.0143.png
# Saved: output_0.1_score_0.92/186_mz_791.5339.png
# Saved: output_0.1_score_0.92/187_mz_777.5555.png
# Saved: output_0.1_score_0.92/188_mz_542.0715.png
# Saved: output_0.1_score_0.92/189_mz_630.6179.png
# Saved: output_0.1_score_0.92/190_mz_1494.1565.png
# Saved: output_0.1_score_0.92/191_mz_846.5322.png
# Saved: output_0.1_score_0.92/192_mz_402.0237.png
# Saved: output_0.1_score_0.92/193_mz_423.9832.png
# Saved: output_0.1_score_0.92/194_mz_697.4753.png
# Saved: output_0.1_score_0.92/195_mz_201.9372.png
# Saved: output_0.1_score_0.92/196_mz_534.2923.png
# Saved: output_0.1_score_0.92/197_mz_812.5174.png
# Saved: output_0.1_score_0.92/198_mz_815.5320.png
# Saved: output_0.1_score_0.92/199_mz_621.6046.png
# Saved: output_0.1_score_0.92/200_mz_832.5781.png
# Saved: output_0.1_score_0.92/201_mz_702.0723.png
# Saved: output_0.1_score_0.92/202_mz_836.6271.png
# Saved: output_0.1_score_0.92/203_mz_974.5565.png
# Saved: output_0.1_score_0.92/204_mz_631.6271.png
# Saved: output_0.1_score_0.92/205_mz_1520.1588.png
# Saved: output_0.1_score_0.92/206_mz_730.5729.png
# Saved: output_0.1_score_0.92/207_mz_222.0327.png
# Saved: output_0.1_score_0.92/208_mz_833.5862.png
# Saved: output_0.1_score_0.92/209_mz_1522.1682.png
# Saved: output_0.1_score_0.92/210_mz_620.6035.png
# Saved: output_0.1_score_0.92/211_mz_580.0320.png
# Saved: output_0.1_score_0.92/212_mz_740.4961.png
# Saved: output_0.1_score_0.92/213_mz_339.2947.png
# Saved: output_0.1_score_0.92/214_mz_646.6168.png
# Saved: output_0.1_score_0.92/215_mz_551.5052.png
# Saved: output_0.1_score_0.92/216_mz_975.5518.png
# Saved: output_0.1_score_0.92/217_mz_834.5319.png
# Saved: output_0.1_score_0.92/218_mz_648.6279.png
# Saved: output_0.1_score_0.92/219_mz_767.5312.png
# Saved: output_0.1_score_0.92/220_mz_780.5778.png
# Saved: output_0.1_score_0.92/221_mz_1521.1633.png
# Saved: output_0.1_score_0.92/222_mz_897.4819.png
# Saved: output_0.1_score_0.92/223_mz_875.4991.png
# Saved: output_0.1_score_0.92/224_mz_1544.1542.png
# Saved: output_0.1_score_0.92/225_mz_814.5224.png
# Saved: output_0.1_score_0.92/226_mz_966.5311.png
# Saved: output_0.1_score_0.92/227_mz_775.5356.png
# Saved: output_0.1_score_0.92/228_mz_858.5287.png
# Saved: output_0.1_score_0.92/229_mz_808.5023.png
# Saved: output_0.1_score_0.92/230_mz_801.5524.png
# Saved: output_0.1_score_0.92/231_mz_802.5665.png
# Saved: output_0.1_score_0.92/232_mz_774.5268.png
# Saved: output_0.1_score_0.92/233_mz_781.5784.png
# Saved: output_0.1_score_0.92/234_mz_813.5133.png
# Saved: output_0.1_score_0.92/235_mz_828.5011.png
# Saved: output_0.1_score_0.92/236_mz_950.5529.png
# Saved: output_0.1_score_0.92/237_mz_782.6530.png
# Saved: output_0.1_score_0.92/238_mz_770.5583.png
# Saved: output_0.1_score_0.92/239_mz_876.5071.png
# Saved: output_0.1_score_0.92/240_mz_560.0797.png
# Saved: output_0.1_score_0.92/241_mz_617.9849.png
# Saved: output_0.1_score_0.92/242_mz_788.5027.png
# Saved: output_0.1_score_0.92/243_mz_560.3174.png
# Saved: output_0.1_score_0.92/244_mz_1542.1475.png
# Saved: output_0.1_score_0.92/245_mz_816.5298.png
# Saved: output_0.1_score_0.92/246_mz_828.5639.png
# Saved: output_0.1_score_0.92/247_mz_808.6637.png
# Saved: output_0.1_score_0.92/248_mz_822.5297.png
# Saved: output_0.1_score_0.92/249_mz_874.5046.png
# Saved: output_0.1_score_0.92/250_mz_832.6662.png
# Saved: output_0.1_score_0.92/251_mz_925.5197.png
# Saved: output_0.1_score_0.92/252_mz_896.4880.png
# Saved: output_0.1_score_0.92/253_mz_802.4798.png
# Saved: output_0.1_score_0.92/254_mz_792.6645.png
# Saved: output_0.1_score_0.92/255_mz_830.5131.png
# Saved: output_0.1_score_0.92/256_mz_579.5273.png
# Saved: output_0.1_score_0.92/257_mz_762.4953.png
# Saved: output_0.1_score_0.92/258_mz_831.5201.png
# Saved: output_0.1_score_0.92/259_mz_800.5515.png
# Saved: output_0.1_score_0.92/260_mz_818.5523.png
# Saved: output_0.1_score_0.92/261_mz_856.5085.png
# Saved: output_0.1_score_0.92/262_mz_837.6503.png
# Saved: output_0.1_score_0.92/263_mz_771.5526.png
# Saved: output_0.1_score_0.92/264_mz_480.3211.png
# Saved: output_0.1_score_0.92/265_mz_786.4932.png
# Saved: output_0.1_score_0.92/266_mz_773.5307.png
# Saved: output_0.1_score_0.92/267_mz_832.5150.png
# Saved: output_0.1_score_0.92/268_mz_799.5511.png
# Saved: output_0.1_score_0.92/269_mz_829.5068.png
# Saved: output_0.1_score_0.92/270_mz_789.4961.png
# Saved: output_0.1_score_0.92/271_mz_778.4689.png
# Saved: output_0.1_score_0.92/272_mz_296.0663.png
# Saved: output_0.1_score_0.92/273_mz_578.5188.png
# Saved: output_0.1_score_0.92/274_mz_562.3243.png
# Saved: output_0.1_score_0.92/275_mz_769.5648.png
# Saved: output_0.1_score_0.92/276_mz_805.4882.png
# Saved: output_0.1_score_0.92/277_mz_723.4974.png
# Saved: output_0.1_score_0.92/278_mz_804.4848.png
# Saved: output_0.1_score_0.92/279_mz_742.5174.png
# Saved: output_0.1_score_0.92/280_mz_820.5273.png
# Saved: output_0.1_score_0.92/281_mz_798.5391.png
# Saved: output_0.1_score_0.92/282_mz_796.5415.png
# Saved: output_0.1_score_0.92/283_mz_821.5281.png
# Saved: output_0.1_score_0.92/284_mz_806.5172.png
# Saved: output_0.1_score_0.92/285_mz_772.5231.png
# Saved: output_0.1_score_0.92/286_mz_964.4960.png
# Saved: output_0.1_score_0.92/287_mz_824.5594.png
# Saved: output_0.1_score_0.92/288_mz_822.6423.png
# Saved: output_0.1_score_0.92/289_mz_826.4664.png
# Saved: output_0.1_score_0.92/290_mz_741.4946.png
# Saved: output_0.1_score_0.92/291_mz_810.6888.png
# Saved: output_0.1_score_0.92/292_mz_787.4854.png
# Saved: output_0.1_score_0.92/293_mz_852.4881.png
# Saved: output_0.1_score_0.92/294_mz_807.5094.png
# Saved: output_0.1_score_0.92/295_mz_912.4556.png
# Saved: output_0.1_score_0.92/296_mz_844.5262.png
# Saved: output_0.1_score_0.92/297_mz_854.4907.png
# Saved: output_0.1_score_0.92/298_mz_873.5623.png
# Saved: output_0.1_score_0.92/299_mz_577.5215.png
# Saved: output_0.1_score_0.92/300_mz_872.5560.png
# Saved: output_0.1_score_0.92/301_mz_825.5629.png
# Saved: output_0.1_score_0.92/302_mz_963.4792.png
# Saved: output_0.1_score_0.92/303_mz_850.4877.png
# Saved: output_0.1_score_0.92/304_mz_845.5290.png
# Saved: output_0.1_score_0.92/305_mz_522.3597.png
# Saved: output_0.1_score_0.92/306_mz_797.5770.png
# Saved: output_0.1_score_0.92/307_mz_826.5668.png
# Saved: output_0.1_score_0.92/308_mz_827.5714.png
# Saved: output_0.1_score_0.92/309_mz_714.4474.png
# Saved: output_0.1_score_0.92/310_mz_840.4328.png
# Saved: output_0.1_score_0.92/311_mz_599.4994.png
# Saved: output_0.1_score_0.92/312_mz_823.6320.png
# ...
# Saved: output_0.1_score_0.99/13_mz_365.3188.png
# Saved: output_0.1_score_0.99/14_mz_383.3277.png
# Saved: output_0.1_score_0.99/15_mz_808.5768.png
# Saved: output_0.1_score_0.99/16_mz_386.3513.png
# Saved: output_0.1_score_0.99/17_mz_735.5735.png
# Saved: output_0.1_score_0.99/18_mz_734.5673.png
# Saved: output_0.1_score_0.99/19_mz_256.0827.png
# Saved: output_0.1_score_0.99/20_mz_384.3286.png
# Saved: output_0.1_score_0.99/21_mz_283.0942.png
# Saved: output_0.1_score_0.99/22_mz_366.3293.png
# Saved: output_0.1_score_0.99/23_mz_736.5804.png
# Saved: output_0.1_score_0.99/24_mz_809.5828.png
# Saved: output_0.1_score_0.99/25_mz_257.2299.png
# Saved: output_0.1_score_0.99/26_mz_731.6000.png
# Saved: output_0.1_score_0.99/27_mz_762.5918.png
# Saved: output_0.1_score_0.99/28_mz_932.5598.png
# Saved: output_0.1_score_0.99/29_mz_732.6042.png
# Saved: output_0.1_score_0.99/30_mz_651.5335.png
# Saved: output_0.1_score_0.99/31_mz_255.2101.png
# Saved: output_0.1_score_0.99/32_mz_327.2354.png
# Saved: output_0.1_score_0.99/33_mz_763.6049.png
# Saved: output_0.1_score_0.99/34_mz_247.2447.png
# Saved: output_0.1_score_0.99/35_mz_427.9302.png
# Saved: output_0.1_score_0.99/36_mz_385.2707.png
# Saved: output_0.1_score_0.99/37_mz_428.9334.png
# Saved: output_0.1_score_0.99/38_mz_161.1338.png
# Saved: output_0.1_score_0.99/39_mz_264.1099.png
# Saved: output_0.1_score_0.99/40_mz_758.5699.png
# Saved: output_0.1_score_0.99/41_mz_652.5370.png
# Saved: output_0.1_score_0.99/42_mz_313.2732.png
# Saved: output_0.1_score_0.99/43_mz_760.5916.png
# Saved: output_0.1_score_0.99/44_mz_756.5510.png
# Saved: output_0.1_score_0.99/45_mz_406.9501.png
# Saved: output_0.1_score_0.99/46_mz_759.5684.png
# Saved: output_0.1_score_0.99/47_mz_326.3040.png
# Saved: output_0.1_score_0.99/48_mz_761.5914.png
# Saved: output_0.1_score_0.99/49_mz_757.5601.png
# Saved: output_0.1_score_0.99/50_mz_354.3367.png
# Saved: output_0.1_score_0.99/51_mz_398.3291.png
# Saved: output_0.1_score_0.99/52_mz_626.5129.png
# Saved: output_0.1_score_0.99/53_mz_215.1771.png
# Saved: output_0.1_score_0.99/54_mz_407.9548.png
# Saved: output_0.1_score_0.99/55_mz_350.0839.png
# Saved: output_0.1_score_0.99/56_mz_733.5854.png
# Saved: output_0.1_score_0.99/57_mz_625.5188.png
# Saved: output_0.1_score_0.99/58_mz_361.2742.png
# Saved: output_0.1_score_0.99/59_mz_346.0598.png
# Saved: output_0.1_score_0.99/60_mz_240.0953.png
# Saved: output_0.1_score_0.99/61_mz_784.5720.png
# Saved: output_0.1_score_0.99/62_mz_353.3347.png
# Saved: output_0.1_score_0.99/63_mz_404.9267.png
# Saved: output_0.1_score_0.99/64_mz_774.9400.png
# Saved: output_0.1_score_0.99/65_mz_356.3532.png
# Saved: output_0.1_score_0.99/66_mz_508.2855.png
# Saved: output_0.1_score_0.99/67_mz_783.5694.png
# Saved: output_0.1_score_0.99/68_mz_136.0608.png
# Saved: output_0.1_score_0.99/69_mz_502.2887.png
# Saved: output_0.1_score_0.99/70_mz_251.9214.png
# Saved: output_0.1_score_0.99/71_mz_282.2793.png
# Saved: output_0.1_score_0.99/72_mz_184.0720.png
# Saved: output_0.1_score_0.99/73_mz_386.2827.png
# Saved: output_0.1_score_0.99/74_mz_482.3231.png
# Saved: output_0.1_score_0.99/75_mz_252.9273.png
# Saved: output_0.1_score_0.99/76_mz_389.3006.png
# Saved: output_0.1_score_0.99/77_mz_526.2990.png
# Saved: output_0.1_score_0.99/78_mz_718.5380.png
# Saved: output_0.1_score_0.99/79_mz_600.9327.png
# Saved: output_0.1_score_0.99/80_mz_785.5751.png
# Saved: output_0.1_score_0.99/81_mz_653.5411.png
# Saved: output_0.1_score_0.99/82_mz_623.5002.png
# Saved: output_0.1_score_0.99/83_mz_768.5477.png
# Saved: output_0.1_score_0.99/84_mz_627.5297.png
# Saved: output_0.1_score_0.99/85_mz_269.1003.png
# Saved: output_0.1_score_0.99/86_mz_782.5675.png
# Saved: output_0.1_score_0.99/87_mz_792.5538.png
# Saved: output_0.1_score_0.99/88_mz_597.9289.png
# Saved: output_0.1_score_0.99/89_mz_750.5461.png
# Saved: output_0.1_score_0.99/90_mz_655.5630.png
# Saved: output_0.1_score_0.99/91_mz_836.5261.png
# Saved: output_0.1_score_0.99/92_mz_518.3260.png
# Saved: output_0.1_score_0.99/93_mz_599.9377.png
# Saved: output_0.1_score_0.99/94_mz_628.5364.png
# Saved: output_0.1_score_0.99/95_mz_229.9417.png
# Saved: output_0.1_score_0.99/96_mz_598.9329.png
# Saved: output_0.1_score_0.99/97_mz_366.1371.png
# Saved: output_0.1_score_0.99/98_mz_746.5800.png
# Saved: output_0.1_score_0.99/99_mz_725.5188.png
# Saved: output_0.1_score_0.99/100_mz_230.9492.png
# Saved: output_0.1_score_0.99/101_mz_754.5827.png
# Saved: output_0.1_score_0.99/102_mz_764.6067.png
# Saved: output_0.1_score_0.99/103_mz_231.9456.png
# Saved: output_0.1_score_0.99/104_mz_749.5297.png
# Saved: output_0.1_score_0.99/105_mz_203.2236.png
# Saved: output_0.1_score_0.99/106_mz_548.5356.png
# Saved: output_0.1_score_0.99/107_mz_753.5875.png
# Saved: output_0.1_score_0.99/108_mz_958.5659.png
# Saved: output_0.1_score_0.99/109_mz_224.1000.png
# Saved: output_0.1_score_0.99/110_mz_649.5179.png
# Saved: output_0.1_score_0.99/111_mz_232.9441.png
# Saved: output_0.1_score_0.99/112_mz_629.5439.png
# Saved: output_0.1_score_0.99/113_mz_443.9010.png
# Saved: output_0.1_score_0.99/114_mz_464.3135.png
# Saved: output_0.1_score_0.99/115_mz_444.9043.png
# Saved: output_0.1_score_0.99/116_mz_549.5485.png
# Saved: output_0.1_score_0.99/117_mz_408.0254.png
# Saved: output_0.1_score_0.99/118_mz_242.1088.png
# Saved: output_0.1_score_0.99/119_mz_222.0783.png
# Saved: output_0.1_score_0.99/120_mz_786.6035.png
# Saved: output_0.1_score_0.99/121_mz_397.3363.png
# Saved: output_0.1_score_0.99/122_mz_268.1057.png
# Saved: output_0.1_score_0.99/123_mz_793.5621.png
# Saved: output_0.1_score_0.99/124_mz_635.5397.png
# Saved: output_0.1_score_0.99/125_mz_776.5574.png
# Saved: output_0.1_score_0.99/126_mz_264.2661.png
# Saved: output_0.1_score_0.99/127_mz_765.5245.png
# Saved: output_0.1_score_0.99/128_mz_966.9248.png
# Saved: output_0.1_score_0.99/129_mz_790.5270.png
# Saved: output_0.1_score_0.99/130_mz_752.5570.png
# Saved: output_0.1_score_0.99/131_mz_837.5366.png
# Saved: output_0.1_score_0.99/132_mz_764.5222.png
# Saved: output_0.1_score_0.99/133_mz_787.5956.png
# Saved: output_0.1_score_0.99/134_mz_424.9368.png
# Saved: output_0.1_score_0.99/135_mz_258.1130.png
# Saved: output_0.1_score_0.99/136_mz_348.0689.png
# Saved: output_0.1_score_0.99/137_mz_747.5825.png
# Saved: output_0.1_score_0.99/138_mz_724.5195.png
# Saved: output_0.1_score_0.99/139_mz_748.5259.png
# Saved: output_0.1_score_0.99/140_mz_744.5532.png
# Saved: output_0.1_score_0.99/141_mz_396.3100.png
# Saved: output_0.1_score_0.99/142_mz_355.3483.png
# Saved: output_0.1_score_0.99/143_mz_804.5468.png
# Saved: output_0.1_score_0.99/144_mz_352.3177.png
# Saved: output_0.1_score_0.99/145_mz_250.0883.png
# Saved: output_0.1_score_0.99/146_mz_751.5392.png
# Saved: output_0.1_score_0.99/147_mz_729.5701.png
# Saved: output_0.1_score_0.99/148_mz_606.5544.png
# Saved: output_0.1_score_0.99/149_mz_422.9320.png
# Saved: output_0.1_score_0.99/150_mz_466.3291.png
# Saved: output_0.1_score_0.99/151_mz_810.6019.png
# Saved: output_0.1_score_0.99/152_mz_812.5920.png
# Saved: output_0.1_score_0.99/153_mz_835.6044.png
# Saved: output_0.1_score_0.99/154_mz_790.9199.png
# Saved: output_0.1_score_0.99/155_mz_811.5966.png
# Saved: output_0.1_score_0.99/156_mz_794.5587.png
# Saved: output_0.1_score_0.99/157_mz_720.5643.png
# Saved: output_0.1_score_0.99/158_mz_464.0783.png
# Saved: output_0.1_score_0.99/159_mz_611.5435.png
# Saved: output_0.1_score_0.99/160_mz_778.5663.png
# Saved: output_0.1_score_0.99/161_mz_834.5950.png
# Saved: output_0.1_score_0.99/162_mz_564.2518.png
# Saved: output_0.1_score_0.99/163_mz_766.5276.png
# Saved: output_0.1_score_0.99/164_mz_614.9061.png
# Saved: output_0.1_score_0.99/165_mz_805.5502.png
# Saved: output_0.1_score_0.99/166_mz_198.1210.png
# Saved: output_0.1_score_0.99/167_mz_926.5427.png
# Saved: output_0.1_score_0.99/168_mz_788.6130.png
# Saved: output_0.1_score_0.99/169_mz_270.1184.png
# Saved: output_0.1_score_0.99/170_mz_634.6154.png
# Saved: output_0.1_score_0.99/171_mz_280.0902.png
# Saved: output_0.1_score_0.99/172_mz_948.5346.png
# Saved: output_0.1_score_0.99/173_mz_664.1207.png
# Saved: output_0.1_score_0.99/174_mz_605.5548.png
# Saved: output_0.1_score_0.99/175_mz_790.6252.png
# Saved: output_0.1_score_0.99/176_mz_789.6188.png
# Saved: output_0.1_score_0.99/177_mz_267.8913.png
# Saved: output_0.1_score_0.99/178_mz_268.8998.png
# Saved: output_0.1_score_0.99/179_mz_284.2929.png
# Saved: output_0.1_score_0.99/180_mz_1495.1523.png
# Saved: output_0.1_score_0.99/181_mz_791.5339.png
# Saved: output_0.1_score_0.99/182_mz_777.5555.png
# Saved: output_0.1_score_0.99/183_mz_587.5433.png
# Saved: output_0.1_score_0.99/184_mz_728.5562.png
# Saved: output_0.1_score_0.99/185_mz_702.5467.png
# Saved: output_0.1_score_0.99/186_mz_847.5362.png
# Saved: output_0.1_score_0.99/187_mz_534.2923.png
# Saved: output_0.1_score_0.99/188_mz_846.5322.png
# Saved: output_0.1_score_0.99/189_mz_602.0143.png
# Saved: output_0.1_score_0.99/190_mz_1494.1565.png
# Saved: output_0.1_score_0.99/191_mz_542.0715.png
# Saved: output_0.1_score_0.99/192_mz_402.0237.png
# Saved: output_0.1_score_0.99/193_mz_423.9832.png
# Saved: output_0.1_score_0.99/194_mz_201.9372.png
# Saved: output_0.1_score_0.99/195_mz_832.5781.png
# Saved: output_0.1_score_0.99/196_mz_812.5174.png
# Saved: output_0.1_score_0.99/197_mz_815.5320.png
# Saved: output_0.1_score_0.99/198_mz_630.6179.png
# Saved: output_0.1_score_0.99/199_mz_974.5565.png
# Saved: output_0.1_score_0.99/200_mz_1520.1588.png
# Saved: output_0.1_score_0.99/201_mz_730.5729.png
# Saved: output_0.1_score_0.99/202_mz_833.5862.png
# Saved: output_0.1_score_0.99/203_mz_222.0327.png
# Saved: output_0.1_score_0.99/204_mz_697.4753.png
# Saved: output_0.1_score_0.99/205_mz_836.6271.png
# Saved: output_0.1_score_0.99/206_mz_740.4961.png
# Saved: output_0.1_score_0.99/207_mz_1522.1682.png
# Saved: output_0.1_score_0.99/208_mz_702.0723.png
# Saved: output_0.1_score_0.99/209_mz_339.2947.png
# Saved: output_0.1_score_0.99/210_mz_621.6046.png
# Saved: output_0.1_score_0.99/211_mz_975.5518.png
# Saved: output_0.1_score_0.99/212_mz_631.6271.png
# Saved: output_0.1_score_0.99/213_mz_580.0320.png
# Saved: output_0.1_score_0.99/214_mz_620.6035.png
# Saved: output_0.1_score_0.99/215_mz_767.5312.png
# Saved: output_0.1_score_0.99/216_mz_834.5319.png
# Saved: output_0.1_score_0.99/217_mz_875.4991.png
# Saved: output_0.1_score_0.99/218_mz_814.5224.png
# Saved: output_0.1_score_0.99/219_mz_551.5052.png
# Saved: output_0.1_score_0.99/220_mz_1521.1633.png
# Saved: output_0.1_score_0.99/221_mz_775.5356.png
# Saved: output_0.1_score_0.99/222_mz_801.5524.png
# Saved: output_0.1_score_0.99/223_mz_646.6168.png
# Saved: output_0.1_score_0.99/224_mz_897.4819.png
# Saved: output_0.1_score_0.99/225_mz_780.5778.png
# Saved: output_0.1_score_0.99/226_mz_774.5268.png
# Saved: output_0.1_score_0.99/227_mz_1544.1542.png
# Saved: output_0.1_score_0.99/228_mz_648.6279.png
# Saved: output_0.1_score_0.99/229_mz_802.5665.png
# Saved: output_0.1_score_0.99/230_mz_828.5011.png
# Saved: output_0.1_score_0.99/231_mz_858.5287.png
# Saved: output_0.1_score_0.99/232_mz_770.5583.png
# Saved: output_0.1_score_0.99/233_mz_808.5023.png
# Saved: output_0.1_score_0.99/234_mz_876.5071.png
# Saved: output_0.1_score_0.99/235_mz_966.5311.png
# Saved: output_0.1_score_0.99/236_mz_874.5046.png
# Saved: output_0.1_score_0.99/237_mz_828.5639.png
# Saved: output_0.1_score_0.99/238_mz_813.5133.png
# Saved: output_0.1_score_0.99/239_mz_560.3174.png
# Saved: output_0.1_score_0.99/240_mz_822.5297.png
# Saved: output_0.1_score_0.99/241_mz_781.5784.png
# Saved: output_0.1_score_0.99/242_mz_830.5131.png
# Saved: output_0.1_score_0.99/243_mz_788.5027.png
# Saved: output_0.1_score_0.99/244_mz_782.6530.png
# Saved: output_0.1_score_0.99/245_mz_816.5298.png
# Saved: output_0.1_score_0.99/246_mz_800.5515.png
# Saved: output_0.1_score_0.99/247_mz_925.5197.png
# Saved: output_0.1_score_0.99/248_mz_831.5201.png
# Saved: output_0.1_score_0.99/249_mz_802.4798.png
# Saved: output_0.1_score_0.99/250_mz_896.4880.png
# Saved: output_0.1_score_0.99/251_mz_950.5529.png
# Saved: output_0.1_score_0.99/252_mz_1542.1475.png
# Saved: output_0.1_score_0.99/253_mz_617.9849.png
# Saved: output_0.1_score_0.99/254_mz_560.0797.png
# Saved: output_0.1_score_0.99/255_mz_773.5307.png
# Saved: output_0.1_score_0.99/256_mz_762.4953.png
# Saved: output_0.1_score_0.99/257_mz_818.5523.png
# Saved: output_0.1_score_0.99/258_mz_579.5273.png
# Saved: output_0.1_score_0.99/259_mz_771.5526.png
# Saved: output_0.1_score_0.99/260_mz_799.5511.png
# Saved: output_0.1_score_0.99/261_mz_832.5150.png
# Saved: output_0.1_score_0.99/262_mz_792.6645.png
# Saved: output_0.1_score_0.99/263_mz_786.4932.png
# Saved: output_0.1_score_0.99/264_mz_769.5648.png
# Saved: output_0.1_score_0.99/265_mz_808.6637.png
# Saved: output_0.1_score_0.99/266_mz_480.3211.png
# Saved: output_0.1_score_0.99/267_mz_829.5068.png
# Saved: output_0.1_score_0.99/268_mz_856.5085.png
# Saved: output_0.1_score_0.99/269_mz_798.5391.png
# Saved: output_0.1_score_0.99/270_mz_578.5188.png
# Saved: output_0.1_score_0.99/271_mz_789.4961.png
# Saved: output_0.1_score_0.99/272_mz_562.3243.png
# Saved: output_0.1_score_0.99/273_mz_820.5273.png
# Saved: output_0.1_score_0.99/274_mz_806.5172.png
# Saved: output_0.1_score_0.99/275_mz_778.4689.png
# Saved: output_0.1_score_0.99/276_mz_772.5231.png
# Saved: output_0.1_score_0.99/277_mz_821.5281.png
# Saved: output_0.1_score_0.99/278_mz_296.0663.png
# Saved: output_0.1_score_0.99/279_mz_824.5594.png
# Saved: output_0.1_score_0.99/280_mz_742.5174.png
# Saved: output_0.1_score_0.99/281_mz_805.4882.png
# Saved: output_0.1_score_0.99/282_mz_837.6503.png
# Saved: output_0.1_score_0.99/283_mz_804.4848.png
# Saved: output_0.1_score_0.99/284_mz_796.5415.png
# Saved: output_0.1_score_0.99/285_mz_741.4946.png
# Saved: output_0.1_score_0.99/286_mz_832.6662.png
# Saved: output_0.1_score_0.99/287_mz_964.4960.png
# Saved: output_0.1_score_0.99/288_mz_723.4974.png
# Saved: output_0.1_score_0.99/289_mz_787.4854.png
# Saved: output_0.1_score_0.99/290_mz_852.4881.png
# Saved: output_0.1_score_0.99/291_mz_844.5262.png
# Saved: output_0.1_score_0.99/292_mz_826.4664.png
# Saved: output_0.1_score_0.99/293_mz_912.4556.png
# Saved: output_0.1_score_0.99/294_mz_807.5094.png
# Saved: output_0.1_score_0.99/295_mz_872.5560.png
# Saved: output_0.1_score_0.99/296_mz_873.5623.png
# Saved: output_0.1_score_0.99/297_mz_577.5215.png
# Saved: output_0.1_score_0.99/298_mz_810.6888.png
# Saved: output_0.1_score_0.99/299_mz_825.5629.png
# Saved: output_0.1_score_0.99/300_mz_845.5290.png
# Saved: output_0.1_score_0.99/301_mz_854.4907.png
# Saved: output_0.1_score_0.99/302_mz_822.6423.png
# Saved: output_0.1_score_0.99/303_mz_963.4792.png
# Saved: output_0.1_score_0.99/304_mz_850.4877.png
# Saved: output_0.1_score_0.99/305_mz_826.5668.png
# Saved: output_0.1_score_0.99/306_mz_522.3597.png
# Saved: output_0.1_score_0.99/307_mz_827.5714.png
# Saved: output_0.1_score_0.99/308_mz_797.5770.png
# Saved: output_0.1_score_0.99/309_mz_840.4328.png
# Saved: output_0.1_score_0.99/310_mz_599.4994.png
# Saved: output_0.1_score_0.99/311_mz_913.4582.png
# Saved: output_0.1_score_0.99/312_mz_850.5641.png
# Saved: output_0.1_score_0.99/313_mz_849.5585.png
# Saved: output_0.1_score_0.99/314_mz_714.4474.png
# Saved: output_0.1_score_0.99/315_mz_853.4827.png
# Saved: output_0.1_score_0.99/316_mz_870.4678.png
# Saved: output_0.1_score_0.99/317_mz_604.5345.png
# Saved: output_0.1_score_0.99/318_mz_848.5533.png
# Saved: output_0.1_score_0.99/319_mz_824.4467.png
# Saved: output_0.1_score_0.99/320_mz_868.4722.png
# Saved: output_0.1_score_0.99/321_mz_713.4442.png
# Saved: output_0.1_score_0.99/322_mz_851.6469.png
# Saved: output_0.1_score_0.99/323_mz_869.4633.png
# Saved: output_0.1_score_0.99/324_mz_823.6320.png
# Saved: output_0.1_score_0.99/325_mz_739.4628.png
# Saved: output_0.1_score_0.99/326_mz_866.4661.png
# Saved: output_0.1_score_0.99/327_mz_603.5365.png
# Saved: output_0.1_score_0.99/328_mz_853.6358.png
# Saved: output_0.1_score_0.99/329_mz_850.6533.png
# Saved: output_0.1_score_0.99/330_mz_865.6309.png
# Saved: output_0.1_score_0.99/331_mz_852.6411.png
# Saved: output_0.1_score_0.99/332_mz_849.6475.png
# Saved: output_0.1_score_0.99/333_mz_867.6489.png
# Saved: output_0.1_score_0.99/334_mz_710.4850.png
# Saved: output_0.1_score_0.99/335_mz_848.6424.png
# Saved: output_0.1_score_0.99/336_mz_840.6227.png
# Saved: output_0.1_score_0.99/337_mz_838.6237.png
# Saved: output_0.1_score_0.99/338_mz_839.6229.png
# Saved: output_0.1_score_0.99/339_mz_866.6460.png
# Saved: output_0.1_score_0.99/340_mz_864.6292.png

# %%
'''import os
import pandas as pd
from matplotlib.colors import LinearSegmentedColormap

sorting_list = ['bg_nonzero_area', 'com_distance_to_tissue', 'bg_dist_max', 'bg_dist_mean']

for sort in sorting_list:
    output_folder = f"{min_background_intensity}_output_{sort}"

    if os.path.exists(output_folder):
        print(f"⚠️ Warning: Output folder '{output_folder}' already exists. Overwriting.")
    else:
        os.makedirs(output_folder, exist_ok=True)

    df_sorted = df_metrics.sort_values(by=sort, ascending=False)
    rank_num = 1

    output_filename = f"df_metrics_sorted_{min_background_intensity}_{sort}.csv"
    df_sorted.to_csv(output_filename, index=False, float_format="%.6f")
    print(f"✅ Saved: {output_filename}")

    for mz in df_sorted["mz"]:
        filename = f"{rank_num}_mz_{mz:.4f}.png"
        filepath = os.path.join(output_folder, filename)
        
        custom_cmap = LinearSegmentedColormap.from_list("custom_scale", [
            (0.0, "#454545"),   # white
            (0.00000001, "#000000"),  # black
            (0.10, "#000080"),  # navy
            (0.15, "#0000FF"),  # blue
            (0.30, "#8000FF"),  # purple-ish
            (0.45, "#FF0000"),  # red
            (0.60, "#FF8000"),  # orange
            (0.75, "#FFFF00"),  # yellow
            (1.0, "#FFFFFF")   # white
        ])
        
        visualize_mz_feature(adata, df_metrics, df_border, mz_value=mz, cmap=custom_cmap, save_path=filepath)
        print(f"Saved: {filepath}")
        rank_num += 1'''
# Out:
# ✅ Saved: df_metrics_sorted_0.4_bg_nonzero_area.csv
# Saved: 0.4_output_bg_nonzero_area/1_mz_808.5768.png
# Saved: 0.4_output_bg_nonzero_area/2_mz_427.9302.png
# Saved: 0.4_output_bg_nonzero_area/3_mz_580.9368.png
# Saved: 0.4_output_bg_nonzero_area/4_mz_406.9501.png
# Saved: 0.4_output_bg_nonzero_area/5_mz_734.5673.png
# Saved: 0.4_output_bg_nonzero_area/6_mz_428.9334.png
# Saved: 0.4_output_bg_nonzero_area/7_mz_735.5735.png
# Saved: 0.4_output_bg_nonzero_area/8_mz_762.5918.png
# Saved: 0.4_output_bg_nonzero_area/9_mz_774.9400.png
# Saved: 0.4_output_bg_nonzero_area/10_mz_760.5916.png
# Saved: 0.4_output_bg_nonzero_area/11_mz_736.5804.png
# Saved: 0.4_output_bg_nonzero_area/12_mz_404.9267.png
# Saved: 0.4_output_bg_nonzero_area/13_mz_136.0608.png
# Saved: 0.4_output_bg_nonzero_area/14_mz_761.5914.png
# Saved: 0.4_output_bg_nonzero_area/15_mz_651.5335.png
# Saved: 0.4_output_bg_nonzero_area/16_mz_809.5828.png
# Saved: 0.4_output_bg_nonzero_area/17_mz_385.2707.png
# Saved: 0.4_output_bg_nonzero_area/18_mz_731.6000.png
# Saved: 0.4_output_bg_nonzero_area/19_mz_598.9329.png
# Saved: 0.4_output_bg_nonzero_area/20_mz_732.6042.png
# Saved: 0.4_output_bg_nonzero_area/21_mz_251.9214.png
# Saved: 0.4_output_bg_nonzero_area/22_mz_652.5370.png
# Saved: 0.4_output_bg_nonzero_area/23_mz_350.0839.png
# Saved: 0.4_output_bg_nonzero_area/24_mz_600.9327.png
# Saved: 0.4_output_bg_nonzero_area/25_mz_763.6049.png
# Saved: 0.4_output_bg_nonzero_area/26_mz_407.9548.png
# Saved: 0.4_output_bg_nonzero_area/27_mz_230.9492.png
# Saved: 0.4_output_bg_nonzero_area/28_mz_231.9456.png
# Saved: 0.4_output_bg_nonzero_area/29_mz_229.9417.png
# Saved: 0.4_output_bg_nonzero_area/30_mz_599.9377.png
# Saved: 0.4_output_bg_nonzero_area/31_mz_348.0689.png
# Saved: 0.4_output_bg_nonzero_area/32_mz_443.9010.png
# Saved: 0.4_output_bg_nonzero_area/33_mz_597.9289.png
# Saved: 0.4_output_bg_nonzero_area/34_mz_252.9273.png
# Saved: 0.4_output_bg_nonzero_area/35_mz_361.2742.png
# Saved: 0.4_output_bg_nonzero_area/36_mz_758.5699.png
# Saved: 0.4_output_bg_nonzero_area/37_mz_408.0254.png
# Saved: 0.4_output_bg_nonzero_area/38_mz_950.9432.png
# Saved: 0.4_output_bg_nonzero_area/39_mz_526.2990.png
# Saved: 0.4_output_bg_nonzero_area/40_mz_759.5684.png
# Saved: 0.4_output_bg_nonzero_area/41_mz_792.5538.png
# Saved: 0.4_output_bg_nonzero_area/42_mz_932.5598.png
# Saved: 0.4_output_bg_nonzero_area/43_mz_664.1207.png
# Saved: 0.4_output_bg_nonzero_area/44_mz_502.2887.png
# Saved: 0.4_output_bg_nonzero_area/45_mz_232.9441.png
# Saved: 0.4_output_bg_nonzero_area/46_mz_444.9043.png
# Saved: 0.4_output_bg_nonzero_area/47_mz_966.9248.png
# Saved: 0.4_output_bg_nonzero_area/48_mz_423.9832.png
# Saved: 0.4_output_bg_nonzero_area/49_mz_836.5261.png
# Saved: 0.4_output_bg_nonzero_area/50_mz_464.0783.png
# Saved: 0.4_output_bg_nonzero_area/51_mz_733.5854.png
# Saved: 0.4_output_bg_nonzero_area/52_mz_768.5477.png
# Saved: 0.4_output_bg_nonzero_area/53_mz_542.0715.png
# Saved: 0.4_output_bg_nonzero_area/54_mz_422.9320.png
# Saved: 0.4_output_bg_nonzero_area/55_mz_602.0143.png
# Saved: 0.4_output_bg_nonzero_area/56_mz_250.0883.png
# Saved: 0.4_output_bg_nonzero_area/57_mz_580.0320.png
# Saved: 0.4_output_bg_nonzero_area/58_mz_341.3084.png
# Saved: 0.4_output_bg_nonzero_area/59_mz_389.3006.png
# Saved: 0.4_output_bg_nonzero_area/60_mz_627.5297.png
# Saved: 0.4_output_bg_nonzero_area/61_mz_655.5630.png
# Saved: 0.4_output_bg_nonzero_area/62_mz_786.6035.png
# Saved: 0.4_output_bg_nonzero_area/63_mz_184.0720.png
# Saved: 0.4_output_bg_nonzero_area/64_mz_180.0717.png
# Saved: 0.4_output_bg_nonzero_area/65_mz_793.5621.png
# Saved: 0.4_output_bg_nonzero_area/66_mz_625.5188.png
# Saved: 0.4_output_bg_nonzero_area/67_mz_653.5411.png
# Saved: 0.4_output_bg_nonzero_area/68_mz_386.2827.png
# Saved: 0.4_output_bg_nonzero_area/69_mz_424.9368.png
# Saved: 0.4_output_bg_nonzero_area/70_mz_185.0686.png
# Saved: 0.4_output_bg_nonzero_area/71_mz_718.5380.png
# Saved: 0.4_output_bg_nonzero_area/72_mz_702.0723.png
# Saved: 0.4_output_bg_nonzero_area/73_mz_790.9199.png
# Saved: 0.4_output_bg_nonzero_area/74_mz_402.0237.png
# Saved: 0.4_output_bg_nonzero_area/75_mz_783.5694.png
# Saved: 0.4_output_bg_nonzero_area/76_mz_837.5366.png
# Saved: 0.4_output_bg_nonzero_area/77_mz_787.5956.png
# Saved: 0.4_output_bg_nonzero_area/78_mz_1520.1588.png
# Saved: 0.4_output_bg_nonzero_area/79_mz_614.9061.png
# Saved: 0.4_output_bg_nonzero_area/80_mz_628.5364.png
# Saved: 0.4_output_bg_nonzero_area/81_mz_623.5002.png
# Saved: 0.4_output_bg_nonzero_area/82_mz_784.5720.png
# Saved: 0.4_output_bg_nonzero_area/83_mz_626.5129.png
# Saved: 0.4_output_bg_nonzero_area/84_mz_617.9849.png
# Saved: 0.4_output_bg_nonzero_area/85_mz_782.5675.png
# Saved: 0.4_output_bg_nonzero_area/86_mz_750.5461.png
# Saved: 0.4_output_bg_nonzero_area/87_mz_508.2855.png
# Saved: 0.4_output_bg_nonzero_area/88_mz_518.3260.png
# Saved: 0.4_output_bg_nonzero_area/89_mz_764.5222.png
# Saved: 0.4_output_bg_nonzero_area/90_mz_284.0794.png
# Saved: 0.4_output_bg_nonzero_area/91_mz_746.5800.png
# Saved: 0.4_output_bg_nonzero_area/92_mz_268.8998.png
# Saved: 0.4_output_bg_nonzero_area/93_mz_703.5655.png
# Saved: 0.4_output_bg_nonzero_area/94_mz_267.8913.png
# Saved: 0.4_output_bg_nonzero_area/95_mz_790.5270.png
# Saved: 0.4_output_bg_nonzero_area/96_mz_201.9372.png
# Saved: 0.4_output_bg_nonzero_area/97_mz_785.5751.png
# Saved: 0.4_output_bg_nonzero_area/98_mz_1494.1565.png
# Saved: 0.4_output_bg_nonzero_area/99_mz_810.6019.png
# Saved: 0.4_output_bg_nonzero_area/100_mz_765.5245.png
# Saved: 0.4_output_bg_nonzero_area/101_mz_629.5439.png
# Saved: 0.4_output_bg_nonzero_area/102_mz_1495.1523.png
# Saved: 0.4_output_bg_nonzero_area/103_mz_1521.1633.png
# Saved: 0.4_output_bg_nonzero_area/104_mz_744.5532.png
# Saved: 0.4_output_bg_nonzero_area/105_mz_749.5297.png
# Saved: 0.4_output_bg_nonzero_area/106_mz_752.5570.png
# Saved: 0.4_output_bg_nonzero_area/107_mz_268.1057.png
# Saved: 0.4_output_bg_nonzero_area/108_mz_1522.1682.png
# Saved: 0.4_output_bg_nonzero_area/109_mz_203.2236.png
# Saved: 0.4_output_bg_nonzero_area/110_mz_764.6067.png
# Saved: 0.4_output_bg_nonzero_area/111_mz_776.5574.png
# Saved: 0.4_output_bg_nonzero_area/112_mz_835.6044.png
# Saved: 0.4_output_bg_nonzero_area/113_mz_812.5920.png
# Saved: 0.4_output_bg_nonzero_area/114_mz_729.5701.png
# Saved: 0.4_output_bg_nonzero_area/115_mz_482.3231.png
# Saved: 0.4_output_bg_nonzero_area/116_mz_788.6130.png
# Saved: 0.4_output_bg_nonzero_area/117_mz_258.1130.png
# Saved: 0.4_output_bg_nonzero_area/118_mz_804.5468.png
# Saved: 0.4_output_bg_nonzero_area/119_mz_466.3291.png
# Saved: 0.4_output_bg_nonzero_area/120_mz_754.5827.png
# Saved: 0.4_output_bg_nonzero_area/121_mz_747.5825.png
# Saved: 0.4_output_bg_nonzero_area/122_mz_366.1371.png
# Saved: 0.4_output_bg_nonzero_area/123_mz_811.5966.png
# Saved: 0.4_output_bg_nonzero_area/124_mz_564.2518.png
# Saved: 0.4_output_bg_nonzero_area/125_mz_256.0827.png
# Saved: 0.4_output_bg_nonzero_area/126_mz_725.5188.png
# Saved: 0.4_output_bg_nonzero_area/127_mz_790.6252.png
# Saved: 0.4_output_bg_nonzero_area/128_mz_370.3516.png
# Saved: 0.4_output_bg_nonzero_area/129_mz_328.3184.png
# Saved: 0.4_output_bg_nonzero_area/130_mz_283.0942.png
# Saved: 0.4_output_bg_nonzero_area/131_mz_794.5587.png
# Saved: 0.4_output_bg_nonzero_area/132_mz_789.6188.png
# Saved: 0.4_output_bg_nonzero_area/133_mz_748.5259.png
# Saved: 0.4_output_bg_nonzero_area/134_mz_1544.1542.png
# Saved: 0.4_output_bg_nonzero_area/135_mz_606.5544.png
# Saved: 0.4_output_bg_nonzero_area/136_mz_724.5195.png
# Saved: 0.4_output_bg_nonzero_area/137_mz_778.5663.png
# Saved: 0.4_output_bg_nonzero_area/138_mz_368.3461.png
# Saved: 0.4_output_bg_nonzero_area/139_mz_365.3188.png
# Saved: 0.4_output_bg_nonzero_area/140_mz_346.0598.png
# Saved: 0.4_output_bg_nonzero_area/141_mz_371.3606.png
# Saved: 0.4_output_bg_nonzero_area/142_mz_386.3513.png
# Saved: 0.4_output_bg_nonzero_area/143_mz_753.5875.png
# Saved: 0.4_output_bg_nonzero_area/144_mz_280.0902.png
# Saved: 0.4_output_bg_nonzero_area/145_mz_269.1003.png
# Saved: 0.4_output_bg_nonzero_area/146_mz_834.5950.png
# Saved: 0.4_output_bg_nonzero_area/147_mz_367.3328.png
# Saved: 0.4_output_bg_nonzero_area/148_mz_222.0327.png
# Saved: 0.4_output_bg_nonzero_area/149_mz_649.5179.png
# Saved: 0.4_output_bg_nonzero_area/150_mz_385.3478.png
# Saved: 0.4_output_bg_nonzero_area/151_mz_366.3293.png
# Saved: 0.4_output_bg_nonzero_area/152_mz_777.5555.png
# Saved: 0.4_output_bg_nonzero_area/153_mz_925.5197.png
# Saved: 0.4_output_bg_nonzero_area/154_mz_974.5565.png
# Saved: 0.4_output_bg_nonzero_area/155_mz_611.5435.png
# Saved: 0.4_output_bg_nonzero_area/156_mz_958.5659.png
# Saved: 0.4_output_bg_nonzero_area/157_mz_549.5485.png
# Saved: 0.4_output_bg_nonzero_area/158_mz_240.0953.png
# Saved: 0.4_output_bg_nonzero_area/159_mz_313.2732.png
# Saved: 0.4_output_bg_nonzero_area/160_mz_816.5298.png
# Saved: 0.4_output_bg_nonzero_area/161_mz_801.5524.png
# Saved: 0.4_output_bg_nonzero_area/162_mz_242.1088.png
# Saved: 0.4_output_bg_nonzero_area/163_mz_751.5392.png
# Saved: 0.4_output_bg_nonzero_area/164_mz_296.0663.png
# Saved: 0.4_output_bg_nonzero_area/165_mz_384.3286.png
# Saved: 0.4_output_bg_nonzero_area/166_mz_326.3040.png
# Saved: 0.4_output_bg_nonzero_area/167_mz_766.5276.png
# Saved: 0.4_output_bg_nonzero_area/168_mz_354.3367.png
# Saved: 0.4_output_bg_nonzero_area/169_mz_771.5526.png
# Saved: 0.4_output_bg_nonzero_area/170_mz_548.5356.png
# Saved: 0.4_output_bg_nonzero_area/171_mz_742.5174.png
# Saved: 0.4_output_bg_nonzero_area/172_mz_948.5346.png
# Saved: 0.4_output_bg_nonzero_area/173_mz_560.0797.png
# Saved: 0.4_output_bg_nonzero_area/174_mz_264.1099.png
# Saved: 0.4_output_bg_nonzero_area/175_mz_814.5224.png
# Saved: 0.4_output_bg_nonzero_area/176_mz_897.4819.png
# Saved: 0.4_output_bg_nonzero_area/177_mz_551.5052.png
# Saved: 0.4_output_bg_nonzero_area/178_mz_728.5562.png
# Saved: 0.4_output_bg_nonzero_area/179_mz_578.5188.png
# Saved: 0.4_output_bg_nonzero_area/180_mz_264.2661.png
# Saved: 0.4_output_bg_nonzero_area/181_mz_975.5518.png
# Saved: 0.4_output_bg_nonzero_area/182_mz_353.3347.png
# Saved: 0.4_output_bg_nonzero_area/183_mz_782.6530.png
# Saved: 0.4_output_bg_nonzero_area/184_mz_247.2447.png
# Saved: 0.4_output_bg_nonzero_area/185_mz_874.5046.png
# Saved: 0.4_output_bg_nonzero_area/186_mz_875.4991.png
# Saved: 0.4_output_bg_nonzero_area/187_mz_780.5778.png
# Saved: 0.4_output_bg_nonzero_area/188_mz_215.1771.png
# Saved: 0.4_output_bg_nonzero_area/189_mz_257.2299.png
# Saved: 0.4_output_bg_nonzero_area/190_mz_832.6662.png
# Saved: 0.4_output_bg_nonzero_area/191_mz_950.5529.png
# Saved: 0.4_output_bg_nonzero_area/192_mz_834.5319.png
# Saved: 0.4_output_bg_nonzero_area/193_mz_832.5781.png
# Saved: 0.4_output_bg_nonzero_area/194_mz_829.5068.png
# Saved: 0.4_output_bg_nonzero_area/195_mz_796.5415.png
# Saved: 0.4_output_bg_nonzero_area/196_mz_800.5515.png
# Saved: 0.4_output_bg_nonzero_area/197_mz_822.6423.png
# Saved: 0.4_output_bg_nonzero_area/198_mz_804.4848.png
# Saved: 0.4_output_bg_nonzero_area/199_mz_635.5397.png
# Saved: 0.4_output_bg_nonzero_area/200_mz_805.5502.png
# Saved: 0.4_output_bg_nonzero_area/201_mz_812.5174.png
# Saved: 0.4_output_bg_nonzero_area/202_mz_926.5427.png
# Saved: 0.4_output_bg_nonzero_area/203_mz_634.6154.png
# Saved: 0.4_output_bg_nonzero_area/204_mz_579.5273.png
# Saved: 0.4_output_bg_nonzero_area/205_mz_560.3174.png
# Saved: 0.4_output_bg_nonzero_area/206_mz_397.3363.png
# Saved: 0.4_output_bg_nonzero_area/207_mz_396.3100.png
# Saved: 0.4_output_bg_nonzero_area/208_mz_464.3135.png
# Saved: 0.4_output_bg_nonzero_area/209_mz_605.5548.png
# Saved: 0.4_output_bg_nonzero_area/210_mz_383.3277.png
# Saved: 0.4_output_bg_nonzero_area/211_mz_702.5467.png
# Saved: 0.4_output_bg_nonzero_area/212_mz_604.5345.png
# Saved: 0.4_output_bg_nonzero_area/213_mz_757.5601.png
# Saved: 0.4_output_bg_nonzero_area/214_mz_369.3523.png
# Saved: 0.4_output_bg_nonzero_area/215_mz_577.5215.png
# Saved: 0.4_output_bg_nonzero_area/216_mz_587.5433.png
# Saved: 0.4_output_bg_nonzero_area/217_mz_770.5583.png
# Saved: 0.4_output_bg_nonzero_area/218_mz_740.4961.png
# Saved: 0.4_output_bg_nonzero_area/219_mz_730.5729.png
# Saved: 0.4_output_bg_nonzero_area/220_mz_603.5365.png
# Saved: 0.4_output_bg_nonzero_area/221_mz_562.3243.png
# ⚠️ Skipping m/z 853.4827 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/222_mz_853.4827.png
# ⚠️ Skipping m/z 850.5641 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/223_mz_850.5641.png
# ⚠️ Skipping m/z 852.6411 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/224_mz_852.6411.png
# ⚠️ Skipping m/z 852.4881 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/225_mz_852.4881.png
# ⚠️ Skipping m/z 853.6358 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/226_mz_853.6358.png
# ⚠️ Skipping m/z 854.4907 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/227_mz_854.4907.png
# ⚠️ Skipping m/z 851.6469 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/228_mz_851.6469.png
# ⚠️ Skipping m/z 856.5085 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/229_mz_856.5085.png
# ⚠️ Skipping m/z 850.6533 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/230_mz_850.6533.png
# ⚠️ Skipping m/z 848.6424 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/231_mz_848.6424.png
# ⚠️ Skipping m/z 850.4877 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/232_mz_850.4877.png
# ⚠️ Skipping m/z 849.6475 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/233_mz_849.6475.png
# ⚠️ Skipping m/z 849.5585 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/234_mz_849.5585.png
# ⚠️ Skipping m/z 864.6292 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/235_mz_864.6292.png
# ⚠️ Skipping m/z 848.5533 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/236_mz_848.5533.png
# ⚠️ Skipping m/z 847.5362 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/237_mz_847.5362.png
# ⚠️ Skipping m/z 846.5322 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/238_mz_846.5322.png
# ⚠️ Skipping m/z 845.5290 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/239_mz_845.5290.png
# ⚠️ Skipping m/z 844.5262 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/240_mz_844.5262.png
# ⚠️ Skipping m/z 840.6227 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/241_mz_840.6227.png
# ⚠️ Skipping m/z 840.4328 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/242_mz_840.4328.png
# ⚠️ Skipping m/z 839.6229 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/243_mz_839.6229.png
# ⚠️ Skipping m/z 838.6237 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/244_mz_838.6237.png
# ⚠️ Skipping m/z 837.6503 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/245_mz_837.6503.png
# ⚠️ Skipping m/z 858.5287 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/246_mz_858.5287.png
# ⚠️ Skipping m/z 869.4633 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/247_mz_869.4633.png
# ⚠️ Skipping m/z 865.6309 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/248_mz_865.6309.png
# ⚠️ Skipping m/z 243.2107 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/249_mz_243.2107.png
# ⚠️ Skipping m/z 1542.1475 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/250_mz_1542.1475.png
# ⚠️ Skipping m/z 198.1210 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/251_mz_198.1210.png
# ⚠️ Skipping m/z 646.6168 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/252_mz_646.6168.png
# ⚠️ Skipping m/z 648.6279 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/253_mz_648.6279.png
# ⚠️ Skipping m/z 222.0783 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/254_mz_222.0783.png
# ⚠️ Skipping m/z 224.1000 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/255_mz_224.1000.png
# ⚠️ Skipping m/z 631.6271 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/256_mz_631.6271.png
# ⚠️ Skipping m/z 630.6179 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/257_mz_630.6179.png
# ⚠️ Skipping m/z 621.6046 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/258_mz_621.6046.png
# ⚠️ Skipping m/z 966.5311 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/259_mz_966.5311.png
# ⚠️ Skipping m/z 964.4960 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/260_mz_964.4960.png
# ⚠️ Skipping m/z 963.4792 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/261_mz_963.4792.png
# ⚠️ Skipping m/z 620.6035 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/262_mz_620.6035.png
# ⚠️ Skipping m/z 697.4753 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/263_mz_697.4753.png
# ⚠️ Skipping m/z 710.4850 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/264_mz_710.4850.png
# ⚠️ Skipping m/z 866.4661 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/265_mz_866.4661.png
# ⚠️ Skipping m/z 713.4442 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/266_mz_713.4442.png
# ⚠️ Skipping m/z 913.4582 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/267_mz_913.4582.png
# ⚠️ Skipping m/z 912.4556 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/268_mz_912.4556.png
# ⚠️ Skipping m/z 714.4474 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/269_mz_714.4474.png
# ⚠️ Skipping m/z 896.4880 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/270_mz_896.4880.png
# ⚠️ Skipping m/z 876.5071 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/271_mz_876.5071.png
# ⚠️ Skipping m/z 720.5643 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/272_mz_720.5643.png
# ⚠️ Skipping m/z 873.5623 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/273_mz_873.5623.png
# ⚠️ Skipping m/z 872.5560 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/274_mz_872.5560.png
# ⚠️ Skipping m/z 870.4678 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/275_mz_870.4678.png
# ⚠️ Skipping m/z 836.6271 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/276_mz_836.6271.png
# ⚠️ Skipping m/z 868.4722 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/277_mz_868.4722.png
# ⚠️ Skipping m/z 867.6489 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/278_mz_867.6489.png
# ⚠️ Skipping m/z 866.6460 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/279_mz_866.6460.png
# ⚠️ Skipping m/z 723.4974 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/280_mz_723.4974.png
# ⚠️ Skipping m/z 778.4689 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/281_mz_778.4689.png
# ⚠️ Skipping m/z 255.2101 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/282_mz_255.2101.png
# ⚠️ Skipping m/z 327.2354 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/283_mz_327.2354.png
# ⚠️ Skipping m/z 480.3211 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/284_mz_480.3211.png
# ⚠️ Skipping m/z 756.5510 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/285_mz_756.5510.png
# ⚠️ Skipping m/z 282.2793 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/286_mz_282.2793.png
# ⚠️ Skipping m/z 802.5665 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/287_mz_802.5665.png
# ⚠️ Skipping m/z 802.4798 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/288_mz_802.4798.png
# ⚠️ Skipping m/z 398.3291 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/289_mz_398.3291.png
# ⚠️ Skipping m/z 799.5511 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/290_mz_799.5511.png
# ⚠️ Skipping m/z 798.5391 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/291_mz_798.5391.png
# ⚠️ Skipping m/z 797.5770 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/292_mz_797.5770.png
# ⚠️ Skipping m/z 284.2929 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/293_mz_284.2929.png
# ⚠️ Skipping m/z 792.6645 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/294_mz_792.6645.png
# ⚠️ Skipping m/z 762.4953 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/295_mz_762.4953.png
# ⚠️ Skipping m/z 791.5339 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/296_mz_791.5339.png
# ⚠️ Skipping m/z 339.2947 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/297_mz_339.2947.png
# ⚠️ Skipping m/z 599.4994 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/298_mz_599.4994.png
# ⚠️ Skipping m/z 767.5312 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/299_mz_767.5312.png
# ⚠️ Skipping m/z 789.4961 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/300_mz_789.4961.png
# ⚠️ Skipping m/z 352.3177 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/301_mz_352.3177.png
# ⚠️ Skipping m/z 788.5027 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/302_mz_788.5027.png
# ⚠️ Skipping m/z 787.4854 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/303_mz_787.4854.png
# ⚠️ Skipping m/z 769.5648 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/304_mz_769.5648.png
# ⚠️ Skipping m/z 786.4932 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/305_mz_786.4932.png
# ⚠️ Skipping m/z 355.3483 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/306_mz_355.3483.png
# ⚠️ Skipping m/z 356.3532 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/307_mz_356.3532.png
# ⚠️ Skipping m/z 772.5231 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/308_mz_772.5231.png
# ⚠️ Skipping m/z 773.5307 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/309_mz_773.5307.png
# ⚠️ Skipping m/z 781.5784 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/310_mz_781.5784.png
# ⚠️ Skipping m/z 774.5268 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/311_mz_774.5268.png
# ⚠️ Skipping m/z 806.5172 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/312_mz_806.5172.png
# ⚠️ Skipping m/z 807.5094 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/313_mz_807.5094.png
# ⚠️ Skipping m/z 808.5023 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/314_mz_808.5023.png
# ⚠️ Skipping m/z 522.3597 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/315_mz_522.3597.png
# ⚠️ Skipping m/z 833.5862 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/316_mz_833.5862.png
# ⚠️ Skipping m/z 775.5356 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/317_mz_775.5356.png
# ⚠️ Skipping m/z 832.5150 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/318_mz_832.5150.png
# ⚠️ Skipping m/z 831.5201 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/319_mz_831.5201.png
# ⚠️ Skipping m/z 830.5131 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/320_mz_830.5131.png
# ⚠️ Skipping m/z 828.5639 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/321_mz_828.5639.png
# ⚠️ Skipping m/z 828.5011 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/322_mz_828.5011.png
# ⚠️ Skipping m/z 827.5714 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/323_mz_827.5714.png
# ⚠️ Skipping m/z 826.5668 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/324_mz_826.5668.png
# ⚠️ Skipping m/z 826.4664 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/325_mz_826.4664.png
# ⚠️ Skipping m/z 825.5629 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/326_mz_825.5629.png
# ⚠️ Skipping m/z 824.5594 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/327_mz_824.5594.png
# ⚠️ Skipping m/z 824.4467 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/328_mz_824.4467.png
# ⚠️ Skipping m/z 823.6320 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/329_mz_823.6320.png
# ⚠️ Skipping m/z 822.5297 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/330_mz_822.5297.png
# ⚠️ Skipping m/z 821.5281 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/331_mz_821.5281.png
# ⚠️ Skipping m/z 820.5273 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/332_mz_820.5273.png
# ⚠️ Skipping m/z 818.5523 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/333_mz_818.5523.png
# ⚠️ Skipping m/z 815.5320 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/334_mz_815.5320.png
# ⚠️ Skipping m/z 739.4628 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/335_mz_739.4628.png
# ⚠️ Skipping m/z 813.5133 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/336_mz_813.5133.png
# ⚠️ Skipping m/z 741.4946 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/337_mz_741.4946.png
# ⚠️ Skipping m/z 161.1338 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/338_mz_161.1338.png
# ⚠️ Skipping m/z 810.6888 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/339_mz_810.6888.png
# ⚠️ Skipping m/z 534.2923 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/340_mz_534.2923.png
# ⚠️ Skipping m/z 270.1184 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/341_mz_270.1184.png
# ⚠️ Skipping m/z 808.6637 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/342_mz_808.6637.png
# ⚠️ Skipping m/z 805.4882 — no matching metric data found.
# Saved: 0.4_output_bg_nonzero_area/343_mz_805.4882.png
# ✅ Saved: df_metrics_sorted_0.4_com_distance_to_tissue.csv
# Saved: 0.4_output_com_distance_to_tissue/1_mz_252.9273.png
# Saved: 0.4_output_com_distance_to_tissue/2_mz_348.0689.png
# Saved: 0.4_output_com_distance_to_tissue/3_mz_268.8998.png
# Saved: 0.4_output_com_distance_to_tissue/4_mz_427.9302.png
# Saved: 0.4_output_com_distance_to_tissue/5_mz_580.9368.png
# Saved: 0.4_output_com_distance_to_tissue/6_mz_408.0254.png
# Saved: 0.4_output_com_distance_to_tissue/7_mz_350.0839.png
# Saved: 0.4_output_com_distance_to_tissue/8_mz_428.9334.png
# Saved: 0.4_output_com_distance_to_tissue/9_mz_664.1207.png
# Saved: 0.4_output_com_distance_to_tissue/10_mz_808.5768.png
# Saved: 0.4_output_com_distance_to_tissue/11_mz_774.9400.png
# Saved: 0.4_output_com_distance_to_tissue/12_mz_464.0783.png
# Saved: 0.4_output_com_distance_to_tissue/13_mz_136.0608.png
# Saved: 0.4_output_com_distance_to_tissue/14_mz_542.0715.png
# Saved: 0.4_output_com_distance_to_tissue/15_mz_406.9501.png
# Saved: 0.4_output_com_distance_to_tissue/16_mz_404.9267.png
# Saved: 0.4_output_com_distance_to_tissue/17_mz_423.9832.png
# Saved: 0.4_output_com_distance_to_tissue/18_mz_950.9432.png
# Saved: 0.4_output_com_distance_to_tissue/19_mz_402.0237.png
# Saved: 0.4_output_com_distance_to_tissue/20_mz_731.6000.png
# Saved: 0.4_output_com_distance_to_tissue/21_mz_580.0320.png
# Saved: 0.4_output_com_distance_to_tissue/22_mz_732.6042.png
# Saved: 0.4_output_com_distance_to_tissue/23_mz_602.0143.png
# Saved: 0.4_output_com_distance_to_tissue/24_mz_703.5655.png
# Saved: 0.4_output_com_distance_to_tissue/25_mz_600.9327.png
# Saved: 0.4_output_com_distance_to_tissue/26_mz_407.9548.png
# Saved: 0.4_output_com_distance_to_tissue/27_mz_229.9417.png
# Saved: 0.4_output_com_distance_to_tissue/28_mz_932.5598.png
# Saved: 0.4_output_com_distance_to_tissue/29_mz_526.2990.png
# Saved: 0.4_output_com_distance_to_tissue/30_mz_599.9377.png
# Saved: 0.4_output_com_distance_to_tissue/31_mz_702.0723.png
# Saved: 0.4_output_com_distance_to_tissue/32_mz_597.9289.png
# Saved: 0.4_output_com_distance_to_tissue/33_mz_251.9214.png
# Saved: 0.4_output_com_distance_to_tissue/34_mz_598.9329.png
# Saved: 0.4_output_com_distance_to_tissue/35_mz_443.9010.png
# Saved: 0.4_output_com_distance_to_tissue/36_mz_760.5916.png
# Saved: 0.4_output_com_distance_to_tissue/37_mz_250.0883.png
# Saved: 0.4_output_com_distance_to_tissue/38_mz_761.5914.png
# Saved: 0.4_output_com_distance_to_tissue/39_mz_231.9456.png
# Saved: 0.4_output_com_distance_to_tissue/40_mz_502.2887.png
# Saved: 0.4_output_com_distance_to_tissue/41_mz_734.5673.png
# Saved: 0.4_output_com_distance_to_tissue/42_mz_735.5735.png
# Saved: 0.4_output_com_distance_to_tissue/43_mz_651.5335.png
# Saved: 0.4_output_com_distance_to_tissue/44_mz_966.9248.png
# Saved: 0.4_output_com_distance_to_tissue/45_mz_230.9492.png
# Saved: 0.4_output_com_distance_to_tissue/46_mz_385.2707.png
# Saved: 0.4_output_com_distance_to_tissue/47_mz_809.5828.png
# Saved: 0.4_output_com_distance_to_tissue/48_mz_736.5804.png
# Saved: 0.4_output_com_distance_to_tissue/49_mz_617.9849.png
# Saved: 0.4_output_com_distance_to_tissue/50_mz_652.5370.png
# Saved: 0.4_output_com_distance_to_tissue/51_mz_792.5538.png
# Saved: 0.4_output_com_distance_to_tissue/52_mz_389.3006.png
# Saved: 0.4_output_com_distance_to_tissue/53_mz_733.5854.png
# Saved: 0.4_output_com_distance_to_tissue/54_mz_361.2742.png
# Saved: 0.4_output_com_distance_to_tissue/55_mz_762.5918.png
# Saved: 0.4_output_com_distance_to_tissue/56_mz_786.6035.png
# Saved: 0.4_output_com_distance_to_tissue/57_mz_518.3260.png
# Saved: 0.4_output_com_distance_to_tissue/58_mz_655.5630.png
# Saved: 0.4_output_com_distance_to_tissue/59_mz_232.9441.png
# Saved: 0.4_output_com_distance_to_tissue/60_mz_763.6049.png
# Saved: 0.4_output_com_distance_to_tissue/61_mz_793.5621.png
# Saved: 0.4_output_com_distance_to_tissue/62_mz_837.5366.png
# Saved: 0.4_output_com_distance_to_tissue/63_mz_787.5956.png
# Saved: 0.4_output_com_distance_to_tissue/64_mz_759.5684.png
# Saved: 0.4_output_com_distance_to_tissue/65_mz_768.5477.png
# Saved: 0.4_output_com_distance_to_tissue/66_mz_627.5297.png
# Saved: 0.4_output_com_distance_to_tissue/67_mz_836.5261.png
# Saved: 0.4_output_com_distance_to_tissue/68_mz_718.5380.png
# Saved: 0.4_output_com_distance_to_tissue/69_mz_1520.1588.png
# Saved: 0.4_output_com_distance_to_tissue/70_mz_1495.1523.png
# Saved: 0.4_output_com_distance_to_tissue/71_mz_653.5411.png
# Saved: 0.4_output_com_distance_to_tissue/72_mz_623.5002.png
# Saved: 0.4_output_com_distance_to_tissue/73_mz_790.9199.png
# Saved: 0.4_output_com_distance_to_tissue/74_mz_764.5222.png
# Saved: 0.4_output_com_distance_to_tissue/75_mz_386.2827.png
# Saved: 0.4_output_com_distance_to_tissue/76_mz_744.5532.png
# Saved: 0.4_output_com_distance_to_tissue/77_mz_625.5188.png
# Saved: 0.4_output_com_distance_to_tissue/78_mz_750.5461.png
# Saved: 0.4_output_com_distance_to_tissue/79_mz_180.0717.png
# Saved: 0.4_output_com_distance_to_tissue/80_mz_1494.1565.png
# Saved: 0.4_output_com_distance_to_tissue/81_mz_810.6019.png
# Saved: 0.4_output_com_distance_to_tissue/82_mz_422.9320.png
# Saved: 0.4_output_com_distance_to_tissue/83_mz_628.5364.png
# Saved: 0.4_output_com_distance_to_tissue/84_mz_626.5129.png
# Saved: 0.4_output_com_distance_to_tissue/85_mz_1521.1633.png
# Saved: 0.4_output_com_distance_to_tissue/86_mz_201.9372.png
# Saved: 0.4_output_com_distance_to_tissue/87_mz_466.3291.png
# Saved: 0.4_output_com_distance_to_tissue/88_mz_444.9043.png
# Saved: 0.4_output_com_distance_to_tissue/89_mz_341.3084.png
# Saved: 0.4_output_com_distance_to_tissue/90_mz_614.9061.png
# Saved: 0.4_output_com_distance_to_tissue/91_mz_729.5701.png
# Saved: 0.4_output_com_distance_to_tissue/92_mz_629.5439.png
# Saved: 0.4_output_com_distance_to_tissue/93_mz_203.2236.png
# Saved: 0.4_output_com_distance_to_tissue/94_mz_746.5800.png
# Saved: 0.4_output_com_distance_to_tissue/95_mz_788.6130.png
# Saved: 0.4_output_com_distance_to_tissue/96_mz_184.0720.png
# Saved: 0.4_output_com_distance_to_tissue/97_mz_284.0794.png
# Saved: 0.4_output_com_distance_to_tissue/98_mz_752.5570.png
# Saved: 0.4_output_com_distance_to_tissue/99_mz_508.2855.png
# Saved: 0.4_output_com_distance_to_tissue/100_mz_268.1057.png
# Saved: 0.4_output_com_distance_to_tissue/101_mz_790.5270.png
# Saved: 0.4_output_com_distance_to_tissue/102_mz_258.1130.png
# Saved: 0.4_output_com_distance_to_tissue/103_mz_811.5966.png
# Saved: 0.4_output_com_distance_to_tissue/104_mz_754.5827.png
# Saved: 0.4_output_com_distance_to_tissue/105_mz_1522.1682.png
# Saved: 0.4_output_com_distance_to_tissue/106_mz_790.6252.png
# Saved: 0.4_output_com_distance_to_tissue/107_mz_765.5245.png
# Saved: 0.4_output_com_distance_to_tissue/108_mz_424.9368.png
# Saved: 0.4_output_com_distance_to_tissue/109_mz_560.0797.png
# Saved: 0.4_output_com_distance_to_tissue/110_mz_812.5920.png
# Saved: 0.4_output_com_distance_to_tissue/111_mz_749.5297.png
# Saved: 0.4_output_com_distance_to_tissue/112_mz_747.5825.png
# Saved: 0.4_output_com_distance_to_tissue/113_mz_725.5188.png
# Saved: 0.4_output_com_distance_to_tissue/114_mz_267.8913.png
# Saved: 0.4_output_com_distance_to_tissue/115_mz_785.5751.png
# Saved: 0.4_output_com_distance_to_tissue/116_mz_280.0902.png
# Saved: 0.4_output_com_distance_to_tissue/117_mz_578.5188.png
# Saved: 0.4_output_com_distance_to_tissue/118_mz_789.6188.png
# Saved: 0.4_output_com_distance_to_tissue/119_mz_366.1371.png
# Saved: 0.4_output_com_distance_to_tissue/120_mz_328.3184.png
# Saved: 0.4_output_com_distance_to_tissue/121_mz_1544.1542.png
# Saved: 0.4_output_com_distance_to_tissue/122_mz_604.5345.png
# Saved: 0.4_output_com_distance_to_tissue/123_mz_603.5365.png
# Saved: 0.4_output_com_distance_to_tissue/124_mz_758.5699.png
# Saved: 0.4_output_com_distance_to_tissue/125_mz_804.5468.png
# Saved: 0.4_output_com_distance_to_tissue/126_mz_748.5259.png
# Saved: 0.4_output_com_distance_to_tissue/127_mz_835.6044.png
# Saved: 0.4_output_com_distance_to_tissue/128_mz_783.5694.png
# Saved: 0.4_output_com_distance_to_tissue/129_mz_283.0942.png
# Saved: 0.4_output_com_distance_to_tissue/130_mz_782.5675.png
# Saved: 0.4_output_com_distance_to_tissue/131_mz_577.5215.png
# Saved: 0.4_output_com_distance_to_tissue/132_mz_724.5195.png
# Saved: 0.4_output_com_distance_to_tissue/133_mz_482.3231.png
# Saved: 0.4_output_com_distance_to_tissue/134_mz_649.5179.png
# Saved: 0.4_output_com_distance_to_tissue/135_mz_386.3513.png
# Saved: 0.4_output_com_distance_to_tissue/136_mz_832.6662.png
# Saved: 0.4_output_com_distance_to_tissue/137_mz_778.5663.png
# Saved: 0.4_output_com_distance_to_tissue/138_mz_551.5052.png
# Saved: 0.4_output_com_distance_to_tissue/139_mz_269.1003.png
# Saved: 0.4_output_com_distance_to_tissue/140_mz_753.5875.png
# Saved: 0.4_output_com_distance_to_tissue/141_mz_764.6067.png
# Saved: 0.4_output_com_distance_to_tissue/142_mz_346.0598.png
# Saved: 0.4_output_com_distance_to_tissue/143_mz_606.5544.png
# Saved: 0.4_output_com_distance_to_tissue/144_mz_256.0827.png
# Saved: 0.4_output_com_distance_to_tissue/145_mz_958.5659.png
# Saved: 0.4_output_com_distance_to_tissue/146_mz_794.5587.png
# Saved: 0.4_output_com_distance_to_tissue/147_mz_549.5485.png
# Saved: 0.4_output_com_distance_to_tissue/148_mz_925.5197.png
# Saved: 0.4_output_com_distance_to_tissue/149_mz_742.5174.png
# Saved: 0.4_output_com_distance_to_tissue/150_mz_313.2732.png
# Saved: 0.4_output_com_distance_to_tissue/151_mz_822.6423.png
# Saved: 0.4_output_com_distance_to_tissue/152_mz_897.4819.png
# Saved: 0.4_output_com_distance_to_tissue/153_mz_784.5720.png
# Saved: 0.4_output_com_distance_to_tissue/154_mz_579.5273.png
# Saved: 0.4_output_com_distance_to_tissue/155_mz_562.3243.png
# Saved: 0.4_output_com_distance_to_tissue/156_mz_365.3188.png
# Saved: 0.4_output_com_distance_to_tissue/157_mz_564.2518.png
# Saved: 0.4_output_com_distance_to_tissue/158_mz_776.5574.png
# Saved: 0.4_output_com_distance_to_tissue/159_mz_370.3516.png
# Saved: 0.4_output_com_distance_to_tissue/160_mz_296.0663.png
# Saved: 0.4_output_com_distance_to_tissue/161_mz_777.5555.png
# Saved: 0.4_output_com_distance_to_tissue/162_mz_974.5565.png
# Saved: 0.4_output_com_distance_to_tissue/163_mz_611.5435.png
# Saved: 0.4_output_com_distance_to_tissue/164_mz_816.5298.png
# Saved: 0.4_output_com_distance_to_tissue/165_mz_385.3478.png
# Saved: 0.4_output_com_distance_to_tissue/166_mz_185.0686.png
# Saved: 0.4_output_com_distance_to_tissue/167_mz_368.3461.png
# Saved: 0.4_output_com_distance_to_tissue/168_mz_780.5778.png
# Saved: 0.4_output_com_distance_to_tissue/169_mz_367.3328.png
# Saved: 0.4_output_com_distance_to_tissue/170_mz_950.5529.png
# Saved: 0.4_output_com_distance_to_tissue/171_mz_366.3293.png
# Saved: 0.4_output_com_distance_to_tissue/172_mz_371.3606.png
# Saved: 0.4_output_com_distance_to_tissue/173_mz_326.3040.png
# Saved: 0.4_output_com_distance_to_tissue/174_mz_354.3367.png
# Saved: 0.4_output_com_distance_to_tissue/175_mz_240.0953.png
# Saved: 0.4_output_com_distance_to_tissue/176_mz_771.5526.png
# Saved: 0.4_output_com_distance_to_tissue/177_mz_384.3286.png
# Saved: 0.4_output_com_distance_to_tissue/178_mz_796.5415.png
# Saved: 0.4_output_com_distance_to_tissue/179_mz_560.3174.png
# Saved: 0.4_output_com_distance_to_tissue/180_mz_605.5548.png
# Saved: 0.4_output_com_distance_to_tissue/181_mz_548.5356.png
# Saved: 0.4_output_com_distance_to_tissue/182_mz_834.5950.png
# Saved: 0.4_output_com_distance_to_tissue/183_mz_396.3100.png
# Saved: 0.4_output_com_distance_to_tissue/184_mz_215.1771.png
# Saved: 0.4_output_com_distance_to_tissue/185_mz_766.5276.png
# Saved: 0.4_output_com_distance_to_tissue/186_mz_728.5562.png
# Saved: 0.4_output_com_distance_to_tissue/187_mz_926.5427.png
# Saved: 0.4_output_com_distance_to_tissue/188_mz_222.0327.png
# Saved: 0.4_output_com_distance_to_tissue/189_mz_814.5224.png
# Saved: 0.4_output_com_distance_to_tissue/190_mz_812.5174.png
# Saved: 0.4_output_com_distance_to_tissue/191_mz_832.5781.png
# Saved: 0.4_output_com_distance_to_tissue/192_mz_353.3347.png
# Saved: 0.4_output_com_distance_to_tissue/193_mz_805.5502.png
# Saved: 0.4_output_com_distance_to_tissue/194_mz_751.5392.png
# Saved: 0.4_output_com_distance_to_tissue/195_mz_587.5433.png
# Saved: 0.4_output_com_distance_to_tissue/196_mz_801.5524.png
# Saved: 0.4_output_com_distance_to_tissue/197_mz_635.5397.png
# Saved: 0.4_output_com_distance_to_tissue/198_mz_874.5046.png
# Saved: 0.4_output_com_distance_to_tissue/199_mz_804.4848.png
# Saved: 0.4_output_com_distance_to_tissue/200_mz_975.5518.png
# Saved: 0.4_output_com_distance_to_tissue/201_mz_834.5319.png
# Saved: 0.4_output_com_distance_to_tissue/202_mz_702.5467.png
# Saved: 0.4_output_com_distance_to_tissue/203_mz_257.2299.png
# Saved: 0.4_output_com_distance_to_tissue/204_mz_730.5729.png
# Saved: 0.4_output_com_distance_to_tissue/205_mz_634.6154.png
# Saved: 0.4_output_com_distance_to_tissue/206_mz_383.3277.png
# Saved: 0.4_output_com_distance_to_tissue/207_mz_397.3363.png
# Saved: 0.4_output_com_distance_to_tissue/208_mz_782.6530.png
# Saved: 0.4_output_com_distance_to_tissue/209_mz_770.5583.png
# Saved: 0.4_output_com_distance_to_tissue/210_mz_247.2447.png
# Saved: 0.4_output_com_distance_to_tissue/211_mz_264.2661.png
# Saved: 0.4_output_com_distance_to_tissue/212_mz_800.5515.png
# Saved: 0.4_output_com_distance_to_tissue/213_mz_829.5068.png
# Saved: 0.4_output_com_distance_to_tissue/214_mz_464.3135.png
# Saved: 0.4_output_com_distance_to_tissue/215_mz_757.5601.png
# Saved: 0.4_output_com_distance_to_tissue/216_mz_875.4991.png
# Saved: 0.4_output_com_distance_to_tissue/217_mz_369.3523.png
# Saved: 0.4_output_com_distance_to_tissue/218_mz_740.4961.png
# Saved: 0.4_output_com_distance_to_tissue/219_mz_264.1099.png
# Saved: 0.4_output_com_distance_to_tissue/220_mz_242.1088.png
# Saved: 0.4_output_com_distance_to_tissue/221_mz_948.5346.png
# ⚠️ Skipping m/z 837.6503 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/222_mz_837.6503.png
# ⚠️ Skipping m/z 224.1000 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/223_mz_224.1000.png
# ⚠️ Skipping m/z 710.4850 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/224_mz_710.4850.png
# ⚠️ Skipping m/z 161.1338 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/225_mz_161.1338.png
# ⚠️ Skipping m/z 840.6227 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/226_mz_840.6227.png
# ⚠️ Skipping m/z 828.5011 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/227_mz_828.5011.png
# ⚠️ Skipping m/z 848.5533 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/228_mz_848.5533.png
# ⚠️ Skipping m/z 772.5231 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/229_mz_772.5231.png
# ⚠️ Skipping m/z 851.6469 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/230_mz_851.6469.png
# ⚠️ Skipping m/z 912.4556 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/231_mz_912.4556.png
# ⚠️ Skipping m/z 845.5290 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/232_mz_845.5290.png
# ⚠️ Skipping m/z 836.6271 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/233_mz_836.6271.png
# ⚠️ Skipping m/z 872.5560 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/234_mz_872.5560.png
# ⚠️ Skipping m/z 849.6475 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/235_mz_849.6475.png
# ⚠️ Skipping m/z 352.3177 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/236_mz_352.3177.png
# ⚠️ Skipping m/z 825.5629 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/237_mz_825.5629.png
# ⚠️ Skipping m/z 852.4881 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/238_mz_852.4881.png
# ⚠️ Skipping m/z 833.5862 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/239_mz_833.5862.png
# ⚠️ Skipping m/z 821.5281 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/240_mz_821.5281.png
# ⚠️ Skipping m/z 858.5287 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/241_mz_858.5287.png
# ⚠️ Skipping m/z 356.3532 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/242_mz_356.3532.png
# ⚠️ Skipping m/z 867.6489 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/243_mz_867.6489.png
# ⚠️ Skipping m/z 815.5320 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/244_mz_815.5320.png
# ⚠️ Skipping m/z 599.4994 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/245_mz_599.4994.png
# ⚠️ Skipping m/z 807.5094 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/246_mz_807.5094.png
# ⚠️ Skipping m/z 1542.1475 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/247_mz_1542.1475.png
# ⚠️ Skipping m/z 799.5511 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/248_mz_799.5511.png
# ⚠️ Skipping m/z 270.1184 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/249_mz_270.1184.png
# ⚠️ Skipping m/z 630.6179 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/250_mz_630.6179.png
# ⚠️ Skipping m/z 870.4678 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/251_mz_870.4678.png
# ⚠️ Skipping m/z 827.5714 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/252_mz_827.5714.png
# ⚠️ Skipping m/z 781.5784 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/253_mz_781.5784.png
# ⚠️ Skipping m/z 826.5668 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/254_mz_826.5668.png
# ⚠️ Skipping m/z 697.4753 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/255_mz_697.4753.png
# ⚠️ Skipping m/z 852.6411 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/256_mz_852.6411.png
# ⚠️ Skipping m/z 284.2929 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/257_mz_284.2929.png
# ⚠️ Skipping m/z 762.4953 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/258_mz_762.4953.png
# ⚠️ Skipping m/z 243.2107 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/259_mz_243.2107.png
# ⚠️ Skipping m/z 838.6237 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/260_mz_838.6237.png
# ⚠️ Skipping m/z 327.2354 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/261_mz_327.2354.png
# ⚠️ Skipping m/z 866.6460 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/262_mz_866.6460.png
# ⚠️ Skipping m/z 823.6320 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/263_mz_823.6320.png
# ⚠️ Skipping m/z 854.4907 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/264_mz_854.4907.png
# ⚠️ Skipping m/z 810.6888 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/265_mz_810.6888.png
# ⚠️ Skipping m/z 774.5268 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/266_mz_774.5268.png
# ⚠️ Skipping m/z 806.5172 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/267_mz_806.5172.png
# ⚠️ Skipping m/z 723.4974 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/268_mz_723.4974.png
# ⚠️ Skipping m/z 739.4628 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/269_mz_739.4628.png
# ⚠️ Skipping m/z 873.5623 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/270_mz_873.5623.png
# ⚠️ Skipping m/z 853.6358 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/271_mz_853.6358.png
# ⚠️ Skipping m/z 831.5201 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/272_mz_831.5201.png
# ⚠️ Skipping m/z 802.4798 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/273_mz_802.4798.png
# ⚠️ Skipping m/z 822.5297 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/274_mz_822.5297.png
# ⚠️ Skipping m/z 964.4960 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/275_mz_964.4960.png
# ⚠️ Skipping m/z 849.5585 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/276_mz_849.5585.png
# ⚠️ Skipping m/z 620.6035 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/277_mz_620.6035.png
# ⚠️ Skipping m/z 850.4877 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/278_mz_850.4877.png
# ⚠️ Skipping m/z 848.6424 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/279_mz_848.6424.png
# ⚠️ Skipping m/z 865.6309 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/280_mz_865.6309.png
# ⚠️ Skipping m/z 866.4661 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/281_mz_866.4661.png
# ⚠️ Skipping m/z 741.4946 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/282_mz_741.4946.png
# ⚠️ Skipping m/z 480.3211 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/283_mz_480.3211.png
# ⚠️ Skipping m/z 198.1210 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/284_mz_198.1210.png
# ⚠️ Skipping m/z 853.4827 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/285_mz_853.4827.png
# ⚠️ Skipping m/z 869.4633 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/286_mz_869.4633.png
# ⚠️ Skipping m/z 786.4932 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/287_mz_786.4932.png
# ⚠️ Skipping m/z 797.5770 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/288_mz_797.5770.png
# ⚠️ Skipping m/z 818.5523 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/289_mz_818.5523.png
# ⚠️ Skipping m/z 534.2923 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/290_mz_534.2923.png
# ⚠️ Skipping m/z 839.6229 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/291_mz_839.6229.png
# ⚠️ Skipping m/z 714.4474 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/292_mz_714.4474.png
# ⚠️ Skipping m/z 775.5356 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/293_mz_775.5356.png
# ⚠️ Skipping m/z 713.4442 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/294_mz_713.4442.png
# ⚠️ Skipping m/z 828.5639 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/295_mz_828.5639.png
# ⚠️ Skipping m/z 769.5648 — no matching metric data found.
# Saved: 0.4_output_com_distance_to_tissue/296_mz_769.5648.png
# ⚠️ Skipping m/z 826.4664 — no matching metric data found.
# ...
# Saved: 0.4_output_bg_dist_mean/170_mz_800.5515.png
# Saved: 0.4_output_bg_dist_mean/171_mz_814.5224.png
# Saved: 0.4_output_bg_dist_mean/172_mz_801.5524.png
# Saved: 0.4_output_bg_dist_mean/173_mz_812.5174.png
# Saved: 0.4_output_bg_dist_mean/174_mz_834.5950.png
# Saved: 0.4_output_bg_dist_mean/175_mz_634.6154.png
# Saved: 0.4_output_bg_dist_mean/176_mz_788.6130.png
# Saved: 0.4_output_bg_dist_mean/177_mz_367.3328.png
# Saved: 0.4_output_bg_dist_mean/178_mz_560.3174.png
# Saved: 0.4_output_bg_dist_mean/179_mz_560.0797.png
# Saved: 0.4_output_bg_dist_mean/180_mz_551.5052.png
# Saved: 0.4_output_bg_dist_mean/181_mz_549.5485.png
# Saved: 0.4_output_bg_dist_mean/182_mz_464.3135.png
# Saved: 0.4_output_bg_dist_mean/183_mz_397.3363.png
# Saved: 0.4_output_bg_dist_mean/184_mz_396.3100.png
# Saved: 0.4_output_bg_dist_mean/185_mz_384.3286.png
# Saved: 0.4_output_bg_dist_mean/186_mz_383.3277.png
# Saved: 0.4_output_bg_dist_mean/187_mz_366.3293.png
# Saved: 0.4_output_bg_dist_mean/188_mz_782.6530.png
# Saved: 0.4_output_bg_dist_mean/189_mz_366.1371.png
# Saved: 0.4_output_bg_dist_mean/190_mz_354.3367.png
# Saved: 0.4_output_bg_dist_mean/191_mz_353.3347.png
# Saved: 0.4_output_bg_dist_mean/192_mz_326.3040.png
# Saved: 0.4_output_bg_dist_mean/193_mz_264.2661.png
# Saved: 0.4_output_bg_dist_mean/194_mz_264.1099.png
# Saved: 0.4_output_bg_dist_mean/195_mz_257.2299.png
# Saved: 0.4_output_bg_dist_mean/196_mz_247.2447.png
# Saved: 0.4_output_bg_dist_mean/197_mz_215.1771.png
# Saved: 0.4_output_bg_dist_mean/198_mz_577.5215.png
# Saved: 0.4_output_bg_dist_mean/199_mz_578.5188.png
# Saved: 0.4_output_bg_dist_mean/200_mz_579.5273.png
# Saved: 0.4_output_bg_dist_mean/201_mz_587.5433.png
# Saved: 0.4_output_bg_dist_mean/202_mz_780.5778.png
# Saved: 0.4_output_bg_dist_mean/203_mz_777.5555.png
# Saved: 0.4_output_bg_dist_mean/204_mz_771.5526.png
# Saved: 0.4_output_bg_dist_mean/205_mz_770.5583.png
# Saved: 0.4_output_bg_dist_mean/206_mz_766.5276.png
# Saved: 0.4_output_bg_dist_mean/207_mz_757.5601.png
# Saved: 0.4_output_bg_dist_mean/208_mz_751.5392.png
# Saved: 0.4_output_bg_dist_mean/209_mz_742.5174.png
# Saved: 0.4_output_bg_dist_mean/210_mz_740.4961.png
# Saved: 0.4_output_bg_dist_mean/211_mz_729.5701.png
# Saved: 0.4_output_bg_dist_mean/212_mz_728.5562.png
# Saved: 0.4_output_bg_dist_mean/213_mz_702.5467.png
# Saved: 0.4_output_bg_dist_mean/214_mz_649.5179.png
# Saved: 0.4_output_bg_dist_mean/215_mz_635.5397.png
# Saved: 0.4_output_bg_dist_mean/216_mz_611.5435.png
# Saved: 0.4_output_bg_dist_mean/217_mz_606.5544.png
# Saved: 0.4_output_bg_dist_mean/218_mz_605.5548.png
# Saved: 0.4_output_bg_dist_mean/219_mz_604.5345.png
# Saved: 0.4_output_bg_dist_mean/220_mz_603.5365.png
# Saved: 0.4_output_bg_dist_mean/221_mz_1544.1542.png
# ⚠️ Skipping m/z 161.1338 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/222_mz_161.1338.png
# ⚠️ Skipping m/z 198.1210 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/223_mz_198.1210.png
# ⚠️ Skipping m/z 222.0783 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/224_mz_222.0783.png
# ⚠️ Skipping m/z 224.1000 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/225_mz_224.1000.png
# ⚠️ Skipping m/z 243.2107 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/226_mz_243.2107.png
# ⚠️ Skipping m/z 255.2101 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/227_mz_255.2101.png
# ⚠️ Skipping m/z 270.1184 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/228_mz_270.1184.png
# ⚠️ Skipping m/z 282.2793 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/229_mz_282.2793.png
# ⚠️ Skipping m/z 284.2929 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/230_mz_284.2929.png
# ⚠️ Skipping m/z 327.2354 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/231_mz_327.2354.png
# ⚠️ Skipping m/z 339.2947 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/232_mz_339.2947.png
# ⚠️ Skipping m/z 352.3177 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/233_mz_352.3177.png
# ⚠️ Skipping m/z 355.3483 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/234_mz_355.3483.png
# ⚠️ Skipping m/z 356.3532 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/235_mz_356.3532.png
# ⚠️ Skipping m/z 398.3291 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/236_mz_398.3291.png
# ⚠️ Skipping m/z 480.3211 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/237_mz_480.3211.png
# ⚠️ Skipping m/z 522.3597 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/238_mz_522.3597.png
# ⚠️ Skipping m/z 534.2923 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/239_mz_534.2923.png
# ⚠️ Skipping m/z 599.4994 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/240_mz_599.4994.png
# ⚠️ Skipping m/z 620.6035 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/241_mz_620.6035.png
# ⚠️ Skipping m/z 621.6046 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/242_mz_621.6046.png
# ⚠️ Skipping m/z 630.6179 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/243_mz_630.6179.png
# ⚠️ Skipping m/z 631.6271 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/244_mz_631.6271.png
# ⚠️ Skipping m/z 646.6168 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/245_mz_646.6168.png
# ⚠️ Skipping m/z 648.6279 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/246_mz_648.6279.png
# ⚠️ Skipping m/z 697.4753 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/247_mz_697.4753.png
# ⚠️ Skipping m/z 710.4850 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/248_mz_710.4850.png
# ⚠️ Skipping m/z 713.4442 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/249_mz_713.4442.png
# ⚠️ Skipping m/z 714.4474 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/250_mz_714.4474.png
# ⚠️ Skipping m/z 720.5643 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/251_mz_720.5643.png
# ⚠️ Skipping m/z 723.4974 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/252_mz_723.4974.png
# ⚠️ Skipping m/z 739.4628 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/253_mz_739.4628.png
# ⚠️ Skipping m/z 741.4946 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/254_mz_741.4946.png
# ⚠️ Skipping m/z 756.5510 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/255_mz_756.5510.png
# ⚠️ Skipping m/z 762.4953 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/256_mz_762.4953.png
# ⚠️ Skipping m/z 767.5312 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/257_mz_767.5312.png
# ⚠️ Skipping m/z 769.5648 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/258_mz_769.5648.png
# ⚠️ Skipping m/z 772.5231 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/259_mz_772.5231.png
# ⚠️ Skipping m/z 773.5307 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/260_mz_773.5307.png
# ⚠️ Skipping m/z 774.5268 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/261_mz_774.5268.png
# ⚠️ Skipping m/z 775.5356 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/262_mz_775.5356.png
# ⚠️ Skipping m/z 778.4689 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/263_mz_778.4689.png
# ⚠️ Skipping m/z 781.5784 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/264_mz_781.5784.png
# ⚠️ Skipping m/z 786.4932 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/265_mz_786.4932.png
# ⚠️ Skipping m/z 787.4854 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/266_mz_787.4854.png
# ⚠️ Skipping m/z 788.5027 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/267_mz_788.5027.png
# ⚠️ Skipping m/z 789.4961 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/268_mz_789.4961.png
# ⚠️ Skipping m/z 791.5339 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/269_mz_791.5339.png
# ⚠️ Skipping m/z 792.6645 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/270_mz_792.6645.png
# ⚠️ Skipping m/z 797.5770 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/271_mz_797.5770.png
# ⚠️ Skipping m/z 798.5391 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/272_mz_798.5391.png
# ⚠️ Skipping m/z 799.5511 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/273_mz_799.5511.png
# ⚠️ Skipping m/z 802.4798 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/274_mz_802.4798.png
# ⚠️ Skipping m/z 802.5665 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/275_mz_802.5665.png
# ⚠️ Skipping m/z 805.4882 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/276_mz_805.4882.png
# ⚠️ Skipping m/z 806.5172 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/277_mz_806.5172.png
# ⚠️ Skipping m/z 807.5094 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/278_mz_807.5094.png
# ⚠️ Skipping m/z 808.5023 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/279_mz_808.5023.png
# ⚠️ Skipping m/z 808.6637 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/280_mz_808.6637.png
# ⚠️ Skipping m/z 810.6888 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/281_mz_810.6888.png
# ⚠️ Skipping m/z 813.5133 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/282_mz_813.5133.png
# ⚠️ Skipping m/z 815.5320 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/283_mz_815.5320.png
# ⚠️ Skipping m/z 818.5523 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/284_mz_818.5523.png
# ⚠️ Skipping m/z 820.5273 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/285_mz_820.5273.png
# ⚠️ Skipping m/z 821.5281 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/286_mz_821.5281.png
# ⚠️ Skipping m/z 822.5297 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/287_mz_822.5297.png
# ⚠️ Skipping m/z 823.6320 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/288_mz_823.6320.png
# ⚠️ Skipping m/z 824.4467 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/289_mz_824.4467.png
# ⚠️ Skipping m/z 824.5594 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/290_mz_824.5594.png
# ⚠️ Skipping m/z 825.5629 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/291_mz_825.5629.png
# ⚠️ Skipping m/z 826.4664 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/292_mz_826.4664.png
# ⚠️ Skipping m/z 826.5668 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/293_mz_826.5668.png
# ⚠️ Skipping m/z 827.5714 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/294_mz_827.5714.png
# ⚠️ Skipping m/z 828.5011 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/295_mz_828.5011.png
# ⚠️ Skipping m/z 828.5639 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/296_mz_828.5639.png
# ⚠️ Skipping m/z 830.5131 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/297_mz_830.5131.png
# ⚠️ Skipping m/z 831.5201 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/298_mz_831.5201.png
# ⚠️ Skipping m/z 832.5150 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/299_mz_832.5150.png
# ⚠️ Skipping m/z 833.5862 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/300_mz_833.5862.png
# ⚠️ Skipping m/z 836.6271 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/301_mz_836.6271.png
# ⚠️ Skipping m/z 837.6503 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/302_mz_837.6503.png
# ⚠️ Skipping m/z 838.6237 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/303_mz_838.6237.png
# ⚠️ Skipping m/z 839.6229 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/304_mz_839.6229.png
# ⚠️ Skipping m/z 840.4328 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/305_mz_840.4328.png
# ⚠️ Skipping m/z 840.6227 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/306_mz_840.6227.png
# ⚠️ Skipping m/z 844.5262 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/307_mz_844.5262.png
# ⚠️ Skipping m/z 845.5290 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/308_mz_845.5290.png
# ⚠️ Skipping m/z 846.5322 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/309_mz_846.5322.png
# ⚠️ Skipping m/z 847.5362 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/310_mz_847.5362.png
# ⚠️ Skipping m/z 848.5533 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/311_mz_848.5533.png
# ⚠️ Skipping m/z 848.6424 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/312_mz_848.6424.png
# ⚠️ Skipping m/z 849.5585 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/313_mz_849.5585.png
# ⚠️ Skipping m/z 849.6475 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/314_mz_849.6475.png
# ⚠️ Skipping m/z 850.4877 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/315_mz_850.4877.png
# ⚠️ Skipping m/z 850.5641 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/316_mz_850.5641.png
# ⚠️ Skipping m/z 850.6533 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/317_mz_850.6533.png
# ⚠️ Skipping m/z 851.6469 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/318_mz_851.6469.png
# ⚠️ Skipping m/z 852.4881 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/319_mz_852.4881.png
# ⚠️ Skipping m/z 852.6411 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/320_mz_852.6411.png
# ⚠️ Skipping m/z 853.4827 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/321_mz_853.4827.png
# ⚠️ Skipping m/z 853.6358 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/322_mz_853.6358.png
# ⚠️ Skipping m/z 854.4907 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/323_mz_854.4907.png
# ⚠️ Skipping m/z 856.5085 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/324_mz_856.5085.png
# ⚠️ Skipping m/z 858.5287 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/325_mz_858.5287.png
# ⚠️ Skipping m/z 864.6292 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/326_mz_864.6292.png
# ⚠️ Skipping m/z 865.6309 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/327_mz_865.6309.png
# ⚠️ Skipping m/z 866.4661 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/328_mz_866.4661.png
# ⚠️ Skipping m/z 866.6460 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/329_mz_866.6460.png
# ⚠️ Skipping m/z 867.6489 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/330_mz_867.6489.png
# ⚠️ Skipping m/z 868.4722 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/331_mz_868.4722.png
# ⚠️ Skipping m/z 869.4633 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/332_mz_869.4633.png
# ⚠️ Skipping m/z 870.4678 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/333_mz_870.4678.png
# ⚠️ Skipping m/z 872.5560 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/334_mz_872.5560.png
# ⚠️ Skipping m/z 873.5623 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/335_mz_873.5623.png
# ⚠️ Skipping m/z 876.5071 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/336_mz_876.5071.png
# ⚠️ Skipping m/z 896.4880 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/337_mz_896.4880.png
# ⚠️ Skipping m/z 912.4556 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/338_mz_912.4556.png
# ⚠️ Skipping m/z 913.4582 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/339_mz_913.4582.png
# ⚠️ Skipping m/z 963.4792 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/340_mz_963.4792.png
# ⚠️ Skipping m/z 964.4960 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/341_mz_964.4960.png
# ⚠️ Skipping m/z 966.5311 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/342_mz_966.5311.png
# ⚠️ Skipping m/z 1542.1475 — no matching metric data found.
# Saved: 0.4_output_bg_dist_mean/343_mz_1542.1475.png

# %%
'''from skimage.measure import find_contours
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

def visualize_mz_feature_with_he(
    adata, df_metrics, df_border, mz_value, he_image_path, pixel_size=1.0, origin=(0, 0), cmap="hot"
):
    # Load H&E image
    he_img = mpimg.imread(he_image_path)

    # Find index of target m/z
    mz_idx = np.argmin(np.abs(adata.var["mzs"].values - mz_value))

    # Get coordinates and intensities
    x = adata.obs["x"].values
    y = adata.obs["y"].values
    intensities = adata.X[:, mz_idx].toarray().flatten() if hasattr(adata.X, "toarray") else adata.X[:, mz_idx].flatten()

    tissue_mask = adata.obs["tissue"].values

    # Extract COMs and border points
    mz_metrics = df_metrics[df_metrics["mz"] == mz_value].iloc[0]
    com_all = (mz_metrics["weighted_com_x_all"], mz_metrics["weighted_com_y_all"])
    com_tissue = (mz_metrics["weighted_com_x_tissue"], mz_metrics["weighted_com_y_tissue"])

    df_mz_border = df_border[df_border["mz"] == mz_value]
    max_row = df_mz_border.loc[df_mz_border["distance"].idxmax()]
    bg_point = (max_row["bg_x"], max_row["bg_y"])
    nearest_tissue_point = (max_row["tissue_x"], max_row["tissue_y"])

    # Convert coordinates to image pixel indices
    x_idx = ((x - origin[0]) / pixel_size).astype(int)
    y_idx = ((y - origin[1]) / pixel_size).astype(int)
    com_all_idx = [(com_all[0] - origin[0]) / pixel_size, (com_all[1] - origin[1]) / pixel_size]
    com_tissue_idx = [(com_tissue[0] - origin[0]) / pixel_size, (com_tissue[1] - origin[1]) / pixel_size]
    bg_point_idx = [(bg_point[0] - origin[0]) / pixel_size, (bg_point[1] - origin[1]) / pixel_size]
    nearest_tissue_point_idx = [(nearest_tissue_point[0] - origin[0]) / pixel_size, (nearest_tissue_point[1] - origin[1]) / pixel_size]

    # Create 2D tissue mask image
    grid_x = np.unique(x_idx)
    grid_y = np.unique(y_idx)
    x_to_i = {v: i for i, v in enumerate(grid_x)}
    y_to_i = {v: i for i, v in enumerate(grid_y)}
    mask_2d = np.zeros((len(grid_y), len(grid_x)), dtype=bool)

    for xi, yi, is_tissue in zip(x_idx, y_idx, tissue_mask):
        if is_tissue and xi in x_to_i and yi in y_to_i:
            mask_2d[y_to_i[yi], x_to_i[xi]] = True

    contours = find_contours(mask_2d.astype(float), level=0.5)

    # Plot
    fig, ax = plt.subplots(figsize=(10, 8))
    ax.imshow(he_img)

    # Overlay MALDI heatmap
    sc = ax.scatter(x_idx, y_idx, c=intensities, s=100, cmap=cmap, marker='s', alpha=0.6)

    # Overlay COMs
    ax.scatter(*com_all_idx, color="cyan", s=150, marker="*", label="COM (all)")
    ax.scatter(*com_tissue_idx, color="blue", s=150, marker="*", label="COM (tissue)")

    # Overlay furthest point
    ax.plot([bg_point_idx[0], nearest_tissue_point_idx[0]], [bg_point_idx[1], nearest_tissue_point_idx[1]],
             color="orange", linestyle="--", label="Max dist to tissue")
    ax.scatter(*bg_point_idx, color="red", s=80, edgecolor="black", label="Furthest BG pt")
    ax.scatter(*nearest_tissue_point_idx, color="green", s=80, edgecolor="black", label="Nearest tissue pt")

    # Overlay tissue margin
    for contour in contours:
        contour_x = grid_x[(contour[:, 1]).astype(int)]
        contour_y = grid_y[(contour[:, 0]).astype(int)]
        ax.plot(contour_x, contour_y, color="white", linewidth=1.5, label="Tissue border")

    ax.set_title(f"Overlay @ m/z {mz_value:.2f}")
    ax.set_xlabel("X")
    ax.set_ylabel("Y")
    ax.invert_yaxis()
    ax.set_aspect('equal')
    plt.colorbar(sc, ax=ax, label=f"Intensity @ m/z {mz_value:.2f}")
    ax.legend()
    plt.tight_layout()
    plt.show()
'''
# Out:
# 'from skimage.measure import find_contours\nimport matplotlib.pyplot as plt\nimport matplotlib.image as mpimg\nimport numpy as np\n\ndef visualize_mz_feature_with_he(\n    adata, df_metrics, df_border, mz_value, he_image_path, pixel_size=1.0, origin=(0, 0), cmap="hot"\n):\n    # Load H&E image\n    he_img = mpimg.imread(he_image_path)\n\n    # Find index of target m/z\n    mz_idx = np.argmin(np.abs(adata.var["mzs"].values - mz_value))\n\n    # Get coordinates and intensities\n    x = adata.obs["x"].values\n    y = adata.obs["y"].values\n    intensities = adata.X[:, mz_idx].toarray().flatten() if hasattr(adata.X, "toarray") else adata.X[:, mz_idx].flatten()\n\n    tissue_mask = adata.obs["tissue"].values\n\n    # Extract COMs and border points\n    mz_metrics = df_metrics[df_metrics["mz"] == mz_value].iloc[0]\n    com_all = (mz_metrics["weighted_com_x_all"], mz_metrics["weighted_com_y_all"])\n    com_tissue = (mz_metrics["weighted_com_x_tissue"], mz_metrics["weighted_com_y_tissue"])\n\n    df_mz_border = df_border[df_border["mz"] == mz_value]\n    max_row = df_mz_border.loc[df_mz_border["distance"].idxmax()]\n    bg_point = (max_row["bg_x"], max_row["bg_y"])\n    nearest_tissue_point = (max_row["tissue_x"], max_row["tissue_y"])\n\n    # Convert coordinates to image pixel indices\n    x_idx = ((x - origin[0]) / pixel_size).astype(int)\n    y_idx = ((y - origin[1]) / pixel_size).astype(int)\n    com_all_idx = [(com_all[0] - origin[0]) / pixel_size, (com_all[1] - origin[1]) / pixel_size]\n    com_tissue_idx = [(com_tissue[0] - origin[0]) / pixel_size, (com_tissue[1] - origin[1]) / pixel_size]\n    bg_point_idx = [(bg_point[0] - origin[0]) / pixel_size, (bg_point[1] - origin[1]) / pixel_size]\n    nearest_tissue_point_idx = [(nearest_tissue_point[0] - origin[0]) / pixel_size, (nearest_tissue_point[1] - origin[1]) / pixel_size]\n\n    # Create 2D tissue mask image\n    grid_x = np.unique(x_idx)\n    grid_y = np.unique(y_idx)\n    x_to_i = {v: i for i, v in enumerate(grid_x)}\n    y_to_i = {v: i for i, v in enumerate(grid_y)}\n    mask_2d = np.zeros((len(grid_y), len(grid_x)), dtype=bool)\n\n    for xi, yi, is_tissue in zip(x_idx, y_idx, tissue_mask):\n        if is_tissue and xi in x_to_i and yi in y_to_i:\n            mask_2d[y_to_i[yi], x_to_i[xi]] = True\n\n    contours = find_contours(mask_2d.astype(float), level=0.5)\n\n    # Plot\n    fig, ax = plt.subplots(figsize=(10, 8))\n    ax.imshow(he_img)\n\n    # Overlay MALDI heatmap\n    sc = ax.scatter(x_idx, y_idx, c=intensities, s=100, cmap=cmap, marker=\'s\', alpha=0.6)\n\n    # Overlay COMs\n    ax.scatter(*com_all_idx, color="cyan", s=150, marker="*", label="COM (all)")\n    ax.scatter(*com_tissue_idx, color="blue", s=150, marker="*", label="COM (tissue)")\n\n    # Overlay furthest point\n    ax.plot([bg_point_idx[0], nearest_tissue_point_idx[0]], [bg_point_idx[1], nearest_tissue_point_idx[1]],\n             color="orange", linestyle="--", label="Max dist to tissue")\n    ax.scatter(*bg_point_idx, color="red", s=80, edgecolor="black", label="Furthest BG pt")\n    ax.scatter(*nearest_tissue_point_idx, color="green", s=80, edgecolor="black", label="Nearest tissue pt")\n\n    # Overlay tissue margin\n    for contour in contours:\n        contour_x = grid_x[(contour[:, 1]).astype(int)]\n        contour_y = grid_y[(contour[:, 0]).astype(int)]\n        ax.plot(contour_x, contour_y, color="white", linewidth=1.5, label="Tissue border")\n\n    ax.set_title(f"Overlay @ m/z {mz_value:.2f}")\n    ax.set_xlabel("X")\n    ax.set_ylabel("Y")\n    ax.invert_yaxis()\n    ax.set_aspect(\'equal\')\n    plt.colorbar(sc, ax=ax, label=f"Intensity @ m/z {mz_value:.2f}")\n    ax.legend()\n    plt.tight_layout()\n    plt.show()\n'

# %%
'''visualize_mz_feature_with_he(
    adata,
    df_metrics,
    df_border,
    mz_value=772.5231,
    he_image_path="path/to/your/he_image.png",
    pixel_size=10.0,  # adjust to match your spatial scale
    origin=(0, 0),
    cmap="hot"
)'''
# Out:
# 'visualize_mz_feature_with_he(\n    adata,\n    df_metrics,\n    df_border,\n    mz_value=772.5231,\n    he_image_path="path/to/your/he_image.png",\n    pixel_size=10.0,  # adjust to match your spatial scale\n    origin=(0, 0),\n    cmap="hot"\n)'

# %%
'''from skimage.transform import AffineTransform, warp

# Define transform manually
transform = AffineTransform(
    scale=(pixel_size, pixel_size),   # e.g., (10, 10) if MALDI is 10 µm/pixel
    translation=(-origin_x, -origin_y),  # shift MALDI to H&E
    rotation=np.deg2rad(angle)       # optional
)'''
# Out:
# 'from skimage.transform import AffineTransform, warp\n\n# Define transform manually\ntransform = AffineTransform(\n    scale=(pixel_size, pixel_size),   # e.g., (10, 10) if MALDI is 10 µm/pixel\n    translation=(-origin_x, -origin_y),  # shift MALDI to H&E\n    rotation=np.deg2rad(angle)       # optional\n)'

# %%
'''# You supply these
msi_points = np.array([[x1_msi, y1_msi], [x2_msi, y2_msi], [x3_msi, y3_msi]])
he_points = np.array([[x1_he, y1_he], [x2_he, y2_he], [x3_he, y3_he]])'''
# Out:
# '# You supply these\nmsi_points = np.array([[x1_msi, y1_msi], [x2_msi, y2_msi], [x3_msi, y3_msi]])\nhe_points = np.array([[x1_he, y1_he], [x2_he, y2_he], [x3_he, y3_he]])'

# %%
'''from skimage.transform import estimate_transform

tform = estimate_transform('affine', msi_points, he_points)'''
# Out:
# "from skimage.transform import estimate_transform\n\ntform = estimate_transform('affine', msi_points, he_points)"

# %%
'''transformed_coords = tform(adata.obs[["x", "y"]].values)
'''
# Out:
# 'transformed_coords = tform(adata.obs[["x", "y"]].values)\n'

# %%
'''import imreg_dft as ird
from skimage import io

# Load images
ref_img = io.imread("he_image.png", as_gray=True)
mov_img = maldi_heatmap  # e.g., summed MALDI intensity as 2D image

# Align
result = ird.similarity(ref_img, mov_img, numiter=3)
aligned_maldi = ird.transform_img(mov_img, tvec=result["tvec"])'''
# Out:
# 'import imreg_dft as ird\nfrom skimage import io\n\n# Load images\nref_img = io.imread("he_image.png", as_gray=True)\nmov_img = maldi_heatmap  # e.g., summed MALDI intensity as 2D image\n\n# Align\nresult = ird.similarity(ref_img, mov_img, numiter=3)\naligned_maldi = ird.transform_img(mov_img, tvec=result["tvec"])'
